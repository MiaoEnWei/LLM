# %%
# 0. IMPORTS & CONFIG

import json
import os
import re 
import pandas as pd
import networkx as nx
import torch
from datetime import datetime
from transformers import AutoTokenizer, AutoModelForCausalLM

# Automatically detect device
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# ---------- Please modify according to your actual paths ----------
# If you have a local GPT-2, fill in the local path; otherwise use "gpt2", "gpt2-medium", "gpt2-xl" directly
GPT2_PATH     = "/media/miaoen/ad4277ac-5cfe-47b0-a2cc-f9e50e0da444/LLM/gpt2-medmcqa-raft-masked"  
PRIMEKG_PATH  = "kg.csv" 
MEDMCQA_FILE  = r"/media/miaoen/ad4277ac-5cfe-47b0-a2cc-f9e50e0da444/LLM/data/medmcqa/dev.json"  # Note: Add 'r' for Windows paths

# ---------- RAG Parameters ----------
MAX_RAG_ENTITIES = 3       # Number of entities to retrieve
MAX_K_EDGES      = 3       # Number of edges retrieved per entity (reduce quantity to save Tokens)
MAX_CTX_CHARS    = 600     # Strictly limit context length to reserve generation space for GPT-2

print(f"Config loaded. Running on {DEVICE}")
# Out:
# Config loaded. Running on cuda

# %%
# Cell 2: Load GPT-2 Model

def load_gpt2(model_path):
    print(f"Loading GPT-2 from: {model_path}")
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
        
    model = AutoModelForCausalLM.from_pretrained(model_path)
    model.to(DEVICE)
    model.eval()
    print("GPT-2 loaded.")
    return tokenizer, model

gpt2_tokenizer, gpt2_model = load_gpt2(GPT2_PATH)

def gpt2_generate(prompt, max_new_tokens=10):
    inputs = gpt2_tokenizer(prompt, return_tensors="pt", truncation=True, max_length=1000).to(DEVICE)
    
    with torch.no_grad():
        outputs = gpt2_model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False,        # Greedy decoding
            pad_token_id=gpt2_tokenizer.eos_token_id,
            eos_token_id=gpt2_tokenizer.eos_token_id
        )
    
    full_text = gpt2_tokenizer.decode(outputs[0], skip_special_tokens=True)
    return full_text
# Out:
# Loading GPT-2 from: /media/miaoen/ad4277ac-5cfe-47b0-a2cc-f9e50e0da444/LLM/gpt2-medmcqa-raft-masked
# GPT-2 loaded.

# %%
# Cell 3: Load Knowledge Graph (PrimeKG)

def load_kg(path):
    print(f"Loading PrimeKG from {path} ...")
    if not os.path.exists(path):
        print("Warning: KG file not found. Creating empty graph.")
        return nx.Graph()
        
    df = pd.read_csv(path, low_memory=False)
    G = nx.from_pandas_edgelist(df, "x_name", "y_name", edge_attr=True)
    print(f"KG Loaded: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")
    return G

G = load_kg(PRIMEKG_PATH)

# Create index
node_index = {str(n).lower(): n for n in G.nodes()}

def resolve_node(name):
    return node_index.get(name.lower()) if name else None

def get_knowledge_context_single(entity, max_edges=MAX_K_EDGES):
    node = resolve_node(entity)
    if node is None: return None

    try:
        edges = list(G.edges(node, data=True))
    except: return None
    
    if not edges: return None

    lines = []
    # Prioritize meaningful relations
    sorted_edges = sorted(edges, key=lambda x: x[2].get('relation', ''), reverse=True)
    
    for u, v, attr in sorted_edges[:max_edges]:
        rel = attr.get("display_relation", attr.get("relation", "related to"))
        nbr = v if node == u else u
        lines.append(f"{node} is {rel} {nbr}.")

    return " ".join(lines)
# Out:
# Loading PrimeKG from kg.csv ...
# KG Loaded: 129262 nodes, 4049405 edges

# %%
# Cell 4: RAG Retrieval Logic (Includes optimized entity extraction + context construction)

import string
import re

# --- 1. Preprocessing: Build fast lookup index ---
# Store node names as a Set, lookup speed is O(1)
# This step is placed outside the function to run only once
valid_nodes_set = set(n.lower() for n in node_index.keys() if len(n) >= 4)

def extract_rag_entities(question, max_entities=MAX_RAG_ENTITIES):
    """
    Optimized version: Uses Set intersection for O(1) lookup, extremely fast.
    """
    q_lower = question.lower()
    
    # Simple tokenization (remove punctuation)
    translator = str.maketrans('', '', string.punctuation)
    clean_q = q_lower.translate(translator)
    tokens = clean_q.split()
    
    # Generate N-grams (supports matching phrases like "heart disease")
    candidates_in_q = set()
    
    # 1-gram (Single words)
    for token in tokens:
        candidates_in_q.add(token)
        
    # 2-gram (Bigrams)
    if len(tokens) >= 2:
        for i in range(len(tokens)-1):
            candidates_in_q.add(f"{tokens[i]} {tokens[i+1]}")
            
    # 3-gram (Trigrams)
    if len(tokens) >= 3:
        for i in range(len(tokens)-2):
            candidates_in_q.add(f"{tokens[i]} {tokens[i+1]} {tokens[i+2]}")

    # Set intersection operation (extremely fast)
    matched = list(candidates_in_q.intersection(valid_nodes_set))
    
    # Sort: Prioritize matching longer words
    matched.sort(key=lambda x: len(x), reverse=True)
    
    # Convert back to Node ID
    ents = []
    count = 0
    for m in matched:
        node_id = node_index.get(m)
        if node_id:
            ents.append(node_id)
            count += 1
            if count >= max_entities:
                break
    return ents

def get_knowledge_context_multi(question):
    """
    This is the function that was reported missing:
    Responsible for calling the extraction function, then converting extracted entities into text Facts.
    """
    # 1. Extract entities
    entities = extract_rag_entities(question)
    if not entities:
        return [], ""

    # 2. Find neighbors and concatenate text
    all_facts = []
    current_len = 0

    for ent in entities:
        # Call the single entity query function defined in Cell 3
        ctx = get_knowledge_context_single(ent)
        if not ctx: continue

        block = f"Fact: {ctx} "
        
        # Length truncation protection
        if current_len + len(block) > MAX_CTX_CHARS:
            break

        all_facts.append(block)
        current_len += len(block)

    return entities, "".join(all_facts)

print("Cell 4 (RAG Logic) updated successfully.")
# Out:
# Cell 4 (RAG Logic) updated successfully.

# %%
# Cell 5: Load Data & Answer Parsing Tools

# Replace the load_medmcqa_example function in Cell 5
def load_medmcqa_example(idx, file_path=MEDMCQA_FILE):
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"File not found: {file_path}")
        
    with open(file_path, "r", encoding="utf-8") as f:
        for line_id, line in enumerate(f):
            if line_id < idx: continue
            line = line.strip()
            if not line: continue
            
            if line_id == idx:
                data = json.loads(line)
                q = data.get("question", "")
                
                # Extract independent options for scoring
                options_dict = {}
                mapping = {"opa":"A", "opb":"B", "opc":"C", "opd":"D"}
                options_text_list = []
                
                for key, lab in mapping.items():
                    if key in data and data[key]:
                        # Clean the option text
                        opt_val = str(data[key]).strip()
                        options_dict[lab] = opt_val
                        options_text_list.append(f"({lab}) {opt_val}")
                
                # Keep the original formatted_q for display (if still needed)
                formatted_q = f"{q}\nOptions:\n" + "\n".join(options_text_list)
                
                return {
                    "question_text": formatted_q,
                    "pure_question": q,
                    "options": options_dict,  # New: Return structured options
                    "answer": data.get("cop")
                }
            if line_id > idx: break
    raise IndexError("Index out of range")

# The parsing function `parse_answer` is no longer needed in scoring mode; it can be kept or deleted.

def parse_answer(text):
    """
    [Fix] Powerful regex parsing to extract A/B/C/D from messy generated text.
    """
    text = text.upper()
    # 1. Prioritize finding explicit formats like "Answer: A" or "Option A"
    match = re.search(r'(?:ANSWER|OPTION|CHOICE)[:\s\-]*([ABCD])', text)
    if match:
        return match.group(1)
    
    # 2. If not found, look for (A) enclosed in parentheses
    match = re.search(r'\(([ABCD])\)', text)
    if match:
        return match.group(1)
        
    # 3. Last resort: Only look at the last appearance of A/B/C/D
    # But be careful not to match letters inside words. Only match standalone A/B/C/D
    candidates = re.findall(r'\b([ABCD])\b', text)
    if candidates:
        return candidates[-1]
        
    return "Random" # Really cannot parse

# %%
# Cell 6: Inference Functions (Fixed Version - Only calculates Loss for the option part)

import torch
import torch.nn.functional as F

def get_lm_score(context, question, option_text):
    """
    Advanced Scoring: Use labels = -100 to mask the Question part,
    calculating Loss (Conditional Likelihood) only for the Option part.
    This effectively solves the "long question diluting option" issue.
    """
    # 1. Construct Prompt and Full Text
    # Note: Add a space after "Answer:" to match GPT-2 conventions
    if context:
        prompt = f"Context: {context}\nQuestion: {question}\nAnswer:"
    else:
        prompt = f"Question: {question}\nAnswer:"
        
    full_text = f"{prompt} {option_text}"
    
    # 2. Encode separately
    # We need to know the length of the prompt to mask it out
    prompt_enc = gpt2_tokenizer(prompt, return_tensors="pt", add_special_tokens=False)
    full_enc = gpt2_tokenizer(full_text, return_tensors="pt", truncation=True, max_length=1024)
    
    input_ids = full_enc.input_ids.to(DEVICE)
    attention_mask = full_enc.attention_mask.to(DEVICE)
    
    # 3. Construct Labels
    # In HuggingFace, if Labels are set to -100, that position is ignored during Loss calculation
    labels = input_ids.clone()
    
    # Get the length of the prompt
    # Note: Be careful if full_text is truncated, though usually the prompt won't be too long
    prompt_len = prompt_enc.input_ids.shape[1]
    
    # Set labels for the prompt part to -100 (excluded from Loss)
    # Perform masking as long as prompt_len is less than the total length
    if prompt_len < labels.shape[1]:
        labels[:, :prompt_len] = -100
    else:
        # Extremely rare case: prompt is longer than truncated length (almost never happens)
        labels[:, :] = -100 
        
    # 4. Calculate Loss
    with torch.no_grad():
        # The model automatically handles labels of -100
        outputs = gpt2_model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        
        # If everything is masked (e.g., option is too long and truncated), loss might be nan
        if torch.isnan(outputs.loss):
            return -float('inf')
            
        loss = outputs.loss.item()
    
    # Return negative Loss (the higher, the better)
    return -loss

# The solve_by_scoring function does not need changes; keep it as is
def solve_by_scoring(question, options_dict, context=""):
    scores = {}
    for label in ["A", "B", "C", "D"]:
        if label not in options_dict:
            scores[label] = -float('inf')
            continue
        opt_text = options_dict[label]
        score = get_lm_score(context, question, opt_text)
        scores[label] = score
    best_label = max(scores, key=scores.get)
    return best_label, scores

# %%
# Replace evaluate_gpt2_and_save in Cell 7
def evaluate_gpt2_and_save(start_idx=0, end_idx=20, output_dir="eval_results"):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    save_path = os.path.join(output_dir, f"gpt2_scoring_results_{timestamp}.jsonl")
    
    print(f"Results will be saved to: {save_path}")
    print(f"Starting SCORING evaluation {start_idx} -> {end_idx}...\n")

    total = 0
    correct_base = 0
    correct_rag = 0
    
    def format_gt(val):
        if val is None: return None
        s = str(val).strip().upper()
        # Handle cases where it might be 1/2/3/4
        mapping = {'1':'A', '2':'B', '3':'C', '4':'D'}
        return mapping.get(s, s) if s in mapping else (s if s in ['A','B','C','D'] else None)

    with open(save_path, "w", encoding="utf-8") as f:
        for i in range(start_idx, end_idx):
            try:
                ex = load_medmcqa_example(i)
            except Exception as e:
                print(f"Skipping {i}: {e}")
                continue
                
            gt = format_gt(ex['answer'])
            if not gt: continue
            
            q_text = ex['pure_question']
            opts = ex['options']
            
            # --- 1. Base Inference (Scoring Method) ---
            pred_base, scores_base = solve_by_scoring(q_text, opts, context="")
            
            # --- 2. RAG Inference (Scoring Method) ---
            # Retrieve first
            entities, ctx = get_knowledge_context_multi(q_text)
            pred_rag, scores_rag = solve_by_scoring(q_text, opts, context=ctx)
            
            # --- 3. Statistics ---
            total += 1
            if pred_base == gt: correct_base += 1
            if pred_rag == gt: correct_rag += 1
            
            # --- 4. Recording ---
            record = {
                "id": i,
                "question": q_text,
                "ground_truth": gt,
                "base_prediction": pred_base,
                "rag_prediction": pred_rag,
                "rag_context": ctx,
                "is_base_correct": (pred_base == gt),
                "is_rag_correct": (pred_rag == gt)
            }
            
            f.write(json.dumps(record, ensure_ascii=False) + "\n")
            
            # Print status
            status = ""
            if pred_rag == gt and pred_base != gt: status = "RAG Fix"
            elif pred_rag != gt and pred_base == gt: status = "RAG Hurt"
            
            print(f"[{i}] GT:{gt} | Base:{pred_base} | RAG:{pred_rag} | {status}")

    if total > 0:
        print(f"\n{'='*30}")
        print(f"Total Samples: {total}")
        print(f"Base Accuracy: {correct_base/total:.2%}")
        print(f"RAG  Accuracy: {correct_rag/total:.2%}")
        print(f"{'='*30}\n")

# Run evaluation
evaluate_gpt2_and_save(0, 4183)
# Out:
# Results will be saved to: eval_results/gpt2_scoring_results_20251215_154935.jsonl
# Starting SCORING evaluation 0 -> 4183...
#
# [0] GT:A | Base:A | RAG:A |
# [1] GT:A | Base:B | RAG:B |
# [2] GT:C | Base:C | RAG:A | RAG Hurt
# [3] GT:C | Base:C | RAG:C |
# [4] GT:A | Base:C | RAG:C |
# [5] GT:A | Base:A | RAG:A |
# [6] GT:A | Base:A | RAG:A |
# [7] GT:B | Base:A | RAG:A |
# [8] GT:B | Base:D | RAG:D |
# [9] GT:B | Base:D | RAG:D |
# [10] GT:B | Base:A | RAG:A |
# [11] GT:A | Base:A | RAG:A |
# [12] GT:B | Base:A | RAG:A |
# [13] GT:A | Base:D | RAG:D |
# [14] GT:A | Base:C | RAG:C |
# [15] GT:B | Base:A | RAG:A |
# [16] GT:A | Base:A | RAG:A |
# [17] GT:D | Base:C | RAG:C |
# [18] GT:A | Base:B | RAG:B |
# [19] GT:A | Base:D | RAG:D |
# [20] GT:B | Base:B | RAG:B |
# [21] GT:C | Base:A | RAG:A |
# [22] GT:A | Base:D | RAG:D |
# [23] GT:A | Base:D | RAG:D |
# [24] GT:D | Base:C | RAG:C |
# [25] GT:B | Base:C | RAG:C |
# [26] GT:A | Base:C | RAG:C |
# [27] GT:D | Base:D | RAG:D |
# [28] GT:A | Base:D | RAG:D |
# [29] GT:C | Base:B | RAG:B |
# [30] GT:A | Base:C | RAG:C |
# [31] GT:B | Base:C | RAG:C |
# [32] GT:A | Base:A | RAG:A |
# [33] GT:A | Base:D | RAG:D |
# [34] GT:D | Base:C | RAG:C |
# [35] GT:C | Base:C | RAG:C |
# [36] GT:B | Base:B | RAG:B |
# [37] GT:D | Base:C | RAG:C |
# [38] GT:C | Base:A | RAG:A |
# [39] GT:C | Base:C | RAG:D | RAG Hurt
# [40] GT:B | Base:D | RAG:D |
# [41] GT:A | Base:C | RAG:C |
# [42] GT:D | Base:C | RAG:C |
# [43] GT:D | Base:A | RAG:A |
# [44] GT:A | Base:B | RAG:B |
# [45] GT:B | Base:A | RAG:A |
# [46] GT:B | Base:D | RAG:D |
# [47] GT:A | Base:D | RAG:D |
# [48] GT:C | Base:A | RAG:A |
# [49] GT:C | Base:D | RAG:D |
# [50] GT:B | Base:B | RAG:B |
# [51] GT:C | Base:A | RAG:A |
# [52] GT:B | Base:A | RAG:A |
# [53] GT:A | Base:C | RAG:C |
# [54] GT:B | Base:A | RAG:A |
# [55] GT:C | Base:C | RAG:C |
# [56] GT:C | Base:B | RAG:B |
# [57] GT:A | Base:A | RAG:A |
# [58] GT:A | Base:C | RAG:C |
# [59] GT:D | Base:A | RAG:A |
# [60] GT:D | Base:B | RAG:B |
# [61] GT:C | Base:C | RAG:C |
# [62] GT:A | Base:D | RAG:C |
# [63] GT:D | Base:D | RAG:D |
# [64] GT:A | Base:A | RAG:A |
# [65] GT:D | Base:C | RAG:C |
# [66] GT:C | Base:A | RAG:A |
# [67] GT:D | Base:B | RAG:B |
# [68] GT:C | Base:B | RAG:B |
# [69] GT:B | Base:C | RAG:C |
# [70] GT:B | Base:D | RAG:D |
# [71] GT:C | Base:A | RAG:A |
# [72] GT:A | Base:D | RAG:D |
# [73] GT:B | Base:A | RAG:A |
# [74] GT:D | Base:D | RAG:D |
# [75] GT:A | Base:D | RAG:A | RAG Fix
# [76] GT:A | Base:C | RAG:C |
# [77] GT:B | Base:D | RAG:D |
# [78] GT:B | Base:D | RAG:D |
# [79] GT:B | Base:A | RAG:A |
# [80] GT:C | Base:A | RAG:A |
# [81] GT:A | Base:B | RAG:B |
# [82] GT:A | Base:A | RAG:A |
# [83] GT:A | Base:A | RAG:A |
# [84] GT:A | Base:D | RAG:D |
# [85] GT:C | Base:B | RAG:B |
# [86] GT:A | Base:B | RAG:B |
# [87] GT:D | Base:B | RAG:B |
# [88] GT:A | Base:B | RAG:B |
# [89] GT:D | Base:B | RAG:B |
# [90] GT:B | Base:D | RAG:D |
# [91] GT:B | Base:A | RAG:A |
# [92] GT:B | Base:D | RAG:D |
# [93] GT:A | Base:D | RAG:D |
# [94] GT:C | Base:B | RAG:B |
# [95] GT:A | Base:D | RAG:D |
# [96] GT:B | Base:C | RAG:C |
# [97] GT:D | Base:B | RAG:B |
# [98] GT:B | Base:D | RAG:D |
# [99] GT:D | Base:B | RAG:B |
# [100] GT:A | Base:D | RAG:D |
# [101] GT:B | Base:D | RAG:D |
# [102] GT:A | Base:B | RAG:B |
# [103] GT:D | Base:A | RAG:A |
# [104] GT:B | Base:A | RAG:A |
# [105] GT:A | Base:A | RAG:B | RAG Hurt
# [106] GT:D | Base:A | RAG:A |
# [107] GT:B | Base:D | RAG:D |
# [108] GT:C | Base:C | RAG:C |
# [109] GT:A | Base:C | RAG:C |
# [110] GT:A | Base:A | RAG:A |
# [111] GT:D | Base:B | RAG:B |
# [112] GT:A | Base:C | RAG:C |
# [113] GT:C | Base:B | RAG:B |
# [114] GT:A | Base:D | RAG:D |
# [115] GT:B | Base:A | RAG:A |
# [116] GT:C | Base:B | RAG:B |
# [117] GT:B | Base:B | RAG:B |
# [118] GT:A | Base:D | RAG:D |
# [119] GT:A | Base:B | RAG:B |
# [120] GT:C | Base:B | RAG:B |
# [121] GT:A | Base:B | RAG:B |
# [122] GT:A | Base:B | RAG:B |
# [123] GT:D | Base:C | RAG:C |
# [124] GT:B | Base:B | RAG:D | RAG Hurt
# [125] GT:A | Base:D | RAG:D |
# [126] GT:A | Base:C | RAG:C |
# [127] GT:B | Base:A | RAG:A |
# [128] GT:D | Base:A | RAG:A |
# [129] GT:B | Base:C | RAG:C |
# [130] GT:C | Base:B | RAG:A |
# [131] GT:D | Base:C | RAG:D | RAG Fix
# [132] GT:B | Base:D | RAG:D |
# [133] GT:B | Base:B | RAG:B |
# [134] GT:B | Base:C | RAG:C |
# [135] GT:A | Base:C | RAG:C |
# [136] GT:B | Base:B | RAG:B |
# [137] GT:A | Base:B | RAG:B |
# [138] GT:C | Base:D | RAG:D |
# [139] GT:A | Base:A | RAG:A |
# [140] GT:C | Base:B | RAG:B |
# [141] GT:A | Base:D | RAG:D |
# [142] GT:A | Base:D | RAG:D |
# [143] GT:C | Base:D | RAG:A |
# [144] GT:B | Base:A | RAG:A |
# [145] GT:A | Base:C | RAG:C |
# [146] GT:C | Base:D | RAG:D |
# [147] GT:A | Base:B | RAG:B |
# [148] GT:D | Base:C | RAG:C |
# [149] GT:B | Base:B | RAG:B |
# [150] GT:A | Base:A | RAG:A |
# [151] GT:B | Base:B | RAG:B |
# [152] GT:C | Base:C | RAG:D | RAG Hurt
# [153] GT:A | Base:A | RAG:A |
# [154] GT:B | Base:A | RAG:B | RAG Fix
# [155] GT:B | Base:D | RAG:D |
# [156] GT:A | Base:C | RAG:C |
# [157] GT:D | Base:D | RAG:D |
# [158] GT:C | Base:C | RAG:C |
# [159] GT:D | Base:B | RAG:B |
# [160] GT:B | Base:D | RAG:D |
# [161] GT:B | Base:C | RAG:C |
# [162] GT:B | Base:C | RAG:C |
# [163] GT:D | Base:D | RAG:D |
# [164] GT:A | Base:C | RAG:C |
# [165] GT:C | Base:B | RAG:B |
# [166] GT:D | Base:C | RAG:C |
# [167] GT:B | Base:C | RAG:C |
# [168] GT:B | Base:A | RAG:A |
# [169] GT:C | Base:B | RAG:A |
# [170] GT:B | Base:D | RAG:D |
# [171] GT:A | Base:A | RAG:A |
# [172] GT:B | Base:D | RAG:D |
# [173] GT:A | Base:D | RAG:D |
# [174] GT:B | Base:A | RAG:D |
# [175] GT:C | Base:B | RAG:B |
# [176] GT:B | Base:B | RAG:B |
# [177] GT:C | Base:C | RAG:C |
# [178] GT:D | Base:D | RAG:D |
# [179] GT:D | Base:A | RAG:D | RAG Fix
# [180] GT:B | Base:C | RAG:C |
# [181] GT:A | Base:D | RAG:D |
# [182] GT:A | Base:C | RAG:C |
# [183] GT:A | Base:B | RAG:B |
# [184] GT:C | Base:D | RAG:D |
# [185] GT:C | Base:D | RAG:D |
# [186] GT:B | Base:D | RAG:D |
# [187] GT:A | Base:B | RAG:B |
# [188] GT:C | Base:B | RAG:B |
# [189] GT:A | Base:A | RAG:A |
# [190] GT:B | Base:A | RAG:A |
# [191] GT:A | Base:D | RAG:D |
# [192] GT:B | Base:A | RAG:A |
# [193] GT:B | Base:C | RAG:C |
# [194] GT:B | Base:D | RAG:D |
# [195] GT:B | Base:B | RAG:B |
# [196] GT:A | Base:A | RAG:A |
# [197] GT:B | Base:C | RAG:A |
# [198] GT:D | Base:D | RAG:D |
# [199] GT:A | Base:B | RAG:A | RAG Fix
# [200] GT:D | Base:B | RAG:B |
# [201] GT:C | Base:B | RAG:B |
# [202] GT:B | Base:C | RAG:C |
# [203] GT:C | Base:D | RAG:D |
# [204] GT:C | Base:C | RAG:C |
# [205] GT:D | Base:A | RAG:A |
# [206] GT:C | Base:C | RAG:C |
# [207] GT:C | Base:D | RAG:D |
# [208] GT:D | Base:B | RAG:B |
# [209] GT:B | Base:D | RAG:D |
# [210] GT:B | Base:B | RAG:B |
# [211] GT:A | Base:A | RAG:A |
# [212] GT:D | Base:D | RAG:D |
# [213] GT:C | Base:B | RAG:B |
# [214] GT:C | Base:B | RAG:B |
# [215] GT:C | Base:D | RAG:D |
# [216] GT:A | Base:D | RAG:D |
# [217] GT:A | Base:A | RAG:A |
# [218] GT:D | Base:B | RAG:B |
# [219] GT:D | Base:B | RAG:B |
# [220] GT:A | Base:A | RAG:B | RAG Hurt
# [221] GT:C | Base:D | RAG:D |
# [222] GT:B | Base:A | RAG:A |
# [223] GT:C | Base:B | RAG:B |
# [224] GT:D | Base:D | RAG:D |
# [225] GT:A | Base:C | RAG:C |
# [226] GT:A | Base:A | RAG:A |
# [227] GT:A | Base:D | RAG:D |
# [228] GT:B | Base:C | RAG:C |
# [229] GT:B | Base:C | RAG:C |
# [230] GT:A | Base:D | RAG:D |
# [231] GT:A | Base:A | RAG:A |
# [232] GT:D | Base:A | RAG:A |
# [233] GT:D | Base:C | RAG:C |
# [234] GT:D | Base:A | RAG:A |
# [235] GT:C | Base:C | RAG:C |
# [236] GT:D | Base:A | RAG:A |
# [237] GT:C | Base:C | RAG:C |
# [238] GT:C | Base:D | RAG:D |
# [239] GT:C | Base:D | RAG:D |
# [240] GT:D | Base:D | RAG:D |
# [241] GT:A | Base:B | RAG:A | RAG Fix
# [242] GT:D | Base:C | RAG:C |
# [243] GT:C | Base:C | RAG:C |
# [244] GT:D | Base:A | RAG:A |
# [245] GT:A | Base:A | RAG:A |
# [246] GT:A | Base:C | RAG:C |
# [247] GT:C | Base:A | RAG:A |
# [248] GT:A | Base:C | RAG:C |
# [249] GT:D | Base:A | RAG:A |
# [250] GT:D | Base:A | RAG:A |
# [251] GT:A | Base:B | RAG:B |
# [252] GT:D | Base:D | RAG:D |
# [253] GT:C | Base:D | RAG:C | RAG Fix
# [254] GT:A | Base:C | RAG:C |
# [255] GT:C | Base:D | RAG:D |
# [256] GT:D | Base:C | RAG:C |
# [257] GT:A | Base:B | RAG:B |
# [258] GT:A | Base:C | RAG:C |
# [259] GT:C | Base:D | RAG:D |
# [260] GT:C | Base:D | RAG:D |
# [261] GT:C | Base:C | RAG:D | RAG Hurt
# [262] GT:D | Base:A | RAG:A |
# [263] GT:D | Base:D | RAG:D |
# [264] GT:B | Base:D | RAG:D |
# [265] GT:D | Base:D | RAG:D |
# [266] GT:A | Base:A | RAG:A |
# [267] GT:B | Base:C | RAG:B | RAG Fix
# [268] GT:B | Base:B | RAG:B |
# [269] GT:C | Base:D | RAG:D |
# [270] GT:C | Base:B | RAG:D |
# [271] GT:D | Base:D | RAG:D |
# [272] GT:A | Base:D | RAG:D |
# [273] GT:C | Base:C | RAG:C |
# [274] GT:C | Base:B | RAG:B |
# [275] GT:D | Base:D | RAG:D |
# [276] GT:D | Base:A | RAG:A |
# [277] GT:B | Base:A | RAG:A |
# [278] GT:B | Base:B | RAG:B |
# [279] GT:D | Base:B | RAG:B |
# [280] GT:A | Base:A | RAG:A |
# [281] GT:C | Base:A | RAG:A |
# [282] GT:C | Base:B | RAG:B |
# [283] GT:D | Base:D | RAG:D |
# [284] GT:C | Base:B | RAG:B |
# [285] GT:C | Base:B | RAG:B |
# [286] GT:C | Base:B | RAG:B |
# [287] GT:D | Base:C | RAG:C |
# [288] GT:B | Base:B | RAG:B |
# [289] GT:C | Base:A | RAG:A |
# [290] GT:D | Base:C | RAG:C |
# [291] GT:C | Base:C | RAG:C |
# [292] GT:A | Base:B | RAG:B |
# [293] GT:D | Base:A | RAG:A |
# [294] GT:D | Base:B | RAG:B |
# [295] GT:B | Base:C | RAG:C |
# [296] GT:A | Base:D | RAG:D |
# [297] GT:B | Base:B | RAG:B |
# [298] GT:B | Base:C | RAG:C |
# [299] GT:A | Base:C | RAG:C |
# [300] GT:A | Base:D | RAG:D |
# [301] GT:C | Base:A | RAG:A |
# [302] GT:B | Base:A | RAG:A |
# [303] GT:D | Base:A | RAG:A |
# [304] GT:A | Base:A | RAG:A |
# [305] GT:B | Base:C | RAG:C |
# [306] GT:B | Base:B | RAG:B |
# [307] GT:A | Base:B | RAG:B |
# [308] GT:A | Base:A | RAG:A |
# [309] GT:B | Base:D | RAG:D |
# [310] GT:B | Base:C | RAG:C |
# [311] GT:A | Base:A | RAG:A |
# [312] GT:D | Base:C | RAG:C |
# [313] GT:A | Base:C | RAG:C |
# [314] GT:A | Base:C | RAG:C |
# [315] GT:B | Base:C | RAG:C |
# [316] GT:A | Base:A | RAG:A |
# [317] GT:A | Base:A | RAG:A |
# [318] GT:A | Base:A | RAG:A |
# [319] GT:B | Base:D | RAG:D |
# [320] GT:A | Base:B | RAG:B |
# [321] GT:D | Base:C | RAG:C |
# [322] GT:D | Base:D | RAG:D |
# [323] GT:B | Base:D | RAG:D |
# [324] GT:D | Base:A | RAG:A |
# [325] GT:B | Base:B | RAG:B |
# [326] GT:B | Base:C | RAG:C |
# [327] GT:B | Base:D | RAG:D |
# [328] GT:B | Base:B | RAG:B |
# [329] GT:D | Base:C | RAG:C |
# [330] GT:C | Base:A | RAG:A |
# [331] GT:D | Base:C | RAG:C |
# [332] GT:D | Base:D | RAG:A | RAG Hurt
# [333] GT:A | Base:A | RAG:A |
# [334] GT:B | Base:A | RAG:A |
# [335] GT:A | Base:B | RAG:B |
# [336] GT:B | Base:D | RAG:D |
# [337] GT:A | Base:A | RAG:A |
# [338] GT:B | Base:A | RAG:A |
# [339] GT:A | Base:D | RAG:D |
# [340] GT:C | Base:A | RAG:A |
# [341] GT:A | Base:B | RAG:B |
# [342] GT:D | Base:D | RAG:D |
# [343] GT:B | Base:D | RAG:D |
# [344] GT:A | Base:C | RAG:C |
# [345] GT:C | Base:A | RAG:A |
# [346] GT:B | Base:B | RAG:B |
# [347] GT:A | Base:B | RAG:B |
# [348] GT:C | Base:B | RAG:A |
# [349] GT:B | Base:B | RAG:B |
# [350] GT:A | Base:A | RAG:A |
# [351] GT:C | Base:C | RAG:C |
# [352] GT:A | Base:D | RAG:D |
# [353] GT:D | Base:B | RAG:B |
# [354] GT:A | Base:A | RAG:A |
# [355] GT:A | Base:C | RAG:C |
# [356] GT:C | Base:D | RAG:D |
# [357] GT:B | Base:B | RAG:B |
# [358] GT:A | Base:D | RAG:D |
# [359] GT:A | Base:A | RAG:A |
# [360] GT:B | Base:D | RAG:D |
# [361] GT:B | Base:C | RAG:C |
# [362] GT:A | Base:D | RAG:D |
# [363] GT:B | Base:C | RAG:C |
# [364] GT:C | Base:D | RAG:D |
# [365] GT:A | Base:D | RAG:D |
# [366] GT:D | Base:C | RAG:C |
# [367] GT:D | Base:A | RAG:A |
# [368] GT:B | Base:C | RAG:C |
# [369] GT:B | Base:A | RAG:A |
# [370] GT:B | Base:C | RAG:C |
# [371] GT:B | Base:D | RAG:D |
# [372] GT:D | Base:D | RAG:D |
# [373] GT:B | Base:B | RAG:B |
# [374] GT:C | Base:B | RAG:B |
# [375] GT:D | Base:D | RAG:D |
# [376] GT:B | Base:A | RAG:A |
# [377] GT:A | Base:D | RAG:D |
# [378] GT:A | Base:C | RAG:C |
# [379] GT:D | Base:B | RAG:B |
# [380] GT:B | Base:D | RAG:D |
# [381] GT:D | Base:A | RAG:A |
# [382] GT:A | Base:D | RAG:D |
# [383] GT:C | Base:A | RAG:A |
# [384] GT:B | Base:A | RAG:A |
# [385] GT:A | Base:D | RAG:D |
# [386] GT:A | Base:C | RAG:C |
# [387] GT:D | Base:D | RAG:D |
# [388] GT:A | Base:C | RAG:C |
# [389] GT:D | Base:D | RAG:B | RAG Hurt
# [390] GT:A | Base:D | RAG:D |
# [391] GT:A | Base:C | RAG:C |
# [392] GT:C | Base:A | RAG:A |
# [393] GT:B | Base:A | RAG:A |
# [394] GT:A | Base:D | RAG:C |
# [395] GT:B | Base:D | RAG:D |
# [396] GT:A | Base:C | RAG:C |
# [397] GT:A | Base:B | RAG:B |
# [398] GT:D | Base:B | RAG:B |
# [399] GT:C | Base:B | RAG:B |
# [400] GT:A | Base:D | RAG:A | RAG Fix
# [401] GT:A | Base:B | RAG:B |
# [402] GT:A | Base:C | RAG:C |
# [403] GT:A | Base:A | RAG:A |
# [404] GT:C | Base:C | RAG:C |
# [405] GT:A | Base:B | RAG:B |
# [406] GT:B | Base:A | RAG:A |
# [407] GT:D | Base:B | RAG:B |
# [408] GT:B | Base:A | RAG:A |
# [409] GT:D | Base:D | RAG:D |
# [410] GT:B | Base:D | RAG:D |
# [411] GT:A | Base:B | RAG:B |
# [412] GT:B | Base:A | RAG:A |
# [413] GT:C | Base:C | RAG:C |
# [414] GT:C | Base:A | RAG:A |
# [415] GT:A | Base:B | RAG:B |
# [416] GT:A | Base:D | RAG:D |
# [417] GT:C | Base:C | RAG:C |
# [418] GT:C | Base:A | RAG:A |
# [419] GT:D | Base:C | RAG:C |
# [420] GT:D | Base:D | RAG:D |
# [421] GT:D | Base:C | RAG:C |
# [422] GT:B | Base:A | RAG:A |
# [423] GT:D | Base:C | RAG:C |
# [424] GT:C | Base:D | RAG:D |
# [425] GT:C | Base:D | RAG:D |
# [426] GT:A | Base:C | RAG:C |
# [427] GT:A | Base:D | RAG:D |
# [428] GT:A | Base:C | RAG:C |
# [429] GT:A | Base:A | RAG:A |
# [430] GT:C | Base:D | RAG:D |
# [431] GT:A | Base:C | RAG:C |
# [432] GT:D | Base:A | RAG:A |
# [433] GT:D | Base:A | RAG:A |
# [434] GT:C | Base:B | RAG:B |
# [435] GT:D | Base:B | RAG:B |
# [436] GT:A | Base:D | RAG:B |
# [437] GT:A | Base:B | RAG:B |
# [438] GT:C | Base:D | RAG:D |
# [439] GT:C | Base:A | RAG:A |
# [440] GT:B | Base:D | RAG:C |
# [441] GT:A | Base:A | RAG:A |
# [442] GT:A | Base:C | RAG:C |
# [443] GT:D | Base:C | RAG:C |
# [444] GT:A | Base:A | RAG:A |
# [445] GT:C | Base:D | RAG:D |
# [446] GT:C | Base:B | RAG:B |
# [447] GT:D | Base:B | RAG:B |
# [448] GT:D | Base:C | RAG:C |
# [449] GT:C | Base:D | RAG:D |
# [450] GT:A | Base:C | RAG:C |
# [451] GT:A | Base:B | RAG:B |
# [452] GT:B | Base:C | RAG:C |
# [453] GT:D | Base:D | RAG:D |
# [454] GT:B | Base:D | RAG:D |
# [455] GT:A | Base:A | RAG:A |
# [456] GT:D | Base:C | RAG:C |
# [457] GT:B | Base:D | RAG:D |
# [458] GT:B | Base:D | RAG:D |
# [459] GT:A | Base:D | RAG:D |
# [460] GT:A | Base:B | RAG:D |
# [461] GT:B | Base:D | RAG:D |
# [462] GT:A | Base:C | RAG:C |
# [463] GT:C | Base:C | RAG:C |
# [464] GT:D | Base:D | RAG:D |
# [465] GT:B | Base:D | RAG:D |
# [466] GT:A | Base:B | RAG:B |
# [467] GT:B | Base:D | RAG:D |
# [468] GT:C | Base:D | RAG:A |
# [469] GT:B | Base:D | RAG:D |
# [470] GT:C | Base:D | RAG:D |
# [471] GT:D | Base:D | RAG:D |
# [472] GT:A | Base:D | RAG:D |
# [473] GT:B | Base:A | RAG:C |
# [474] GT:A | Base:D | RAG:D |
# [475] GT:B | Base:D | RAG:B | RAG Fix
# [476] GT:A | Base:C | RAG:C |
# [477] GT:B | Base:B | RAG:B |
# [478] GT:A | Base:B | RAG:B |
# [479] GT:C | Base:A | RAG:A |
# [480] GT:C | Base:C | RAG:C |
# [481] GT:B | Base:B | RAG:B |
# [482] GT:B | Base:B | RAG:B |
# [483] GT:C | Base:D | RAG:D |
# [484] GT:B | Base:D | RAG:D |
# [485] GT:C | Base:B | RAG:D |
# [486] GT:A | Base:C | RAG:C |
# [487] GT:D | Base:A | RAG:A |
# [488] GT:C | Base:B | RAG:B |
# [489] GT:A | Base:C | RAG:C |
# [490] GT:A | Base:A | RAG:D | RAG Hurt
# [491] GT:C | Base:A | RAG:B |
# [492] GT:A | Base:C | RAG:C |
# [493] GT:C | Base:B | RAG:B |
# [494] GT:C | Base:A | RAG:B |
# [495] GT:C | Base:D | RAG:D |
# [496] GT:B | Base:A | RAG:A |
# [497] GT:D | Base:B | RAG:B |
# [498] GT:B | Base:A | RAG:A |
# [499] GT:B | Base:A | RAG:A |
# [500] GT:A | Base:D | RAG:A | RAG Fix
# [501] GT:D | Base:D | RAG:C | RAG Hurt
# [502] GT:D | Base:A | RAG:A |
# [503] GT:B | Base:D | RAG:D |
# [504] GT:C | Base:A | RAG:A |
# [505] GT:A | Base:D | RAG:D |
# [506] GT:B | Base:B | RAG:B |
# [507] GT:C | Base:D | RAG:C | RAG Fix
# [508] GT:D | Base:A | RAG:A |
# [509] GT:B | Base:C | RAG:C |
# [510] GT:A | Base:A | RAG:A |
# [511] GT:A | Base:A | RAG:A |
# [512] GT:A | Base:D | RAG:D |
# [513] GT:D | Base:A | RAG:A |
# [514] GT:B | Base:B | RAG:B |
# [515] GT:C | Base:D | RAG:D |
# [516] GT:D | Base:D | RAG:A | RAG Hurt
# [517] GT:A | Base:C | RAG:C |
# [518] GT:D | Base:D | RAG:D |
# [519] GT:A | Base:A | RAG:A |
# [520] GT:D | Base:B | RAG:B |
# [521] GT:A | Base:D | RAG:D |
# [522] GT:C | Base:D | RAG:D |
# [523] GT:D | Base:A | RAG:A |
# [524] GT:A | Base:A | RAG:A |
# [525] GT:A | Base:D | RAG:D |
# [526] GT:A | Base:C | RAG:C |
# [527] GT:A | Base:C | RAG:C |
# [528] GT:A | Base:A | RAG:A |
# [529] GT:D | Base:A | RAG:A |
# [530] GT:B | Base:B | RAG:B |
# [531] GT:A | Base:D | RAG:D |
# [532] GT:C | Base:A | RAG:A |
# [533] GT:A | Base:B | RAG:B |
# [534] GT:B | Base:B | RAG:B |
# [535] GT:D | Base:D | RAG:D |
# [536] GT:B | Base:B | RAG:B |
# [537] GT:C | Base:B | RAG:B |
# [538] GT:A | Base:D | RAG:D |
# [539] GT:B | Base:D | RAG:D |
# [540] GT:B | Base:A | RAG:A |
# [541] GT:B | Base:C | RAG:C |
# [542] GT:D | Base:D | RAG:D |
# [543] GT:B | Base:A | RAG:A |
# [544] GT:A | Base:A | RAG:A |
# [545] GT:C | Base:B | RAG:B |
# [546] GT:D | Base:C | RAG:C |
# [547] GT:A | Base:D | RAG:D |
# [548] GT:C | Base:B | RAG:B |
# [549] GT:B | Base:B | RAG:B |
# [550] GT:B | Base:A | RAG:A |
# [551] GT:D | Base:C | RAG:C |
# [552] GT:D | Base:D | RAG:D |
# [553] GT:D | Base:C | RAG:C |
# [554] GT:D | Base:C | RAG:B |
# [555] GT:A | Base:D | RAG:D |
# [556] GT:B | Base:B | RAG:B |
# [557] GT:B | Base:C | RAG:C |
# [558] GT:D | Base:D | RAG:D |
# [559] GT:A | Base:A | RAG:A |
# [560] GT:B | Base:A | RAG:A |
# [561] GT:D | Base:C | RAG:C |
# [562] GT:B | Base:C | RAG:C |
# [563] GT:A | Base:D | RAG:D |
# [564] GT:A | Base:A | RAG:A |
# [565] GT:A | Base:A | RAG:A |
# [566] GT:D | Base:B | RAG:B |
# [567] GT:A | Base:C | RAG:C |
# [568] GT:A | Base:C | RAG:C |
# [569] GT:D | Base:B | RAG:B |
# [570] GT:A | Base:D | RAG:D |
# [571] GT:A | Base:C | RAG:C |
# [572] GT:B | Base:D | RAG:D |
# [573] GT:C | Base:A | RAG:A |
# [574] GT:C | Base:D | RAG:D |
# [575] GT:A | Base:A | RAG:A |
# [576] GT:B | Base:B | RAG:B |
# [577] GT:A | Base:A | RAG:A |
# [578] GT:A | Base:C | RAG:C |
# [579] GT:A | Base:C | RAG:C |
# [580] GT:B | Base:B | RAG:B |
# [581] GT:C | Base:C | RAG:C |
# [582] GT:C | Base:B | RAG:B |
# [583] GT:A | Base:A | RAG:A |
# [584] GT:B | Base:C | RAG:C |
# [585] GT:C | Base:B | RAG:B |
# [586] GT:A | Base:A | RAG:A |
# [587] GT:A | Base:B | RAG:B |
# [588] GT:A | Base:A | RAG:A |
# [589] GT:B | Base:D | RAG:D |
# [590] GT:D | Base:D | RAG:A | RAG Hurt
# [591] GT:C | Base:D | RAG:D |
# [592] GT:B | Base:A | RAG:A |
# [593] GT:B | Base:C | RAG:C |
# [594] GT:C | Base:C | RAG:C |
# [595] GT:C | Base:D | RAG:D |
# [596] GT:A | Base:A | RAG:A |
# [597] GT:C | Base:C | RAG:C |
# [598] GT:A | Base:D | RAG:D |
# [599] GT:D | Base:D | RAG:C | RAG Hurt
# [600] GT:B | Base:A | RAG:A |
# [601] GT:A | Base:D | RAG:D |
# [602] GT:B | Base:A | RAG:A |
# [603] GT:D | Base:D | RAG:D |
# [604] GT:D | Base:B | RAG:B |
# [605] GT:D | Base:B | RAG:D | RAG Fix
# [606] GT:C | Base:D | RAG:D |
# [607] GT:A | Base:B | RAG:B |
# [608] GT:A | Base:D | RAG:D |
# [609] GT:D | Base:A | RAG:A |
# [610] GT:B | Base:D | RAG:D |
# [611] GT:D | Base:D | RAG:D |
# [612] GT:A | Base:B | RAG:B |
# [613] GT:B | Base:B | RAG:B |
# [614] GT:A | Base:B | RAG:B |
# [615] GT:B | Base:B | RAG:B |
# [616] GT:B | Base:C | RAG:C |
# [617] GT:C | Base:D | RAG:D |
# [618] GT:C | Base:D | RAG:D |
# [619] GT:A | Base:A | RAG:A |
# [620] GT:D | Base:A | RAG:A |
# [621] GT:B | Base:D | RAG:D |
# [622] GT:A | Base:B | RAG:B |
# [623] GT:A | Base:B | RAG:B |
# [624] GT:D | Base:D | RAG:D |
# [625] GT:C | Base:A | RAG:D |
# [626] GT:D | Base:C | RAG:C |
# [627] GT:B | Base:A | RAG:A |
# [628] GT:A | Base:B | RAG:B |
# [629] GT:C | Base:C | RAG:C |
# [630] GT:B | Base:C | RAG:C |
# [631] GT:C | Base:A | RAG:A |
# [632] GT:C | Base:A | RAG:A |
# [633] GT:A | Base:A | RAG:A |
# [634] GT:B | Base:B | RAG:B |
# [635] GT:A | Base:B | RAG:B |
# [636] GT:C | Base:D | RAG:D |
# [637] GT:A | Base:D | RAG:D |
# [638] GT:B | Base:C | RAG:C |
# [639] GT:B | Base:A | RAG:A |
# [640] GT:B | Base:C | RAG:B | RAG Fix
# [641] GT:C | Base:A | RAG:A |
# [642] GT:A | Base:A | RAG:A |
# [643] GT:B | Base:C | RAG:C |
# [644] GT:A | Base:C | RAG:C |
# [645] GT:A | Base:C | RAG:C |
# [646] GT:D | Base:B | RAG:B |
# [647] GT:A | Base:C | RAG:C |
# [648] GT:C | Base:C | RAG:C |
# [649] GT:B | Base:A | RAG:A |
# [650] GT:D | Base:B | RAG:B |
# [651] GT:B | Base:C | RAG:C |
# [652] GT:D | Base:C | RAG:C |
# [653] GT:B | Base:A | RAG:A |
# [654] GT:C | Base:D | RAG:B |
# [655] GT:C | Base:D | RAG:D |
# [656] GT:B | Base:D | RAG:D |
# [657] GT:A | Base:B | RAG:B |
# [658] GT:B | Base:A | RAG:D |
# [659] GT:A | Base:B | RAG:B |
# [660] GT:A | Base:C | RAG:C |
# [661] GT:B | Base:D | RAG:D |
# [662] GT:A | Base:C | RAG:C |
# [663] GT:A | Base:A | RAG:A |
# [664] GT:D | Base:D | RAG:D |
# [665] GT:D | Base:A | RAG:A |
# [666] GT:A | Base:C | RAG:C |
# [667] GT:D | Base:A | RAG:A |
# [668] GT:B | Base:D | RAG:D |
# [669] GT:C | Base:B | RAG:B |
# [670] GT:A | Base:D | RAG:D |
# [671] GT:A | Base:D | RAG:D |
# [672] GT:D | Base:B | RAG:B |
# [673] GT:D | Base:B | RAG:B |
# [674] GT:D | Base:A | RAG:A |
# [675] GT:B | Base:C | RAG:C |
# [676] GT:A | Base:B | RAG:B |
# [677] GT:B | Base:D | RAG:D |
# [678] GT:A | Base:A | RAG:A |
# [679] GT:B | Base:B | RAG:B |
# [680] GT:D | Base:B | RAG:B |
# [681] GT:C | Base:C | RAG:C |
# [682] GT:B | Base:B | RAG:B |
# [683] GT:B | Base:D | RAG:D |
# [684] GT:D | Base:C | RAG:C |
# [685] GT:B | Base:B | RAG:B |
# [686] GT:A | Base:C | RAG:C |
# [687] GT:D | Base:B | RAG:B |
# [688] GT:D | Base:B | RAG:B |
# [689] GT:D | Base:B | RAG:B |
# [690] GT:B | Base:D | RAG:D |
# [691] GT:C | Base:C | RAG:C |
# [692] GT:D | Base:C | RAG:C |
# [693] GT:B | Base:D | RAG:D |
# [694] GT:D | Base:D | RAG:D |
# [695] GT:A | Base:D | RAG:D |
# [696] GT:A | Base:A | RAG:A |
# [697] GT:C | Base:A | RAG:A |
# [698] GT:A | Base:C | RAG:C |
# [699] GT:C | Base:C | RAG:C |
# [700] GT:B | Base:D | RAG:D |
# [701] GT:A | Base:C | RAG:C |
# [702] GT:D | Base:A | RAG:A |
# [703] GT:C | Base:D | RAG:D |
# [704] GT:A | Base:C | RAG:C |
# [705] GT:B | Base:A | RAG:A |
# [706] GT:D | Base:D | RAG:D |
# [707] GT:B | Base:C | RAG:C |
# [708] GT:B | Base:D | RAG:D |
# [709] GT:D | Base:D | RAG:D |
# [710] GT:A | Base:B | RAG:B |
# [711] GT:D | Base:A | RAG:A |
# [712] GT:B | Base:C | RAG:C |
# [713] GT:B | Base:D | RAG:A |
# [714] GT:B | Base:C | RAG:C |
# [715] GT:A | Base:C | RAG:C |
# [716] GT:B | Base:B | RAG:B |
# [717] GT:D | Base:A | RAG:A |
# [718] GT:A | Base:A | RAG:A |
# [719] GT:A | Base:C | RAG:C |
# [720] GT:C | Base:C | RAG:C |
# [721] GT:D | Base:A | RAG:A |
# [722] GT:C | Base:C | RAG:C |
# [723] GT:B | Base:C | RAG:C |
# [724] GT:B | Base:B | RAG:D | RAG Hurt
# [725] GT:C | Base:C | RAG:C |
# [726] GT:B | Base:B | RAG:B |
# [727] GT:C | Base:D | RAG:D |
# [728] GT:A | Base:C | RAG:C |
# [729] GT:B | Base:A | RAG:A |
# [730] GT:D | Base:C | RAG:C |
# [731] GT:C | Base:A | RAG:A |
# [732] GT:B | Base:A | RAG:A |
# [733] GT:B | Base:D | RAG:D |
# [734] GT:A | Base:A | RAG:A |
# [735] GT:D | Base:B | RAG:B |
# [736] GT:C | Base:D | RAG:D |
# [737] GT:A | Base:B | RAG:B |
# [738] GT:B | Base:D | RAG:D |
# [739] GT:C | Base:C | RAG:C |
# [740] GT:C | Base:A | RAG:A |
# [741] GT:A | Base:A | RAG:A |
# [742] GT:A | Base:D | RAG:D |
# [743] GT:B | Base:D | RAG:D |
# [744] GT:A | Base:A | RAG:A |
# [745] GT:C | Base:D | RAG:D |
# [746] GT:D | Base:C | RAG:C |
# [747] GT:C | Base:C | RAG:C |
# [748] GT:A | Base:D | RAG:D |
# [749] GT:D | Base:C | RAG:C |
# [750] GT:B | Base:B | RAG:B |
# [751] GT:B | Base:B | RAG:B |
# [752] GT:A | Base:A | RAG:A |
# [753] GT:D | Base:D | RAG:D |
# [754] GT:C | Base:A | RAG:A |
# [755] GT:A | Base:C | RAG:C |
# [756] GT:C | Base:C | RAG:C |
# [757] GT:B | Base:D | RAG:D |
# [758] GT:C | Base:C | RAG:C |
# [759] GT:A | Base:D | RAG:D |
# [760] GT:A | Base:C | RAG:C |
# [761] GT:C | Base:A | RAG:A |
# [762] GT:B | Base:A | RAG:A |
# [763] GT:C | Base:D | RAG:D |
# [764] GT:A | Base:D | RAG:B |
# [765] GT:D | Base:A | RAG:A |
# [766] GT:C | Base:D | RAG:D |
# [767] GT:A | Base:D | RAG:D |
# [768] GT:B | Base:A | RAG:A |
# [769] GT:A | Base:B | RAG:B |
# [770] GT:A | Base:D | RAG:A | RAG Fix
# [771] GT:A | Base:C | RAG:C |
# [772] GT:A | Base:C | RAG:C |
# [773] GT:B | Base:A | RAG:A |
# [774] GT:C | Base:C | RAG:C |
# [775] GT:C | Base:B | RAG:B |
# [776] GT:C | Base:D | RAG:D |
# [777] GT:A | Base:A | RAG:A |
# [778] GT:D | Base:C | RAG:C |
# [779] GT:B | Base:B | RAG:B |
# [780] GT:A | Base:A | RAG:A |
# [781] GT:D | Base:C | RAG:C |
# [782] GT:A | Base:A | RAG:A |
# [783] GT:B | Base:A | RAG:A |
# [784] GT:A | Base:C | RAG:C |
# [785] GT:D | Base:D | RAG:D |
# [786] GT:C | Base:B | RAG:B |
# [787] GT:D | Base:B | RAG:B |
# [788] GT:A | Base:B | RAG:B |
# [789] GT:A | Base:A | RAG:A |
# [790] GT:B | Base:B | RAG:B |
# [791] GT:A | Base:D | RAG:D |
# [792] GT:A | Base:A | RAG:A |
# [793] GT:A | Base:A | RAG:A |
# [794] GT:C | Base:D | RAG:D |
# [795] GT:A | Base:B | RAG:B |
# [796] GT:A | Base:A | RAG:A |
# [797] GT:B | Base:A | RAG:A |
# [798] GT:C | Base:A | RAG:A |
# [799] GT:A | Base:C | RAG:C |
# [800] GT:C | Base:C | RAG:C |
# [801] GT:A | Base:A | RAG:A |
# [802] GT:D | Base:A | RAG:A |
# [803] GT:C | Base:C | RAG:C |
# [804] GT:A | Base:A | RAG:A |
# [805] GT:A | Base:A | RAG:A |
# [806] GT:C | Base:C | RAG:C |
# [807] GT:D | Base:D | RAG:D |
# [808] GT:A | Base:A | RAG:A |
# [809] GT:D | Base:B | RAG:B |
# [810] GT:C | Base:A | RAG:A |
# [811] GT:D | Base:B | RAG:B |
# [812] GT:A | Base:A | RAG:A |
# [813] GT:B | Base:A | RAG:A |
# [814] GT:B | Base:C | RAG:A |
# [815] GT:A | Base:C | RAG:C |
# [816] GT:B | Base:B | RAG:B |
# [817] GT:A | Base:D | RAG:D |
# [818] GT:A | Base:D | RAG:D |
# [819] GT:B | Base:C | RAG:C |
# [820] GT:A | Base:C | RAG:C |
# [821] GT:C | Base:C | RAG:C |
# [822] GT:C | Base:D | RAG:A |
# [823] GT:B | Base:C | RAG:C |
# [824] GT:B | Base:B | RAG:B |
# [825] GT:A | Base:C | RAG:C |
# [826] GT:D | Base:D | RAG:D |
# [827] GT:D | Base:A | RAG:A |
# [828] GT:C | Base:D | RAG:A |
# [829] GT:B | Base:B | RAG:B |
# [830] GT:D | Base:D | RAG:D |
# [831] GT:B | Base:A | RAG:A |
# [832] GT:C | Base:A | RAG:A |
# [833] GT:D | Base:B | RAG:B |
# [834] GT:B | Base:B | RAG:B |
# [835] GT:A | Base:A | RAG:A |
# [836] GT:A | Base:C | RAG:C |
# [837] GT:D | Base:A | RAG:A |
# [838] GT:C | Base:A | RAG:A |
# [839] GT:B | Base:B | RAG:B |
# [840] GT:A | Base:B | RAG:B |
# [841] GT:B | Base:C | RAG:C |
# [842] GT:C | Base:D | RAG:D |
# [843] GT:D | Base:D | RAG:D |
# [844] GT:B | Base:D | RAG:D |
# [845] GT:B | Base:A | RAG:A |
# [846] GT:C | Base:C | RAG:C |
# [847] GT:A | Base:D | RAG:D |
# [848] GT:A | Base:D | RAG:D |
# [849] GT:B | Base:A | RAG:A |
# [850] GT:C | Base:D | RAG:D |
# [851] GT:A | Base:A | RAG:A |
# [852] GT:C | Base:A | RAG:A |
# [853] GT:B | Base:B | RAG:A | RAG Hurt
# [854] GT:D | Base:C | RAG:C |
# [855] GT:C | Base:D | RAG:D |
# [856] GT:C | Base:A | RAG:A |
# [857] GT:A | Base:C | RAG:C |
# [858] GT:A | Base:A | RAG:A |
# [859] GT:A | Base:A | RAG:A |
# [860] GT:D | Base:A | RAG:A |
# [861] GT:A | Base:D | RAG:D |
# [862] GT:C | Base:B | RAG:B |
# [863] GT:A | Base:B | RAG:B |
# [864] GT:B | Base:C | RAG:C |
# [865] GT:A | Base:A | RAG:A |
# [866] GT:D | Base:B | RAG:B |
# [867] GT:C | Base:D | RAG:D |
# [868] GT:C | Base:D | RAG:D |
# [869] GT:C | Base:D | RAG:D |
# [870] GT:B | Base:C | RAG:C |
# [871] GT:B | Base:D | RAG:D |
# [872] GT:A | Base:A | RAG:A |
# [873] GT:A | Base:A | RAG:A |
# [874] GT:D | Base:A | RAG:A |
# [875] GT:A | Base:C | RAG:C |
# [876] GT:D | Base:C | RAG:C |
# [877] GT:A | Base:D | RAG:D |
# [878] GT:C | Base:C | RAG:D | RAG Hurt
# [879] GT:A | Base:B | RAG:B |
# [880] GT:D | Base:D | RAG:D |
# [881] GT:C | Base:A | RAG:A |
# [882] GT:C | Base:C | RAG:C |
# [883] GT:D | Base:A | RAG:A |
# [884] GT:D | Base:A | RAG:A |
# [885] GT:A | Base:C | RAG:C |
# [886] GT:C | Base:A | RAG:A |
# [887] GT:A | Base:D | RAG:D |
# [888] GT:A | Base:B | RAG:B |
# [889] GT:B | Base:D | RAG:D |
# [890] GT:C | Base:C | RAG:C |
# [891] GT:A | Base:A | RAG:A |
# [892] GT:A | Base:D | RAG:A | RAG Fix
# [893] GT:D | Base:B | RAG:B |
# [894] GT:C | Base:D | RAG:D |
# [895] GT:A | Base:D | RAG:D |
# [896] GT:B | Base:C | RAG:C |
# [897] GT:A | Base:C | RAG:C |
# [898] GT:A | Base:C | RAG:C |
# [899] GT:D | Base:B | RAG:B |
# [900] GT:A | Base:B | RAG:B |
# [901] GT:A | Base:A | RAG:A |
# [902] GT:C | Base:B | RAG:B |
# [903] GT:B | Base:B | RAG:B |
# [904] GT:A | Base:A | RAG:A |
# [905] GT:D | Base:C | RAG:C |
# [906] GT:B | Base:D | RAG:D |
# [907] GT:B | Base:A | RAG:A |
# [908] GT:D | Base:A | RAG:A |
# [909] GT:A | Base:D | RAG:D |
# [910] GT:C | Base:D | RAG:D |
# [911] GT:B | Base:A | RAG:B | RAG Fix
# [912] GT:A | Base:A | RAG:A |
# [913] GT:B | Base:B | RAG:B |
# [914] GT:D | Base:A | RAG:A |
# [915] GT:B | Base:C | RAG:C |
# [916] GT:C | Base:D | RAG:D |
# [917] GT:C | Base:D | RAG:D |
# [918] GT:B | Base:C | RAG:C |
# [919] GT:A | Base:D | RAG:D |
# [920] GT:A | Base:D | RAG:D |
# [921] GT:C | Base:B | RAG:B |
# [922] GT:A | Base:B | RAG:B |
# [923] GT:C | Base:D | RAG:B |
# [924] GT:D | Base:C | RAG:C |
# [925] GT:B | Base:D | RAG:D |
# [926] GT:B | Base:C | RAG:C |
# [927] GT:B | Base:A | RAG:A |
# [928] GT:C | Base:A | RAG:A |
# [929] GT:A | Base:C | RAG:C |
# [930] GT:A | Base:C | RAG:C |
# [931] GT:A | Base:A | RAG:A |
# [932] GT:B | Base:B | RAG:B |
# [933] GT:A | Base:B | RAG:B |
# [934] GT:C | Base:D | RAG:D |
# [935] GT:C | Base:C | RAG:C |
# [936] GT:A | Base:A | RAG:A |
# [937] GT:B | Base:A | RAG:A |
# [938] GT:A | Base:D | RAG:B |
# [939] GT:A | Base:A | RAG:A |
# [940] GT:A | Base:C | RAG:C |
# [941] GT:B | Base:D | RAG:D |
# [942] GT:B | Base:C | RAG:C |
# [943] GT:C | Base:D | RAG:D |
# [944] GT:A | Base:A | RAG:A |
# [945] GT:B | Base:A | RAG:A |
# [946] GT:B | Base:A | RAG:A |
# [947] GT:A | Base:C | RAG:C |
# [948] GT:B | Base:B | RAG:D | RAG Hurt
# [949] GT:B | Base:B | RAG:B |
# [950] GT:B | Base:B | RAG:B |
# [951] GT:A | Base:A | RAG:A |
# [952] GT:B | Base:C | RAG:C |
# [953] GT:D | Base:C | RAG:A |
# [954] GT:C | Base:C | RAG:D | RAG Hurt
# [955] GT:B | Base:A | RAG:A |
# [956] GT:B | Base:B | RAG:B |
# [957] GT:B | Base:B | RAG:B |
# [958] GT:B | Base:A | RAG:A |
# [959] GT:C | Base:A | RAG:A |
# [960] GT:B | Base:B | RAG:B |
# [961] GT:C | Base:C | RAG:C |
# [962] GT:B | Base:A | RAG:A |
# [963] GT:A | Base:A | RAG:A |
# [964] GT:D | Base:A | RAG:A |
# [965] GT:C | Base:D | RAG:D |
# [966] GT:A | Base:A | RAG:A |
# [967] GT:C | Base:B | RAG:B |
# [968] GT:C | Base:A | RAG:A |
# [969] GT:C | Base:A | RAG:A |
# [970] GT:D | Base:B | RAG:B |
# [971] GT:A | Base:A | RAG:A |
# [972] GT:D | Base:B | RAG:B |
# [973] GT:D | Base:C | RAG:D | RAG Fix
# [974] GT:A | Base:D | RAG:D |
# [975] GT:A | Base:D | RAG:D |
# [976] GT:C | Base:B | RAG:B |
# [977] GT:D | Base:B | RAG:D | RAG Fix
# [978] GT:C | Base:B | RAG:B |
# [979] GT:A | Base:C | RAG:C |
# [980] GT:C | Base:B | RAG:B |
# [981] GT:A | Base:C | RAG:B |
# [982] GT:A | Base:A | RAG:A |
# [983] GT:C | Base:C | RAG:C |
# [984] GT:D | Base:B | RAG:B |
# [985] GT:B | Base:A | RAG:A |
# [986] GT:D | Base:A | RAG:A |
# [987] GT:A | Base:C | RAG:C |
# [988] GT:D | Base:A | RAG:A |
# [989] GT:B | Base:B | RAG:B |
# [990] GT:B | Base:D | RAG:D |
# [991] GT:A | Base:D | RAG:D |
# [992] GT:A | Base:C | RAG:C |
# [993] GT:A | Base:B | RAG:B |
# [994] GT:B | Base:B | RAG:B |
# [995] GT:D | Base:B | RAG:B |
# [996] GT:D | Base:C | RAG:C |
# [997] GT:A | Base:A | RAG:A |
# [998] GT:C | Base:B | RAG:B |
# [999] GT:D | Base:D | RAG:A | RAG Hurt
# [1000] GT:C | Base:D | RAG:D |
# [1001] GT:C | Base:A | RAG:A |
# [1002] GT:B | Base:B | RAG:B |
# [1003] GT:A | Base:D | RAG:D |
# [1004] GT:C | Base:D | RAG:D |
# [1005] GT:A | Base:A | RAG:A |
# [1006] GT:D | Base:A | RAG:A |
# [1007] GT:A | Base:C | RAG:C |
# [1008] GT:A | Base:C | RAG:C |
# [1009] GT:D | Base:D | RAG:D |
# [1010] GT:D | Base:D | RAG:D |
# [1011] GT:A | Base:D | RAG:D |
# [1012] GT:C | Base:A | RAG:A |
# [1013] GT:D | Base:A | RAG:D | RAG Fix
# [1014] GT:C | Base:B | RAG:B |
# [1015] GT:A | Base:B | RAG:B |
# [1016] GT:A | Base:A | RAG:A |
# [1017] GT:C | Base:D | RAG:D |
# [1018] GT:A | Base:D | RAG:D |
# [1019] GT:D | Base:A | RAG:A |
# [1020] GT:C | Base:D | RAG:D |
# [1021] GT:A | Base:A | RAG:A |
# [1022] GT:A | Base:A | RAG:A |
# [1023] GT:C | Base:C | RAG:C |
# [1024] GT:B | Base:A | RAG:A |
# [1025] GT:A | Base:B | RAG:B |
# [1026] GT:C | Base:A | RAG:A |
# [1027] GT:A | Base:A | RAG:A |
# [1028] GT:D | Base:A | RAG:A |
# [1029] GT:C | Base:D | RAG:D |
# [1030] GT:B | Base:A | RAG:A |
# [1031] GT:A | Base:D | RAG:D |
# [1032] GT:C | Base:A | RAG:A |
# [1033] GT:B | Base:B | RAG:B |
# [1034] GT:A | Base:A | RAG:A |
# [1035] GT:A | Base:D | RAG:D |
# [1036] GT:C | Base:A | RAG:A |
# [1037] GT:C | Base:C | RAG:C |
# [1038] GT:D | Base:B | RAG:B |
# [1039] GT:C | Base:C | RAG:B | RAG Hurt
# [1040] GT:B | Base:D | RAG:D |
# [1041] GT:D | Base:D | RAG:D |
# [1042] GT:B | Base:C | RAG:C |
# [1043] GT:A | Base:D | RAG:D |
# [1044] GT:B | Base:B | RAG:B |
# [1045] GT:A | Base:B | RAG:B |
# [1046] GT:C | Base:B | RAG:B |
# [1047] GT:B | Base:A | RAG:A |
# [1048] GT:D | Base:D | RAG:D |
# [1049] GT:A | Base:B | RAG:B |
# [1050] GT:A | Base:B | RAG:B |
# [1051] GT:C | Base:A | RAG:A |
# [1052] GT:D | Base:B | RAG:B |
# [1053] GT:C | Base:B | RAG:B |
# [1054] GT:A | Base:C | RAG:C |
# [1055] GT:A | Base:A | RAG:A |
# [1056] GT:B | Base:D | RAG:D |
# [1057] GT:D | Base:B | RAG:B |
# [1058] GT:A | Base:D | RAG:D |
# [1059] GT:B | Base:D | RAG:D |
# [1060] GT:C | Base:D | RAG:D |
# [1061] GT:B | Base:C | RAG:C |
# [1062] GT:C | Base:D | RAG:D |
# [1063] GT:D | Base:A | RAG:A |
# [1064] GT:D | Base:A | RAG:A |
# [1065] GT:B | Base:A | RAG:A |
# [1066] GT:A | Base:D | RAG:D |
# [1067] GT:C | Base:D | RAG:D |
# [1068] GT:A | Base:D | RAG:D |
# [1069] GT:A | Base:B | RAG:B |
# [1070] GT:C | Base:D | RAG:D |
# [1071] GT:A | Base:A | RAG:A |
# [1072] GT:D | Base:C | RAG:C |
# [1073] GT:C | Base:B | RAG:B |
# [1074] GT:D | Base:C | RAG:C |
# [1075] GT:B | Base:D | RAG:D |
# [1076] GT:D | Base:A | RAG:A |
# [1077] GT:C | Base:D | RAG:B |
# [1078] GT:C | Base:C | RAG:C |
# [1079] GT:B | Base:D | RAG:D |
# [1080] GT:B | Base:D | RAG:D |
# [1081] GT:C | Base:C | RAG:C |
# [1082] GT:A | Base:D | RAG:D |
# [1083] GT:D | Base:C | RAG:C |
# [1084] GT:A | Base:A | RAG:A |
# [1085] GT:B | Base:B | RAG:B |
# [1086] GT:C | Base:C | RAG:C |
# [1087] GT:A | Base:D | RAG:D |
# [1088] GT:B | Base:A | RAG:A |
# [1089] GT:B | Base:A | RAG:A |
# [1090] GT:D | Base:A | RAG:A |
# [1091] GT:C | Base:B | RAG:B |
# [1092] GT:B | Base:A | RAG:A |
# [1093] GT:D | Base:C | RAG:C |
# [1094] GT:B | Base:A | RAG:A |
# [1095] GT:A | Base:C | RAG:C |
# [1096] GT:A | Base:D | RAG:D |
# [1097] GT:D | Base:A | RAG:A |
# [1098] GT:D | Base:D | RAG:D |
# [1099] GT:C | Base:A | RAG:B |
# [1100] GT:B | Base:B | RAG:B |
# [1101] GT:D | Base:A | RAG:A |
# [1102] GT:A | Base:A | RAG:A |
# [1103] GT:D | Base:D | RAG:D |
# [1104] GT:A | Base:A | RAG:A |
# [1105] GT:A | Base:B | RAG:B |
# [1106] GT:D | Base:B | RAG:B |
# [1107] GT:B | Base:A | RAG:A |
# [1108] GT:B | Base:B | RAG:B |
# [1109] GT:B | Base:A | RAG:A |
# [1110] GT:C | Base:B | RAG:B |
# [1111] GT:B | Base:D | RAG:D |
# [1112] GT:D | Base:A | RAG:A |
# [1113] GT:C | Base:C | RAG:C |
# [1114] GT:D | Base:B | RAG:B |
# [1115] GT:A | Base:D | RAG:D |
# [1116] GT:D | Base:A | RAG:A |
# [1117] GT:C | Base:A | RAG:B |
# [1118] GT:A | Base:C | RAG:C |
# [1119] GT:C | Base:D | RAG:D |
# [1120] GT:A | Base:C | RAG:C |
# [1121] GT:D | Base:B | RAG:B |
# [1122] GT:D | Base:D | RAG:D |
# [1123] GT:A | Base:A | RAG:A |
# [1124] GT:C | Base:C | RAG:C |
# [1125] GT:C | Base:C | RAG:C |
# [1126] GT:B | Base:A | RAG:A |
# [1127] GT:A | Base:C | RAG:C |
# [1128] GT:C | Base:B | RAG:B |
# [1129] GT:B | Base:C | RAG:C |
# [1130] GT:B | Base:B | RAG:B |
# [1131] GT:B | Base:C | RAG:C |
# [1132] GT:B | Base:D | RAG:D |
# [1133] GT:C | Base:D | RAG:D |
# [1134] GT:B | Base:B | RAG:B |
# [1135] GT:B | Base:C | RAG:C |
# [1136] GT:B | Base:D | RAG:D |
# [1137] GT:D | Base:D | RAG:D |
# [1138] GT:B | Base:A | RAG:A |
# [1139] GT:A | Base:B | RAG:B |
# [1140] GT:D | Base:D | RAG:D |
# [1141] GT:B | Base:C | RAG:C |
# [1142] GT:A | Base:A | RAG:A |
# [1143] GT:C | Base:D | RAG:D |
# [1144] GT:C | Base:C | RAG:C |
# [1145] GT:A | Base:C | RAG:C |
# [1146] GT:C | Base:C | RAG:C |
# [1147] GT:B | Base:A | RAG:A |
# [1148] GT:C | Base:B | RAG:B |
# [1149] GT:A | Base:B | RAG:B |
# [1150] GT:C | Base:D | RAG:D |
# [1151] GT:B | Base:D | RAG:D |
# [1152] GT:B | Base:B | RAG:B |
# [1153] GT:B | Base:D | RAG:D |
# [1154] GT:A | Base:D | RAG:D |
# [1155] GT:A | Base:D | RAG:A | RAG Fix
# [1156] GT:D | Base:D | RAG:D |
# [1157] GT:A | Base:A | RAG:A |
# [1158] GT:B | Base:D | RAG:D |
# [1159] GT:A | Base:B | RAG:B |
# [1160] GT:D | Base:A | RAG:A |
# [1161] GT:C | Base:C | RAG:C |
# [1162] GT:C | Base:D | RAG:C | RAG Fix
# [1163] GT:B | Base:C | RAG:C |
# [1164] GT:A | Base:A | RAG:A |
# [1165] GT:B | Base:D | RAG:D |
# [1166] GT:C | Base:B | RAG:B |
# [1167] GT:A | Base:C | RAG:C |
# [1168] GT:B | Base:B | RAG:B |
# [1169] GT:A | Base:C | RAG:C |
# [1170] GT:D | Base:D | RAG:D |
# [1171] GT:B | Base:D | RAG:D |
# [1172] GT:A | Base:C | RAG:D |
# [1173] GT:D | Base:A | RAG:A |
# [1174] GT:C | Base:D | RAG:D |
# [1175] GT:C | Base:A | RAG:A |
# [1176] GT:C | Base:D | RAG:D |
# [1177] GT:A | Base:A | RAG:A |
# [1178] GT:C | Base:D | RAG:D |
# [1179] GT:C | Base:B | RAG:B |
# [1180] GT:B | Base:D | RAG:D |
# [1181] GT:C | Base:B | RAG:D |
# [1182] GT:B | Base:B | RAG:B |
# [1183] GT:B | Base:B | RAG:B |
# [1184] GT:C | Base:A | RAG:A |
# [1185] GT:B | Base:D | RAG:D |
# [1186] GT:C | Base:D | RAG:D |
# [1187] GT:C | Base:B | RAG:B |
# [1188] GT:B | Base:A | RAG:A |
# [1189] GT:B | Base:A | RAG:A |
# [1190] GT:A | Base:B | RAG:B |
# [1191] GT:A | Base:B | RAG:C |
# [1192] GT:B | Base:C | RAG:C |
# [1193] GT:D | Base:D | RAG:D |
# [1194] GT:C | Base:D | RAG:D |
# [1195] GT:B | Base:C | RAG:A |
# [1196] GT:A | Base:B | RAG:B |
# [1197] GT:D | Base:C | RAG:C |
# [1198] GT:C | Base:A | RAG:A |
# [1199] GT:C | Base:C | RAG:C |
# [1200] GT:D | Base:C | RAG:C |
# [1201] GT:C | Base:B | RAG:B |
# [1202] GT:D | Base:A | RAG:A |
# [1203] GT:B | Base:B | RAG:B |
# [1204] GT:A | Base:D | RAG:D |
# [1205] GT:B | Base:C | RAG:C |
# [1206] GT:C | Base:A | RAG:A |
# [1207] GT:A | Base:A | RAG:A |
# [1208] GT:D | Base:D | RAG:D |
# [1209] GT:D | Base:A | RAG:A |
# [1210] GT:B | Base:C | RAG:C |
# [1211] GT:B | Base:D | RAG:D |
# [1212] GT:A | Base:C | RAG:C |
# [1213] GT:D | Base:B | RAG:B |
# [1214] GT:C | Base:D | RAG:D |
# [1215] GT:A | Base:C | RAG:D |
# [1216] GT:A | Base:B | RAG:C |
# [1217] GT:B | Base:A | RAG:A |
# [1218] GT:B | Base:C | RAG:C |
# [1219] GT:A | Base:C | RAG:C |
# [1220] GT:D | Base:B | RAG:B |
# [1221] GT:B | Base:B | RAG:B |
# [1222] GT:D | Base:C | RAG:C |
# [1223] GT:B | Base:A | RAG:A |
# [1224] GT:B | Base:A | RAG:A |
# [1225] GT:A | Base:A | RAG:A |
# [1226] GT:A | Base:D | RAG:D |
# [1227] GT:D | Base:B | RAG:B |
# [1228] GT:B | Base:D | RAG:D |
# [1229] GT:A | Base:B | RAG:B |
# [1230] GT:A | Base:A | RAG:A |
# [1231] GT:B | Base:C | RAG:C |
# [1232] GT:D | Base:C | RAG:C |
# [1233] GT:A | Base:C | RAG:C |
# [1234] GT:B | Base:A | RAG:A |
# [1235] GT:D | Base:D | RAG:D |
# [1236] GT:D | Base:C | RAG:C |
# [1237] GT:A | Base:B | RAG:B |
# [1238] GT:C | Base:C | RAG:B | RAG Hurt
# [1239] GT:D | Base:A | RAG:A |
# [1240] GT:A | Base:A | RAG:A |
# [1241] GT:C | Base:D | RAG:D |
# [1242] GT:C | Base:A | RAG:A |
# [1243] GT:B | Base:D | RAG:D |
# [1244] GT:A | Base:D | RAG:D |
# [1245] GT:B | Base:D | RAG:D |
# [1246] GT:B | Base:C | RAG:C |
# [1247] GT:D | Base:D | RAG:D |
# [1248] GT:D | Base:D | RAG:D |
# [1249] GT:B | Base:D | RAG:D |
# [1250] GT:D | Base:A | RAG:B |
# [1251] GT:B | Base:A | RAG:A |
# [1252] GT:C | Base:C | RAG:C |
# [1253] GT:B | Base:A | RAG:A |
# [1254] GT:C | Base:B | RAG:A |
# [1255] GT:B | Base:B | RAG:B |
# [1256] GT:B | Base:C | RAG:C |
# [1257] GT:C | Base:D | RAG:A |
# [1258] GT:B | Base:A | RAG:A |
# [1259] GT:A | Base:A | RAG:A |
# [1260] GT:B | Base:C | RAG:C |
# [1261] GT:B | Base:C | RAG:C |
# [1262] GT:C | Base:C | RAG:C |
# [1263] GT:D | Base:D | RAG:D |
# [1264] GT:C | Base:A | RAG:A |
# [1265] GT:D | Base:D | RAG:D |
# [1266] GT:B | Base:B | RAG:B |
# [1267] GT:A | Base:C | RAG:D |
# [1268] GT:A | Base:B | RAG:B |
# [1269] GT:C | Base:A | RAG:A |
# [1270] GT:D | Base:D | RAG:D |
# [1271] GT:A | Base:C | RAG:C |
# [1272] GT:C | Base:B | RAG:B |
# [1273] GT:C | Base:B | RAG:B |
# [1274] GT:A | Base:C | RAG:B |
# [1275] GT:A | Base:C | RAG:C |
# [1276] GT:D | Base:B | RAG:B |
# [1277] GT:B | Base:D | RAG:A |
# [1278] GT:B | Base:C | RAG:C |
# [1279] GT:D | Base:B | RAG:B |
# [1280] GT:A | Base:A | RAG:A |
# [1281] GT:A | Base:D | RAG:D |
# [1282] GT:D | Base:B | RAG:B |
# [1283] GT:D | Base:A | RAG:A |
# [1284] GT:A | Base:A | RAG:A |
# [1285] GT:C | Base:C | RAG:C |
# [1286] GT:B | Base:D | RAG:D |
# [1287] GT:C | Base:C | RAG:C |
# [1288] GT:A | Base:D | RAG:C |
# [1289] GT:B | Base:A | RAG:A |
# [1290] GT:C | Base:B | RAG:B |
# [1291] GT:D | Base:C | RAG:C |
# [1292] GT:B | Base:D | RAG:D |
# [1293] GT:B | Base:B | RAG:B |
# [1294] GT:B | Base:A | RAG:A |
# [1295] GT:B | Base:C | RAG:C |
# [1296] GT:A | Base:D | RAG:D |
# [1297] GT:C | Base:D | RAG:B |
# [1298] GT:A | Base:D | RAG:D |
# [1299] GT:C | Base:C | RAG:C |
# [1300] GT:C | Base:C | RAG:C |
# [1301] GT:A | Base:A | RAG:A |
# [1302] GT:C | Base:D | RAG:D |
# [1303] GT:D | Base:D | RAG:D |
# [1304] GT:D | Base:B | RAG:B |
# [1305] GT:C | Base:A | RAG:C | RAG Fix
# [1306] GT:D | Base:B | RAG:B |
# [1307] GT:D | Base:B | RAG:B |
# [1308] GT:B | Base:A | RAG:A |
# [1309] GT:A | Base:D | RAG:D |
# [1310] GT:A | Base:D | RAG:D |
# [1311] GT:B | Base:B | RAG:B |
# [1312] GT:A | Base:D | RAG:B |
# [1313] GT:D | Base:D | RAG:D |
# [1314] GT:B | Base:A | RAG:A |
# [1315] GT:A | Base:B | RAG:B |
# [1316] GT:B | Base:B | RAG:B |
# [1317] GT:C | Base:D | RAG:D |
# [1318] GT:A | Base:B | RAG:B |
# [1319] GT:D | Base:D | RAG:D |
# [1320] GT:D | Base:A | RAG:A |
# [1321] GT:A | Base:A | RAG:A |
# [1322] GT:D | Base:B | RAG:B |
# [1323] GT:A | Base:D | RAG:D |
# [1324] GT:A | Base:A | RAG:A |
# [1325] GT:A | Base:B | RAG:B |
# [1326] GT:B | Base:B | RAG:B |
# [1327] GT:C | Base:D | RAG:D |
# [1328] GT:A | Base:B | RAG:B |
# [1329] GT:B | Base:D | RAG:D |
# [1330] GT:D | Base:C | RAG:C |
# [1331] GT:B | Base:C | RAG:D |
# [1332] GT:A | Base:A | RAG:A |
# [1333] GT:D | Base:D | RAG:D |
# [1334] GT:D | Base:D | RAG:D |
# [1335] GT:B | Base:B | RAG:B |
# [1336] GT:B | Base:D | RAG:D |
# [1337] GT:D | Base:B | RAG:B |
# [1338] GT:D | Base:D | RAG:D |
# [1339] GT:B | Base:B | RAG:B |
# [1340] GT:D | Base:B | RAG:B |
# [1341] GT:A | Base:A | RAG:A |
# [1342] GT:A | Base:B | RAG:B |
# [1343] GT:C | Base:C | RAG:C |
# [1344] GT:B | Base:A | RAG:A |
# [1345] GT:C | Base:A | RAG:A |
# [1346] GT:A | Base:B | RAG:B |
# [1347] GT:C | Base:D | RAG:D |
# [1348] GT:B | Base:A | RAG:A |
# [1349] GT:D | Base:A | RAG:A |
# [1350] GT:D | Base:C | RAG:C |
# [1351] GT:D | Base:A | RAG:A |
# [1352] GT:C | Base:A | RAG:A |
# [1353] GT:C | Base:C | RAG:C |
# [1354] GT:B | Base:A | RAG:A |
# [1355] GT:A | Base:A | RAG:A |
# [1356] GT:D | Base:D | RAG:D |
# [1357] GT:C | Base:D | RAG:D |
# [1358] GT:A | Base:B | RAG:B |
# [1359] GT:B | Base:D | RAG:D |
# [1360] GT:A | Base:C | RAG:C |
# [1361] GT:C | Base:D | RAG:D |
# [1362] GT:C | Base:C | RAG:C |
# [1363] GT:D | Base:D | RAG:D |
# [1364] GT:A | Base:B | RAG:B |
# [1365] GT:A | Base:A | RAG:A |
# [1366] GT:A | Base:C | RAG:C |
# [1367] GT:C | Base:A | RAG:A |
# [1368] GT:B | Base:A | RAG:A |
# [1369] GT:B | Base:C | RAG:C |
# [1370] GT:A | Base:A | RAG:A |
# [1371] GT:C | Base:A | RAG:A |
# [1372] GT:B | Base:D | RAG:D |
# [1373] GT:D | Base:C | RAG:C |
# [1374] GT:B | Base:B | RAG:B |
# [1375] GT:C | Base:C | RAG:C |
# [1376] GT:D | Base:A | RAG:A |
# [1377] GT:D | Base:D | RAG:D |
# [1378] GT:D | Base:A | RAG:A |
# [1379] GT:D | Base:C | RAG:C |
# [1380] GT:A | Base:D | RAG:D |
# [1381] GT:B | Base:A | RAG:A |
# [1382] GT:A | Base:D | RAG:D |
# [1383] GT:B | Base:C | RAG:C |
# [1384] GT:D | Base:B | RAG:B |
# [1385] GT:D | Base:D | RAG:D |
# [1386] GT:D | Base:C | RAG:C |
# [1387] GT:D | Base:B | RAG:B |
# [1388] GT:B | Base:D | RAG:D |
# [1389] GT:C | Base:D | RAG:C | RAG Fix
# [1390] GT:A | Base:C | RAG:C |
# [1391] GT:A | Base:B | RAG:B |
# [1392] GT:A | Base:D | RAG:D |
# [1393] GT:A | Base:B | RAG:B |
# [1394] GT:D | Base:A | RAG:A |
# [1395] GT:B | Base:A | RAG:A |
# [1396] GT:C | Base:B | RAG:B |
# [1397] GT:C | Base:D | RAG:D |
# [1398] GT:D | Base:C | RAG:C |
# [1399] GT:A | Base:A | RAG:A |
# [1400] GT:D | Base:A | RAG:A |
# [1401] GT:C | Base:A | RAG:A |
# [1402] GT:C | Base:D | RAG:D |
# [1403] GT:B | Base:C | RAG:C |
# [1404] GT:C | Base:A | RAG:A |
# [1405] GT:D | Base:D | RAG:D |
# [1406] GT:B | Base:A | RAG:A |
# [1407] GT:A | Base:D | RAG:D |
# [1408] GT:A | Base:D | RAG:D |
# [1409] GT:D | Base:D | RAG:D |
# [1410] GT:C | Base:B | RAG:B |
# [1411] GT:A | Base:D | RAG:D |
# [1412] GT:A | Base:C | RAG:C |
# [1413] GT:A | Base:A | RAG:A |
# [1414] GT:B | Base:B | RAG:B |
# [1415] GT:C | Base:D | RAG:D |
# [1416] GT:B | Base:D | RAG:D |
# [1417] GT:B | Base:D | RAG:D |
# [1418] GT:C | Base:D | RAG:D |
# [1419] GT:B | Base:A | RAG:A |
# [1420] GT:A | Base:C | RAG:C |
# [1421] GT:D | Base:D | RAG:D |
# [1422] GT:C | Base:C | RAG:C |
# [1423] GT:B | Base:A | RAG:A |
# [1424] GT:B | Base:A | RAG:A |
# [1425] GT:D | Base:C | RAG:C |
# [1426] GT:B | Base:C | RAG:C |
# [1427] GT:C | Base:B | RAG:B |
# [1428] GT:A | Base:A | RAG:A |
# [1429] GT:A | Base:B | RAG:B |
# [1430] GT:C | Base:B | RAG:B |
# [1431] GT:D | Base:A | RAG:A |
# [1432] GT:D | Base:B | RAG:B |
# [1433] GT:D | Base:D | RAG:D |
# [1434] GT:D | Base:B | RAG:B |
# [1435] GT:A | Base:C | RAG:C |
# [1436] GT:A | Base:D | RAG:D |
# [1437] GT:D | Base:B | RAG:B |
# [1438] GT:A | Base:A | RAG:A |
# [1439] GT:B | Base:A | RAG:A |
# [1440] GT:A | Base:D | RAG:D |
# [1441] GT:D | Base:A | RAG:A |
# [1442] GT:C | Base:C | RAG:C |
# [1443] GT:B | Base:D | RAG:D |
# [1444] GT:A | Base:C | RAG:C |
# [1445] GT:B | Base:D | RAG:D |
# [1446] GT:B | Base:A | RAG:A |
# [1447] GT:D | Base:B | RAG:B |
# [1448] GT:A | Base:D | RAG:D |
# [1449] GT:B | Base:B | RAG:B |
# [1450] GT:A | Base:D | RAG:D |
# [1451] GT:A | Base:A | RAG:A |
# [1452] GT:A | Base:C | RAG:C |
# [1453] GT:A | Base:D | RAG:D |
# [1454] GT:C | Base:A | RAG:A |
# [1455] GT:A | Base:B | RAG:B |
# [1456] GT:B | Base:D | RAG:D |
# [1457] GT:B | Base:B | RAG:B |
# [1458] GT:C | Base:B | RAG:B |
# [1459] GT:A | Base:A | RAG:A |
# [1460] GT:C | Base:B | RAG:A |
# [1461] GT:C | Base:B | RAG:B |
# [1462] GT:A | Base:D | RAG:D |
# [1463] GT:D | Base:D | RAG:D |
# [1464] GT:C | Base:C | RAG:C |
# [1465] GT:A | Base:B | RAG:B |
# [1466] GT:B | Base:C | RAG:C |
# [1467] GT:B | Base:B | RAG:B |
# [1468] GT:D | Base:D | RAG:D |
# [1469] GT:B | Base:D | RAG:A |
# [1470] GT:B | Base:A | RAG:A |
# [1471] GT:C | Base:D | RAG:D |
# [1472] GT:D | Base:C | RAG:C |
# [1473] GT:C | Base:D | RAG:D |
# [1474] GT:D | Base:C | RAG:C |
# [1475] GT:A | Base:B | RAG:B |
# [1476] GT:A | Base:B | RAG:B |
# [1477] GT:C | Base:B | RAG:A |
# [1478] GT:B | Base:C | RAG:C |
# [1479] GT:A | Base:D | RAG:D |
# [1480] GT:B | Base:B | RAG:B |
# [1481] GT:C | Base:B | RAG:B |
# [1482] GT:D | Base:B | RAG:B |
# [1483] GT:D | Base:A | RAG:A |
# [1484] GT:D | Base:D | RAG:D |
# [1485] GT:C | Base:B | RAG:B |
# [1486] GT:C | Base:D | RAG:D |
# [1487] GT:C | Base:C | RAG:C |
# [1488] GT:A | Base:C | RAG:C |
# [1489] GT:B | Base:B | RAG:B |
# [1490] GT:B | Base:B | RAG:B |
# [1491] GT:A | Base:D | RAG:D |
# [1492] GT:D | Base:D | RAG:C | RAG Hurt
# [1493] GT:A | Base:C | RAG:C |
# [1494] GT:C | Base:C | RAG:C |
# [1495] GT:C | Base:A | RAG:A |
# [1496] GT:A | Base:A | RAG:A |
# [1497] GT:A | Base:A | RAG:A |
# [1498] GT:B | Base:D | RAG:D |
# [1499] GT:A | Base:D | RAG:D |
# [1500] GT:B | Base:C | RAG:C |
# [1501] GT:D | Base:B | RAG:C |
# [1502] GT:A | Base:D | RAG:D |
# [1503] GT:B | Base:C | RAG:C |
# [1504] GT:A | Base:D | RAG:D |
# [1505] GT:B | Base:D | RAG:D |
# [1506] GT:C | Base:D | RAG:B |
# [1507] GT:A | Base:D | RAG:D |
# [1508] GT:A | Base:A | RAG:A |
# [1509] GT:C | Base:D | RAG:D |
# [1510] GT:A | Base:C | RAG:C |
# [1511] GT:D | Base:A | RAG:A |
# [1512] GT:B | Base:A | RAG:A |
# [1513] GT:D | Base:A | RAG:A |
# [1514] GT:A | Base:D | RAG:D |
# [1515] GT:A | Base:A | RAG:A |
# [1516] GT:D | Base:A | RAG:A |
# [1517] GT:C | Base:A | RAG:A |
# [1518] GT:B | Base:A | RAG:A |
# ...
# [3693] GT:C | Base:A | RAG:A |
# [3694] GT:C | Base:D | RAG:D |
# [3695] GT:A | Base:C | RAG:A | RAG Fix
# [3696] GT:A | Base:B | RAG:B |
# [3697] GT:B | Base:C | RAG:C |
# [3698] GT:A | Base:B | RAG:B |
# [3699] GT:B | Base:B | RAG:B |
# [3700] GT:A | Base:A | RAG:A |
# [3701] GT:B | Base:A | RAG:A |
# [3702] GT:A | Base:D | RAG:D |
# [3703] GT:D | Base:B | RAG:B |
# [3704] GT:A | Base:A | RAG:A |
# [3705] GT:C | Base:D | RAG:D |
# [3706] GT:C | Base:A | RAG:A |
# [3707] GT:C | Base:B | RAG:B |
# [3708] GT:D | Base:B | RAG:B |
# [3709] GT:C | Base:A | RAG:A |
# [3710] GT:C | Base:D | RAG:D |
# [3711] GT:D | Base:B | RAG:B |
# [3712] GT:C | Base:A | RAG:A |
# [3713] GT:B | Base:A | RAG:A |
# [3714] GT:C | Base:D | RAG:D |
# [3715] GT:B | Base:C | RAG:C |
# [3716] GT:C | Base:A | RAG:A |
# [3717] GT:B | Base:A | RAG:A |
# [3718] GT:A | Base:B | RAG:B |
# [3719] GT:B | Base:C | RAG:C |
# [3720] GT:D | Base:D | RAG:D |
# [3721] GT:A | Base:A | RAG:A |
# [3722] GT:D | Base:C | RAG:C |
# [3723] GT:A | Base:D | RAG:D |
# [3724] GT:B | Base:B | RAG:A | RAG Hurt
# [3725] GT:A | Base:C | RAG:C |
# [3726] GT:C | Base:A | RAG:B |
# [3727] GT:A | Base:C | RAG:C |
# [3728] GT:B | Base:C | RAG:C |
# [3729] GT:D | Base:A | RAG:A |
# [3730] GT:A | Base:D | RAG:D |
# [3731] GT:C | Base:D | RAG:D |
# [3732] GT:D | Base:C | RAG:C |
# [3733] GT:D | Base:C | RAG:C |
# [3734] GT:A | Base:A | RAG:A |
# [3735] GT:B | Base:D | RAG:D |
# [3736] GT:C | Base:A | RAG:A |
# [3737] GT:C | Base:B | RAG:B |
# [3738] GT:A | Base:B | RAG:B |
# [3739] GT:C | Base:C | RAG:C |
# [3740] GT:C | Base:C | RAG:C |
# [3741] GT:C | Base:A | RAG:A |
# [3742] GT:D | Base:C | RAG:C |
# [3743] GT:D | Base:D | RAG:D |
# [3744] GT:B | Base:B | RAG:B |
# [3745] GT:C | Base:A | RAG:A |
# [3746] GT:A | Base:C | RAG:C |
# [3747] GT:C | Base:A | RAG:A |
# [3748] GT:B | Base:C | RAG:C |
# [3749] GT:B | Base:B | RAG:B |
# [3750] GT:B | Base:B | RAG:B |
# [3751] GT:A | Base:D | RAG:D |
# [3752] GT:A | Base:A | RAG:A |
# [3753] GT:A | Base:D | RAG:D |
# [3754] GT:C | Base:C | RAG:C |
# [3755] GT:C | Base:C | RAG:C |
# [3756] GT:B | Base:D | RAG:D |
# [3757] GT:B | Base:A | RAG:A |
# [3758] GT:B | Base:D | RAG:D |
# [3759] GT:D | Base:A | RAG:A |
# [3760] GT:A | Base:A | RAG:A |
# [3761] GT:D | Base:C | RAG:C |
# [3762] GT:A | Base:B | RAG:B |
# [3763] GT:A | Base:B | RAG:A | RAG Fix
# [3764] GT:B | Base:B | RAG:B |
# [3765] GT:A | Base:C | RAG:C |
# [3766] GT:D | Base:B | RAG:B |
# [3767] GT:C | Base:A | RAG:A |
# [3768] GT:B | Base:C | RAG:C |
# [3769] GT:D | Base:B | RAG:B |
# [3770] GT:D | Base:A | RAG:A |
# [3771] GT:D | Base:C | RAG:C |
# [3772] GT:D | Base:C | RAG:C |
# [3773] GT:B | Base:A | RAG:A |
# [3774] GT:B | Base:D | RAG:D |
# [3775] GT:C | Base:B | RAG:B |
# [3776] GT:C | Base:A | RAG:A |
# [3777] GT:A | Base:C | RAG:C |
# [3778] GT:B | Base:C | RAG:B | RAG Fix
# [3779] GT:D | Base:B | RAG:B |
# [3780] GT:B | Base:C | RAG:C |
# [3781] GT:C | Base:A | RAG:A |
# [3782] GT:A | Base:B | RAG:B |
# [3783] GT:C | Base:A | RAG:A |
# [3784] GT:C | Base:D | RAG:A |
# [3785] GT:D | Base:C | RAG:C |
# [3786] GT:A | Base:C | RAG:C |
# [3787] GT:B | Base:A | RAG:A |
# [3788] GT:B | Base:D | RAG:A |
# [3789] GT:B | Base:B | RAG:B |
# [3790] GT:D | Base:B | RAG:B |
# [3791] GT:A | Base:B | RAG:B |
# [3792] GT:A | Base:C | RAG:C |
# [3793] GT:B | Base:B | RAG:B |
# [3794] GT:C | Base:C | RAG:C |
# [3795] GT:D | Base:B | RAG:B |
# [3796] GT:A | Base:B | RAG:B |
# [3797] GT:A | Base:A | RAG:A |
# [3798] GT:A | Base:B | RAG:B |
# [3799] GT:B | Base:B | RAG:B |
# [3800] GT:A | Base:A | RAG:A |
# [3801] GT:C | Base:A | RAG:A |
# [3802] GT:B | Base:D | RAG:D |
# [3803] GT:A | Base:A | RAG:A |
# [3804] GT:A | Base:A | RAG:A |
# [3805] GT:A | Base:D | RAG:D |
# [3806] GT:A | Base:A | RAG:A |
# [3807] GT:B | Base:B | RAG:B |
# [3808] GT:A | Base:A | RAG:A |
# [3809] GT:D | Base:A | RAG:A |
# [3810] GT:A | Base:C | RAG:C |
# [3811] GT:D | Base:D | RAG:D |
# [3812] GT:C | Base:B | RAG:B |
# [3813] GT:D | Base:B | RAG:B |
# [3814] GT:D | Base:C | RAG:C |
# [3815] GT:D | Base:C | RAG:C |
# [3816] GT:B | Base:D | RAG:D |
# [3817] GT:D | Base:A | RAG:A |
# [3818] GT:B | Base:D | RAG:D |
# [3819] GT:A | Base:A | RAG:A |
# [3820] GT:C | Base:D | RAG:D |
# [3821] GT:C | Base:B | RAG:B |
# [3822] GT:D | Base:D | RAG:D |
# [3823] GT:B | Base:C | RAG:C |
# [3824] GT:A | Base:C | RAG:C |
# [3825] GT:C | Base:B | RAG:B |
# [3826] GT:B | Base:D | RAG:D |
# [3827] GT:B | Base:B | RAG:C | RAG Hurt
# [3828] GT:A | Base:C | RAG:C |
# [3829] GT:A | Base:D | RAG:D |
# [3830] GT:D | Base:C | RAG:B |
# [3831] GT:C | Base:D | RAG:D |
# [3832] GT:C | Base:A | RAG:A |
# [3833] GT:A | Base:C | RAG:C |
# [3834] GT:D | Base:A | RAG:A |
# [3835] GT:A | Base:B | RAG:B |
# [3836] GT:A | Base:D | RAG:D |
# [3837] GT:A | Base:A | RAG:A |
# [3838] GT:D | Base:C | RAG:C |
# [3839] GT:A | Base:B | RAG:B |
# [3840] GT:C | Base:C | RAG:C |
# [3841] GT:B | Base:C | RAG:C |
# [3842] GT:A | Base:C | RAG:C |
# [3843] GT:B | Base:D | RAG:D |
# [3844] GT:C | Base:D | RAG:D |
# [3845] GT:A | Base:D | RAG:D |
# [3846] GT:C | Base:B | RAG:B |
# [3847] GT:D | Base:D | RAG:D |
# [3848] GT:D | Base:C | RAG:C |
# [3849] GT:B | Base:C | RAG:C |
# [3850] GT:C | Base:C | RAG:C |
# [3851] GT:A | Base:D | RAG:D |
# [3852] GT:C | Base:C | RAG:C |
# [3853] GT:A | Base:B | RAG:B |
# [3854] GT:A | Base:D | RAG:D |
# [3855] GT:B | Base:C | RAG:C |
# [3856] GT:A | Base:B | RAG:B |
# [3857] GT:B | Base:A | RAG:A |
# [3858] GT:A | Base:A | RAG:A |
# [3859] GT:D | Base:D | RAG:D |
# [3860] GT:C | Base:B | RAG:B |
# [3861] GT:C | Base:B | RAG:B |
# [3862] GT:D | Base:B | RAG:B |
# [3863] GT:A | Base:A | RAG:D | RAG Hurt
# [3864] GT:A | Base:C | RAG:C |
# [3865] GT:C | Base:D | RAG:D |
# [3866] GT:B | Base:A | RAG:C |
# [3867] GT:C | Base:A | RAG:A |
# [3868] GT:A | Base:A | RAG:A |
# [3869] GT:B | Base:D | RAG:D |
# [3870] GT:B | Base:A | RAG:A |
# [3871] GT:D | Base:B | RAG:B |
# [3872] GT:C | Base:D | RAG:D |
# [3873] GT:C | Base:C | RAG:C |
# [3874] GT:D | Base:A | RAG:A |
# [3875] GT:D | Base:D | RAG:D |
# [3876] GT:A | Base:A | RAG:A |
# [3877] GT:B | Base:D | RAG:D |
# [3878] GT:B | Base:D | RAG:D |
# [3879] GT:C | Base:C | RAG:C |
# [3880] GT:D | Base:D | RAG:D |
# [3881] GT:D | Base:D | RAG:D |
# [3882] GT:A | Base:D | RAG:D |
# [3883] GT:A | Base:B | RAG:B |
# [3884] GT:A | Base:C | RAG:C |
# [3885] GT:C | Base:A | RAG:A |
# [3886] GT:A | Base:D | RAG:D |
# [3887] GT:A | Base:D | RAG:D |
# [3888] GT:A | Base:A | RAG:A |
# [3889] GT:B | Base:D | RAG:D |
# [3890] GT:B | Base:C | RAG:C |
# [3891] GT:D | Base:C | RAG:C |
# [3892] GT:C | Base:A | RAG:A |
# [3893] GT:B | Base:C | RAG:C |
# [3894] GT:B | Base:D | RAG:D |
# [3895] GT:A | Base:B | RAG:B |
# [3896] GT:A | Base:C | RAG:B |
# [3897] GT:A | Base:D | RAG:D |
# [3898] GT:C | Base:A | RAG:A |
# [3899] GT:D | Base:B | RAG:B |
# [3900] GT:B | Base:B | RAG:B |
# [3901] GT:D | Base:A | RAG:A |
# [3902] GT:B | Base:C | RAG:A |
# [3903] GT:C | Base:D | RAG:A |
# [3904] GT:B | Base:A | RAG:A |
# [3905] GT:A | Base:D | RAG:D |
# [3906] GT:B | Base:A | RAG:A |
# [3907] GT:C | Base:D | RAG:D |
# [3908] GT:C | Base:C | RAG:C |
# [3909] GT:B | Base:B | RAG:B |
# [3910] GT:C | Base:B | RAG:B |
# [3911] GT:C | Base:A | RAG:C | RAG Fix
# [3912] GT:C | Base:D | RAG:D |
# [3913] GT:A | Base:D | RAG:D |
# [3914] GT:D | Base:C | RAG:C |
# [3915] GT:A | Base:D | RAG:D |
# [3916] GT:B | Base:D | RAG:D |
# [3917] GT:A | Base:A | RAG:A |
# [3918] GT:C | Base:A | RAG:A |
# [3919] GT:C | Base:A | RAG:A |
# [3920] GT:A | Base:C | RAG:C |
# [3921] GT:D | Base:C | RAG:C |
# [3922] GT:A | Base:B | RAG:B |
# [3923] GT:A | Base:B | RAG:B |
# [3924] GT:A | Base:A | RAG:A |
# [3925] GT:B | Base:B | RAG:B |
# [3926] GT:C | Base:B | RAG:B |
# [3927] GT:A | Base:C | RAG:C |
# [3928] GT:A | Base:B | RAG:B |
# [3929] GT:A | Base:D | RAG:D |
# [3930] GT:A | Base:D | RAG:A | RAG Fix
# [3931] GT:A | Base:A | RAG:A |
# [3932] GT:D | Base:D | RAG:D |
# [3933] GT:C | Base:C | RAG:C |
# [3934] GT:C | Base:C | RAG:C |
# [3935] GT:C | Base:A | RAG:A |
# [3936] GT:A | Base:A | RAG:A |
# [3937] GT:A | Base:D | RAG:D |
# [3938] GT:D | Base:A | RAG:A |
# [3939] GT:A | Base:A | RAG:B | RAG Hurt
# [3940] GT:A | Base:A | RAG:A |
# [3941] GT:C | Base:D | RAG:D |
# [3942] GT:D | Base:C | RAG:C |
# [3943] GT:B | Base:C | RAG:C |
# [3944] GT:D | Base:C | RAG:C |
# [3945] GT:A | Base:B | RAG:B |
# [3946] GT:D | Base:D | RAG:D |
# [3947] GT:A | Base:D | RAG:D |
# [3948] GT:A | Base:C | RAG:C |
# [3949] GT:A | Base:D | RAG:D |
# [3950] GT:A | Base:A | RAG:A |
# [3951] GT:D | Base:D | RAG:D |
# [3952] GT:D | Base:A | RAG:A |
# [3953] GT:B | Base:C | RAG:C |
# [3954] GT:C | Base:C | RAG:A | RAG Hurt
# [3955] GT:D | Base:D | RAG:D |
# [3956] GT:A | Base:C | RAG:C |
# [3957] GT:A | Base:B | RAG:B |
# [3958] GT:B | Base:C | RAG:C |
# [3959] GT:A | Base:A | RAG:A |
# [3960] GT:D | Base:D | RAG:D |
# [3961] GT:B | Base:B | RAG:C | RAG Hurt
# [3962] GT:B | Base:A | RAG:A |
# [3963] GT:D | Base:B | RAG:A |
# [3964] GT:D | Base:A | RAG:A |
# [3965] GT:C | Base:D | RAG:D |
# [3966] GT:D | Base:A | RAG:A |
# [3967] GT:D | Base:D | RAG:D |
# [3968] GT:A | Base:A | RAG:D | RAG Hurt
# [3969] GT:A | Base:B | RAG:B |
# [3970] GT:B | Base:C | RAG:C |
# [3971] GT:D | Base:C | RAG:A |
# [3972] GT:B | Base:D | RAG:D |
# [3973] GT:A | Base:A | RAG:A |
# [3974] GT:B | Base:A | RAG:A |
# [3975] GT:C | Base:C | RAG:C |
# [3976] GT:C | Base:D | RAG:D |
# [3977] GT:A | Base:B | RAG:B |
# [3978] GT:B | Base:C | RAG:C |
# [3979] GT:A | Base:D | RAG:D |
# [3980] GT:A | Base:C | RAG:C |
# [3981] GT:B | Base:C | RAG:C |
# [3982] GT:B | Base:C | RAG:C |
# [3983] GT:C | Base:C | RAG:C |
# [3984] GT:C | Base:B | RAG:B |
# [3985] GT:C | Base:A | RAG:A |
# [3986] GT:C | Base:B | RAG:B |
# [3987] GT:D | Base:D | RAG:D |
# [3988] GT:A | Base:B | RAG:B |
# [3989] GT:A | Base:A | RAG:A |
# [3990] GT:A | Base:C | RAG:C |
# [3991] GT:D | Base:A | RAG:A |
# [3992] GT:C | Base:D | RAG:D |
# [3993] GT:B | Base:B | RAG:B |
# [3994] GT:A | Base:C | RAG:C |
# [3995] GT:B | Base:B | RAG:C | RAG Hurt
# [3996] GT:C | Base:D | RAG:D |
# [3997] GT:A | Base:D | RAG:D |
# [3998] GT:B | Base:A | RAG:A |
# [3999] GT:D | Base:D | RAG:D |
# [4000] GT:D | Base:A | RAG:A |
# [4001] GT:A | Base:D | RAG:D |
# [4002] GT:D | Base:A | RAG:A |
# [4003] GT:D | Base:B | RAG:B |
# [4004] GT:B | Base:C | RAG:C |
# [4005] GT:A | Base:C | RAG:C |
# [4006] GT:A | Base:A | RAG:A |
# [4007] GT:A | Base:C | RAG:C |
# [4008] GT:B | Base:D | RAG:D |
# [4009] GT:C | Base:D | RAG:D |
# [4010] GT:B | Base:D | RAG:D |
# [4011] GT:A | Base:D | RAG:D |
# [4012] GT:A | Base:A | RAG:B | RAG Hurt
# [4013] GT:D | Base:C | RAG:C |
# [4014] GT:C | Base:B | RAG:B |
# [4015] GT:B | Base:D | RAG:B | RAG Fix
# [4016] GT:B | Base:D | RAG:D |
# [4017] GT:A | Base:C | RAG:C |
# [4018] GT:A | Base:D | RAG:D |
# [4019] GT:C | Base:B | RAG:B |
# [4020] GT:B | Base:A | RAG:A |
# [4021] GT:D | Base:B | RAG:B |
# [4022] GT:C | Base:C | RAG:C |
# [4023] GT:D | Base:D | RAG:D |
# [4024] GT:D | Base:C | RAG:C |
# [4025] GT:A | Base:A | RAG:A |
# [4026] GT:B | Base:B | RAG:B |
# [4027] GT:B | Base:A | RAG:D |
# [4028] GT:D | Base:C | RAG:C |
# [4029] GT:C | Base:B | RAG:B |
# [4030] GT:A | Base:C | RAG:C |
# [4031] GT:B | Base:C | RAG:C |
# [4032] GT:D | Base:A | RAG:A |
# [4033] GT:A | Base:D | RAG:D |
# [4034] GT:C | Base:A | RAG:A |
# [4035] GT:D | Base:B | RAG:B |
# [4036] GT:C | Base:A | RAG:A |
# [4037] GT:D | Base:B | RAG:B |
# [4038] GT:B | Base:D | RAG:D |
# [4039] GT:B | Base:A | RAG:B | RAG Fix
# [4040] GT:C | Base:A | RAG:C | RAG Fix
# [4041] GT:D | Base:C | RAG:C |
# [4042] GT:C | Base:C | RAG:C |
# [4043] GT:B | Base:A | RAG:A |
# [4044] GT:B | Base:B | RAG:B |
# [4045] GT:A | Base:C | RAG:C |
# [4046] GT:D | Base:B | RAG:B |
# [4047] GT:A | Base:D | RAG:D |
# [4048] GT:B | Base:C | RAG:C |
# [4049] GT:C | Base:A | RAG:A |
# [4050] GT:A | Base:B | RAG:B |
# [4051] GT:B | Base:A | RAG:A |
# [4052] GT:C | Base:D | RAG:D |
# [4053] GT:B | Base:C | RAG:C |
# [4054] GT:D | Base:C | RAG:C |
# [4055] GT:A | Base:C | RAG:C |
# [4056] GT:D | Base:B | RAG:B |
# [4057] GT:C | Base:C | RAG:C |
# [4058] GT:A | Base:A | RAG:A |
# [4059] GT:A | Base:A | RAG:A |
# [4060] GT:A | Base:C | RAG:C |
# [4061] GT:C | Base:B | RAG:B |
# [4062] GT:A | Base:B | RAG:B |
# [4063] GT:B | Base:D | RAG:D |
# [4064] GT:C | Base:C | RAG:C |
# [4065] GT:A | Base:A | RAG:A |
# [4066] GT:B | Base:B | RAG:C | RAG Hurt
# [4067] GT:A | Base:D | RAG:D |
# [4068] GT:A | Base:C | RAG:C |
# [4069] GT:C | Base:C | RAG:C |
# [4070] GT:D | Base:D | RAG:D |
# [4071] GT:D | Base:A | RAG:A |
# [4072] GT:A | Base:D | RAG:D |
# [4073] GT:A | Base:D | RAG:D |
# [4074] GT:A | Base:C | RAG:C |
# [4075] GT:A | Base:A | RAG:A |
# [4076] GT:A | Base:B | RAG:B |
# [4077] GT:B | Base:C | RAG:C |
# [4078] GT:B | Base:B | RAG:B |
# [4079] GT:D | Base:C | RAG:C |
# [4080] GT:D | Base:A | RAG:A |
# [4081] GT:A | Base:A | RAG:A |
# [4082] GT:D | Base:A | RAG:A |
# [4083] GT:C | Base:B | RAG:B |
# [4084] GT:B | Base:D | RAG:D |
# [4085] GT:A | Base:C | RAG:C |
# [4086] GT:C | Base:C | RAG:C |
# [4087] GT:D | Base:B | RAG:B |
# [4088] GT:C | Base:B | RAG:B |
# [4089] GT:A | Base:A | RAG:A |
# [4090] GT:C | Base:B | RAG:B |
# [4091] GT:C | Base:D | RAG:D |
# [4092] GT:D | Base:D | RAG:B | RAG Hurt
# [4093] GT:A | Base:A | RAG:A |
# [4094] GT:A | Base:A | RAG:A |
# [4095] GT:A | Base:A | RAG:D | RAG Hurt
# [4096] GT:C | Base:A | RAG:A |
# [4097] GT:A | Base:C | RAG:C |
# [4098] GT:B | Base:C | RAG:C |
# [4099] GT:C | Base:B | RAG:B |
# [4100] GT:B | Base:A | RAG:A |
# [4101] GT:A | Base:D | RAG:D |
# [4102] GT:A | Base:C | RAG:C |
# [4103] GT:A | Base:B | RAG:B |
# [4104] GT:A | Base:A | RAG:A |
# [4105] GT:B | Base:B | RAG:B |
# [4106] GT:A | Base:D | RAG:D |
# [4107] GT:C | Base:A | RAG:A |
# [4108] GT:C | Base:D | RAG:D |
# [4109] GT:C | Base:B | RAG:B |
# [4110] GT:C | Base:C | RAG:C |
# [4111] GT:B | Base:B | RAG:A | RAG Hurt
# [4112] GT:D | Base:A | RAG:A |
# [4113] GT:A | Base:C | RAG:C |
# [4114] GT:A | Base:B | RAG:B |
# [4115] GT:B | Base:A | RAG:A |
# [4116] GT:D | Base:A | RAG:A |
# [4117] GT:C | Base:C | RAG:C |
# [4118] GT:A | Base:C | RAG:C |
# [4119] GT:D | Base:D | RAG:C | RAG Hurt
# [4120] GT:C | Base:B | RAG:B |
# [4121] GT:B | Base:A | RAG:A |
# [4122] GT:B | Base:A | RAG:A |
# [4123] GT:A | Base:B | RAG:B |
# [4124] GT:C | Base:A | RAG:A |
# [4125] GT:C | Base:A | RAG:A |
# [4126] GT:A | Base:C | RAG:C |
# [4127] GT:A | Base:B | RAG:B |
# [4128] GT:D | Base:C | RAG:C |
# [4129] GT:C | Base:A | RAG:A |
# [4130] GT:C | Base:C | RAG:C |
# [4131] GT:C | Base:C | RAG:D | RAG Hurt
# [4132] GT:C | Base:B | RAG:B |
# [4133] GT:A | Base:A | RAG:B | RAG Hurt
# [4134] GT:C | Base:D | RAG:D |
# [4135] GT:D | Base:C | RAG:C |
# [4136] GT:B | Base:D | RAG:D |
# [4137] GT:A | Base:B | RAG:B |
# [4138] GT:A | Base:B | RAG:B |
# [4139] GT:C | Base:B | RAG:B |
# [4140] GT:A | Base:C | RAG:C |
# [4141] GT:B | Base:A | RAG:A |
# [4142] GT:B | Base:B | RAG:B |
# [4143] GT:B | Base:A | RAG:A |
# [4144] GT:C | Base:B | RAG:B |
# [4145] GT:A | Base:A | RAG:A |
# [4146] GT:A | Base:C | RAG:C |
# [4147] GT:D | Base:C | RAG:C |
# [4148] GT:D | Base:C | RAG:C |
# [4149] GT:A | Base:D | RAG:D |
# [4150] GT:D | Base:B | RAG:B |
# [4151] GT:D | Base:C | RAG:C |
# [4152] GT:A | Base:A | RAG:A |
# [4153] GT:C | Base:C | RAG:C |
# [4154] GT:A | Base:C | RAG:C |
# [4155] GT:A | Base:C | RAG:C |
# [4156] GT:B | Base:C | RAG:C |
# [4157] GT:A | Base:C | RAG:C |
# [4158] GT:B | Base:C | RAG:C |
# [4159] GT:C | Base:D | RAG:B |
# [4160] GT:A | Base:D | RAG:D |
# [4161] GT:A | Base:D | RAG:D |
# [4162] GT:B | Base:D | RAG:D |
# [4163] GT:C | Base:C | RAG:C |
# [4164] GT:B | Base:D | RAG:D |
# [4165] GT:A | Base:A | RAG:A |
# [4166] GT:D | Base:D | RAG:D |
# [4167] GT:B | Base:C | RAG:C |
# [4168] GT:C | Base:B | RAG:B |
# [4169] GT:D | Base:B | RAG:B |
# [4170] GT:A | Base:D | RAG:D |
# [4171] GT:B | Base:B | RAG:B |
# [4172] GT:B | Base:D | RAG:D |
# [4173] GT:A | Base:C | RAG:C |
# [4174] GT:A | Base:A | RAG:A |
# [4175] GT:C | Base:D | RAG:D |
# [4176] GT:B | Base:C | RAG:C |
# [4177] GT:B | Base:B | RAG:B |
# [4178] GT:A | Base:C | RAG:C |
# [4179] GT:D | Base:C | RAG:C |
# [4180] GT:A | Base:D | RAG:D |
# [4181] GT:B | Base:C | RAG:C |
# [4182] GT:A | Base:A | RAG:A |
#
# ==============================
# Total Samples: 4183
# Base Accuracy: 25.72%
# RAG  Accuracy: 25.84%
# ==============================

# %% [markdown]
# Overall Accuracy

# %%
import json
import os
import pandas as pd
from collections import defaultdict

# -------------------------
# 1. Set Correct File Paths
# -------------------------
# Please ensure this is the new filename generated by the "evaluation code" just now!
path = r"eval_results/gpt2_scoring_results_20251215_154935.jsonl"  # <--- Please manually modify the timestamp here

# Automatically find the latest file (If you don't want to change the filename manually, use this code to find the latest one)
def get_latest_file(directory, prefix="gpt2_scoring_results"):
    if not os.path.exists(directory): return None
    files = [os.path.join(directory, f) for f in os.listdir(directory) if f.startswith(prefix) and f.endswith(".jsonl")]
    if not files: return None
    return max(files, key=os.path.getmtime)

latest_path = get_latest_file("eval_results")
if latest_path:
    print(f"Auto-detected latest file: {latest_path}")
    path = latest_path
else:
    print(f"Using manual path: {path}")

# -------------------------
# 2. Read and Check Data
# -------------------------
rows = []
if os.path.exists(path):
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():
                rows.append(json.loads(line))
else:
    print(f"  Error: File not found at {path}")
    rows = []

if not rows:
    print("  No data found.")
else:
    # --- Debug: Print all Keys of the first row ---
    print(f"  Loaded {len(rows)} rows.")
    first_row = rows[0]
    print("Keys in the first row:", list(first_row.keys()))
    
    # Check if key fields exist
    if "is_base_correct" not in first_row:
        print("\n   WARNING: 'is_base_correct' key is MISSING!")
        print("Did you run the old evaluation code? The new scoring code should produce this key.")
        # Attempt auto-repair (if ground_truth and base_prediction exist)
        if "ground_truth" in first_row and "base_prediction" in first_row:
            print("  Attempting to recalculate correctness on the fly...")
            for r in rows:
                r["is_base_correct"] = (r["base_prediction"] == r["ground_truth"])
                r["is_rag_correct"] = (r["rag_prediction"] == r["ground_truth"])
        else:
            print("  Cannot calculate accuracy. Missing prediction data.")

# -------------------------
# 3. Statistics and Analysis
# -------------------------
if rows and "is_base_correct" in rows[0]:
    total = len(rows)
    base_correct = sum(1 for r in rows if r.get("is_base_correct", False))
    rag_correct = sum(1 for r in rows if r.get("is_rag_correct", False))

    print("\n========== Overall Accuracy====")
    print(f"Total samples : {total}")
    print(f"Base Accuracy : {base_correct/total:.2%}")
    print(f"RAG  Accuracy : {rag_correct/total:.2%}")
    print(f"Net Gain      : {rag_correct - base_correct} samples")

    # RAG Effect
    rag_fix = sum(1 for r in rows if not r.get("is_base_correct") and r.get("is_rag_correct"))
    rag_hurt = sum(1 for r in rows if r.get("is_base_correct") and not r.get("is_rag_correct"))

    print("\n========== RAG Effect====")
    print(f"RAG Fix  (Base Wrong -> RAG Right): {rag_fix}")
    print(f"RAG Hurt (Base Right -> RAG Wrong): {rag_hurt}")
# Out:
# Auto-detected latest file: eval_results/gpt2_scoring_results_20251215_154935.jsonl
#   Loaded 4183 rows.
# Keys in the first row: ['id', 'question', 'ground_truth', 'base_prediction', 'rag_prediction', 'rag_context', 'is_base_correct', 'is_rag_correct']
#
# ========== Overall Accuracy ==========
# Total samples : 4183
# Base Accuracy : 25.72%
# RAG  Accuracy : 25.84%
# Net Gain      : 5 samples
#
# ========== RAG Effect ==========
# RAG Fix  (Base Wrong -> RAG Right): 70
# RAG Hurt (Base Right -> RAG Wrong): 65

# %%
import json
import pandas as pd
import os
from collections import Counter

# 1. Automatically find the latest result file
def get_latest_file(directory, prefix="gpt2_scoring_results"):
    if not os.path.exists(directory): return None
    files = [os.path.join(directory, f) for f in os.listdir(directory) if f.startswith(prefix) and f.endswith(".jsonl")]
    if not files: return None
    return max(files, key=os.path.getmtime)

path = get_latest_file("eval_results")
print(f"Analyzing file: {path}")

# 2. Read data
data = []
with open(path, 'r', encoding='utf-8') as f:
    for line in f:
        data.append(json.loads(line))

df = pd.DataFrame(data)

# 3. Core Verification: Check A/B/C/D distribution
print("\n========== Prediction Distribution (Check if 'only selecting A/B' issue is resolved)====")
base_counts = df['base_prediction'].value_counts().sort_index()
rag_counts = df['rag_prediction'].value_counts().sort_index()
gt_counts = df['ground_truth'].value_counts().sort_index()

dist_df = pd.DataFrame({
    'Ground Truth': gt_counts,
    'Base Preds': base_counts,
    'RAG Preds': rag_counts
}).fillna(0).astype(int)

print(dist_df)

# 4. Did it actually select C/D?
c_d_selected = df[df['rag_prediction'].isin(['C', 'D'])].shape[0]
print(f"\nCount of C or D selected in RAG mode: {c_d_selected} / {len(df)}")
if c_d_selected > 0:
    print("  Success! The model has started selecting C and D.")
else:
    print("  Warning: The model still has not selected C or D.")

# 5. Error Analysis: Look at incorrectly predicted examples
print("\n========== Error Case Analysis (Examples where RAG was wrong)====")
wrong_samples = df[~df['is_rag_correct']].head(3)

for idx, row in wrong_samples.iterrows():
    print(f"ID: {row['id']}")
    print(f"Question: {row['question'][:100]}...")
    print(f"Ground Truth: {row['ground_truth']} | Model Prediction: {row['rag_prediction']}")
    # Print score comparison (if available)
    if 'scores_rag' in row:
        scores = row['scores_rag']
        sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
        print(f"Score Ranking: {sorted_scores}")
    print("-" * 50)

# %%
#
# Layer 1: Basic Imports & Configuration
#
import json
import os
import pickle
import numpy as np
import torch
import faiss
from sentence_transformers import SentenceTransformer
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# ---------------------------------------------------------
# [Configuration Area] Please modify variables below according to your actual paths
# ---------------------------------------------------------
GPT2_PATH           = "/media/miaoen/ad4277ac-5cfe-47b0-a2cc-f9e50e0da444/LLM/gpt2"
MEDMCQA_FILE        = "/media/miaoen/ad4277ac-5cfe-47b0-a2cc-f9e50e0da444/LLM/data/medmcqa/dev.json"

# Knowledge Base File Paths (Ensure these files are in the current directory, or use absolute paths)
FAISS_INDEX_PATH    = "pubmed_qa.index"
DOCS_PKL_PATH       = "pubmed_documents.pkl"

# Embedding Model (Must match the model used when building the index)
EMBED_MODEL_NAME    = "all-MiniLM-L6-v2" 

DEVICE              = "cuda" if torch.cuda.is_available() else "cpu"

# RAG Parameters
TOP_K_DOCS          = 2     # Retrieve the top 2 most relevant abstracts
MAX_CTX_CHARS       = 2000  # Maximum context characters (Prevent GPT-2 memory overflow/context limit issues)

print(f"Config OK. DEVICE = {DEVICE}")

#
# Layer 2: Model Layer (GPT-2 Loading & Fixed Generation Function)
#
def load_gpt2(model_path: str = GPT2_PATH):
    print(f"Loading GPT-2 from {model_path} ...")
    try:
        tokenizer = GPT2Tokenizer.from_pretrained(model_path)
        if tokenizer.pad_token is None:
            tokenizer.pad_token = tokenizer.eos_token
        model = GPT2LMHeadModel.from_pretrained(model_path).to(DEVICE)
        print(f"GPT-2 loaded.")
        return tokenizer, model
    except Exception as e:
        print(f"Error loading GPT-2: {e}")
        return None, None

tokenizer, model = load_gpt2()

def gpt2_generate(prompt: str, max_new_tokens: int = 120, do_sample: bool = True, temperature: float = 0.7, top_p: float = 0.9):
    """
    General generation function, UserWarning issues fixed.
    """
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(DEVICE)
    
    # Input length truncation protection (GPT-2 context is usually 1024)
    if inputs.shape[1] > 900:
        inputs = inputs[:, -900:]
        
    attention_mask = torch.ones_like(inputs)

    # Dynamically build parameters to avoid errors when passing temperature with do_sample=False
    gen_kwargs = {
        "max_new_tokens": max_new_tokens,
        "do_sample": do_sample,
        "top_p": top_p,
        "no_repeat_ngram_size": 3,
        "pad_token_id": tokenizer.eos_token_id,
        "attention_mask": attention_mask,
    }

    # Only pass temperature when sampling is enabled
    if do_sample:
        gen_kwargs["temperature"] = temperature

    with torch.no_grad():
        outputs = model.generate(inputs, **gen_kwargs)
    
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

#
# Layer 3: Knowledge Base Layer (Load FAISS & Documents)
#
def load_retrieval_system():
    if not os.path.exists(FAISS_INDEX_PATH) or not os.path.exists(DOCS_PKL_PATH):
        print(f"Error: Knowledge base files not found. Please check if {FAISS_INDEX_PATH} and {DOCS_PKL_PATH} exist.")
        return None, None, None

    print(f"Loading Embedding Model: {EMBED_MODEL_NAME} ...")
    embed_model = SentenceTransformer(EMBED_MODEL_NAME)
    
    print(f"Loading FAISS Index ...")
    index = faiss.read_index(FAISS_INDEX_PATH)
    
    print(f"Loading Documents ...")
    with open(DOCS_PKL_PATH, "rb") as f:
        documents = pickle.load(f)
        
    print(f"Knowledge Base Loaded! Index size: {index.ntotal}, Docs count: {len(documents)}")
    return embed_model, index, documents

# Initialize global variables
embed_model, faiss_index, doc_store = load_retrieval_system()

#
# Layer 4: Vector Retrieval RAG -- Semantic Search Core Logic
#
def get_pubmed_context(question_text: str, top_k: int = TOP_K_DOCS) -> str:
    """
    1. Question to Vector
    2. FAISS Search for Similar Document IDs
    3. Extract Text and Concatenate
    """
    if faiss_index is None:
        return ""

    # 1. Encode
    q_emb = embed_model.encode([question_text], convert_to_numpy=True)
    
    # 2. Search
    distances, indices = faiss_index.search(q_emb, top_k)
    
    # 3. Fetch Text
    retrieved_texts = []
    current_chars = 0
    
    for idx_in_store in indices[0]:
        if idx_in_store == -1: continue # Placeholder when FAISS finds nothing
        
        if idx_in_store >= len(doc_store): continue # Prevent index out of bounds

        doc_content = doc_store[idx_in_store]
        
        # Simple cleaning
        clean_content = doc_content.replace("\n", " ").strip()
        if not clean_content: continue

        # Length check
        if current_chars + len(clean_content) > MAX_CTX_CHARS:
            remaining = MAX_CTX_CHARS - current_chars
            retrieved_texts.append(f"Abstract: {clean_content[:remaining]}...")
            break
        
        retrieved_texts.append(f"Abstract: {clean_content}")
        current_chars += len(clean_content)
    
    if not retrieved_texts:
        return ""
    
    return "\n\n".join(retrieved_texts)

#
# Layer 5: MedMCQA Data Loading
#
def load_medmcqa_example(idx: int = 0, file_path: str = MEDMCQA_FILE):
    """
    Read the idx-th sample from the MedMCQA dataset
    """
    with open(file_path, "r", encoding="utf-8") as f:
        line_idx = 0
        for line in f:
            line = line.strip()
            if not line: continue
            if line_idx == idx:
                data = json.loads(line)
                
                # Construct question stem
                q = data.get("question") or data.get("Question") or ""
                
                # Construct options
                options_lines = []
                option_map = {"opa": "A", "opb": "B", "opc": "C", "opd": "D"}
                found = False
                for k, lab in option_map.items():
                    if k in data:
                        found = True
                        options_lines.append(f"{lab}) {data[k]}")
                if not found and "options" in data:
                    for i, opt in enumerate(data["options"]):
                        options_lines.append(f"{chr(ord('A')+i)}) {opt}")
                
                question_text = q
                if options_lines:
                    question_text += "\nOptions:\n" + "\n".join(options_lines)
                
                # Get answer
                answer = data.get("cop") or data.get("answer") or data.get("label")
                return {"raw": data, "question_text": question_text, "answer": answer}
            line_idx += 1
    raise IndexError(f"Index {idx} out of range")

#
# Layer 6: GPT-2 QA Interface (No RAG vs Vector RAG)
#
def qa_no_rag(question: str) -> str:
    """
    Baseline: No database query, ask GPT-2 directly
    """
    prompt = (
        "You are a medical exam solver.\n"
        "You will be given one multiple-choice question with options A, B, C, and D.\n"
        "Choose the single best option and reply with ONLY one capital letter: A, B, C, or D.\n"
        "Do not output anything else.\n\n"
        f"{question}\n\n"
        "Answer (A, B, C, or D):"
    )
    # do_sample=False indicates greedy search (deterministic results)
    full_text = gpt2_generate(prompt, max_new_tokens=8, do_sample=False)
    
    # Extract the last letter
    tail = full_text.strip()
    for ch in reversed(tail):
        if ch in ["A", "B", "C", "D"]: return ch
    return tail

def qa_with_rag_vector(question: str):
    """
    Vector RAG: Query Database -> Concatenate Context -> Ask GPT-2
    """
    # 1. Get context
    context = get_pubmed_context(question, top_k=TOP_K_DOCS)
    
    if not context:
        return "", qa_no_rag(question)

    # 2. Construct Prompt
    prompt = (
        "You are a medical exam solver.\n"
        "Below are some relevant research abstracts retrieved from PubMed.\n"
        "Use this context to help answer the question.\n"
        "You will be given one multiple-choice question with options A, B, C, and D.\n"
        "Choose the single best option and reply with ONLY one capital letter: A, B, C, or D.\n"
        "Do not output anything else.\n\n"
        f"Context:\n{context}\n\n"
        f"Question:\n{question}\n\n"
        "Answer (A, B, C, or D):"
    )
    
    full_text = gpt2_generate(prompt, max_new_tokens=8, do_sample=False)
    
    tail = full_text.strip()
    for ch in reversed(tail):
        if ch in ["A", "B", "C", "D"]:
            return context, ch

    return context, tail

#
# Layer 7: Comparison Test Function (Single Item)
#
def compare_rag_medmcqa_vector(idx: int = 0, max_print_chars: int = 600, save_dir: str = "rag_logs_vector"):
    """
    Run a single test and print a detailed report
    """
    try:
        example = load_medmcqa_example(idx)
    except IndexError:
        print(f"Index {idx} out of range.")
        return

    question = example["question_text"]
    gt_raw = example["answer"]

    # Unify answer format to A/B/C/D
    def _to_letter(x):
        if x is None: return None
        s = str(x).strip()
        if s in ["A", "B", "C", "D"]: return s
        if s.isdigit() and 1 <= int(s) <= 4: return chr(ord("A") + int(s) - 1)
        return s

    gt = _to_letter(gt_raw)

    # 1) No RAG
    ans_no = qa_no_rag(question)
    
    # 2) Vector RAG
    retrieved_ctx, ans_rag = qa_with_rag_vector(question)

    correct_no  = (str(ans_no) == str(gt))
    correct_rag = (str(ans_rag) == str(gt))

    # Print report
    os.makedirs(save_dir, exist_ok=True)
    out_path = os.path.join(save_dir, f"medmcqa_idx_{idx}.txt")
    
    def _short(s): return s if len(s) <= max_print_chars else s[:max_print_chars] + "..."

    print("=" * 60)
    print(f"MedMCQA Sample idx = {idx}")
    print("Question:")
    print(_short(question))
    print(f"\nCorrect Answer (GT): {gt}")
    print("-" * 60)
    print(f"[No RAG] Prediction: {ans_no} | Correct? {correct_no}")
    print("-" * 60)
    print(f"[Vector RAG] Prediction: {ans_rag} | Correct? {correct_rag}")
    print("\n[Retrieved Context (Top 2)]:")
    if retrieved_ctx:
        print(_short(retrieved_ctx))
    else:
        print("(No relevant documents)")
    print("=" * 60)
    
    # Save to file
    with open(out_path, "w", encoding="utf-8") as f:
        f.write(f"Q: {question}\nGT: {gt}\n\nCTX:\n{retrieved_ctx}\n\nPred_No: {ans_no}\nPred_RAG: {ans_rag}")
# Out:
# Config OK. DEVICE = cuda
# Loading GPT-2 from /media/miaoen/ad4277ac-5cfe-47b0-a2cc-f9e50e0da444/LLM/gpt2 ...
# GPT-2 loaded.
# Loading Embedding Model: all-MiniLM-L6-v2 ...
# Loading FAISS Index ...
# Loading Documents ...
# Knowledge Base Loaded! Index size: 800, Docs count: 800

# %%
import pandas as pd
import os
from datetime import datetime # Import datetime module

#
# Layer 8: Batch Evaluation (Auto Timestamp + Directory Management)
#
def evaluate_medmcqa_acc(start_idx=0, end_idx=100, output_file=None):
    """
    Batch test and save results.
    Arguments:
        output_file: (Optional) Specify filename. If not provided, automatically generated based on current time.
    """
    
    # --- 1. Automatically build filename with timestamp ---
    if output_file is None:
        # Get current time, format: YYYYMMDD_HHMMSS
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        output_file = f"rag_eval_{timestamp}.csv"
    
    # --- 2. Automatically create results folder (Optional, for tidiness) ---
    output_dir = "results"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"Output directory created: {output_dir}")
    
    # Combine full path: results/rag_eval_2025xxxx.csv
    full_output_path = os.path.join(output_dir, output_file)
    
    print(f"Start batch evaluation: Index {start_idx} -> {end_idx}")
    print(f"Results will be saved to: {full_output_path}")
    
    results = [] 
    total = 0
    correct_no = 0
    correct_rag = 0
    improved = 0
    worsened = 0
    
    for idx in range(start_idx, end_idx):
        try:
            ex = load_medmcqa_example(idx)
        except: 
            continue
        
        q = ex["question_text"]
        raw_ans = ex["answer"]
        
        # Parse Ground Truth (GT)
        gt = None
        if raw_ans and str(raw_ans).strip() in ["A","B","C","D"]: 
            gt = str(raw_ans).strip()
        elif raw_ans and str(raw_ans).isdigit(): 
            gt = chr(ord("A") + int(raw_ans) - 1)
        
        if not gt: continue 

        # === Core Prediction ===
        pred_no = qa_no_rag(q)
        ctx_rag, pred_rag = qa_with_rag_vector(q)
        
        # === Statistics ===
        is_correct_no = (pred_no == gt)
        is_correct_rag = (pred_rag == gt)
        
        if is_correct_no: correct_no += 1
        if is_correct_rag: correct_rag += 1
        total += 1
        
        status = "Same"
        if not is_correct_no and is_correct_rag:
            status = "Improved"
            improved += 1
        elif is_correct_no and not is_correct_rag:
            status = "Worsened"
            worsened += 1
        
        results.append({
            "Index": idx,
            "Question": q,
            "Ground_Truth": gt,
            "Pred_No_RAG": pred_no,
            "Correct_No_RAG": is_correct_no,
            "Pred_Vector_RAG": pred_rag,
            "Correct_Vector_RAG": is_correct_rag,
            "Status": status,
            "Retrieved_Context": ctx_rag
        })

        print(f"[{idx}] GT:{gt} | NoRAG:{pred_no} {'O' if is_correct_no else 'X'} | RAG:{pred_rag} {'O' if is_correct_rag else 'X'} | {status}")

    # === Calculate Final Metrics ===
    acc_no = correct_no / total if total > 0 else 0
    acc_rag = correct_rag / total if total > 0 else 0
    
    print(f"\nFinal Results ({total} questions):")
    print(f"Pure GPT-2 Accuracy : {acc_no:.4f}")
    print(f"RAG (Vector) Accuracy: {acc_rag:.4f}")
    
    # === Save File ===
    if results:
        df = pd.DataFrame(results)
        df["Global_Acc_No_RAG"] = f"{acc_no:.2%}"
        df["Global_Acc_Vector_RAG"] = f"{acc_rag:.2%}"
        
        # 1. Save detailed CSV
        df.to_csv(full_output_path, index=False, encoding="utf-8-sig")
        print(f"Detailed results saved: {full_output_path}")
        
        # 2. Save Summary CSV (Filename automatically adds _summary)
        base, ext = os.path.splitext(output_file) # Separate filename and extension
        summary_filename = f"{base}_summary{ext}"
        full_summary_path = os.path.join(output_dir, summary_filename)
        
        summary_data = [{
            "Timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"), # Record exact time
            "Range": f"{start_idx}-{end_idx}",
            "Total_Questions": total,
            "Acc_No_RAG": acc_no,
            "Acc_Vector_RAG": acc_rag,
            "Improved_Count": improved,
            "Worsened_Count": worsened
        }]
        pd.DataFrame(summary_data).to_csv(full_summary_path, index=False, encoding="utf-8-sig")
        print(f"Summary statistics saved: {full_summary_path}")
        
    else:
        print("No results generated, skipping save.")

#
# Run Example
#
if __name__ == "__main__":
    # Method 1: No arguments passed, automatically generate filename with timestamp
    evaluate_medmcqa_acc(0, 4183)
    
    # Method 2: If you want to specify a name, you can pass it (will also be saved in results folder)
    # evaluate_medmcqa_acc(0, 50, output_file="my_custom_experiment.csv")
