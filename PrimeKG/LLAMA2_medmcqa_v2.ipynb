# %%
# Cell 1: Import Dependencies & Load Llama-2 (4-bit)
import json
import os
import re
import pandas as pd
import networkx as nx
import torch
import torch.nn.functional as F
from datetime import datetime
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

LLAMA2_PATH   = r"/LLM/llama2"
PRIMEKG_PATH  = r"kg.csv"
MEDMCQA_FILE  = r"/LLM/data/medmcqa/dev.json"
OUTPUT_DIR    = "eval_results_llama2"   

# RAG Parameters
MAX_RAG_ENTITIES = 3    
MAX_K_EDGES      = 5    
MAX_CTX_CHARS    = 2000 

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Config loaded. Running on {DEVICE}")

# ---------------- Model Loading ----------------
def load_llama2_4bit(model_path):
    print(f"Loading LLaMA2 4-bit from: {model_path}")
    
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.float16,
    )
    
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    # Llama2 has no pad token; usually set to eos or unk, here we set it to eos
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
        
    model = AutoModelForCausalLM.from_pretrained(
        model_path,
        quantization_config=bnb_config,
        device_map="auto", 
    )
    print("LLaMA2 4-bit loaded!")
    return tokenizer, model

llama2_tokenizer, llama2_model = load_llama2_4bit(LLAMA2_PATH)
# Out:
# Config loaded. Running on cuda
# Loading LLaMA2 4-bit from: /LLM/llama2
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Cell 2: Knowledge Graph Loading and RAG Functions
def load_kg(path):
    print(f"Loading PrimeKG from {path} ...")
    if not os.path.exists(path):
        return nx.Graph()
    df = pd.read_csv(path, low_memory=False)
    G = nx.from_pandas_edgelist(df, "x_name", "y_name", edge_attr=True)
    print(f"KG Loaded: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")
    return G

G = load_kg(PRIMEKG_PATH)
node_index = {str(n).lower(): n for n in G.nodes()}

BLACKLIST = {
    "rest", "left", "right", "lateral", "medial", "distal", "proximal",
    "central", "group", "zone", "growth", "tube", "head", "neck", 
    "body", "hand", "foot", "wing", "type", "part", "high", "low",
    "blood", "cell", "tissue", "disease", "drug", "pathway", "human"
}

def extract_rag_entities(question, max_entities=MAX_RAG_ENTITIES):
    q_lower = question.lower()
    ents = []
    candidates = [n for n in node_index.keys() if len(n) >= 4]
    for cand in candidates:
        if cand in BLACKLIST: continue
        if re.search(r'\b' + re.escape(cand) + r'\b', q_lower):
            ents.append(node_index[cand])
            if len(ents) >= max_entities: break
    return ents

def get_knowledge_context_single(entity, max_edges=MAX_K_EDGES):
    node = node_index.get(entity.lower())
    if not node: return None
    try:
        edges = list(G.edges(node, data=True))
    except: return None
    if not edges: return None
    sorted_edges = sorted(edges, key=lambda x: x[2].get('relation', ''), reverse=True)
    lines = []
    for u, v, attr in sorted_edges[:max_edges]:
        rel = attr.get("display_relation", attr.get("relation", "related to"))
        nbr = v if node == u else u
        lines.append(f"{node} is {rel} {nbr}.")
    return " ".join(lines)

def get_knowledge_context_multi(question):
    entities = extract_rag_entities(question)
    if not entities: return [], ""
    all_facts = []
    current_len = 0
    for ent in entities:
        ctx = get_knowledge_context_single(ent)
        if not ctx: continue
        block = f"Fact about {ent}: {ctx} "
        if current_len + len(block) > MAX_CTX_CHARS: break
        all_facts.append(block)
        current_len += len(block)
    return entities, "".join(all_facts)
# Out:
# Loading PrimeKG from kg.csv ...
# KG Loaded: 129262 nodes, 4049405 edges

# %%
# Cell 3: Load MedMCQA Example

def load_medmcqa_example(idx, file_path=MEDMCQA_FILE):
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"File not found: {file_path}")
        
    with open(file_path, "r", encoding="utf-8") as f:
        for line_id, line in enumerate(f):
            if line_id < idx: continue
            if line_id > idx: break 
            
            line = line.strip()
            if not line: continue
            
            data = json.loads(line)
            q = data.get("question", "")
            options_dict = {}
            mapping = {"opa":"A", "opb":"B", "opc":"C", "opd":"D"}
            for key, lab in mapping.items():
                if key in data and data[key]:
                    options_dict[lab] = str(data[key]).strip()
            
            return {
                "id": idx,
                "question": q,
                "options": options_dict,
                "answer": data.get("cop")
            }
    raise IndexError("Index out of range")

# %%
# Cell 4: Llama 2 PPL Scoring Function (with length normalization)
def get_llama2_score(context, question, option_text):
    """
    Calculate the plausibility score of (Context + Question + Option).
    Use labels=-100 to mask the Question, calculating Loss only for the Option.
    """
    # 1. Construct Prompt
    parts = []
    if context:
        parts.append(f"Context: {context}") # RAG knowledge as prerequisite
    parts.append(f"Question: {question}")
    parts.append("Answer:")
    
    prompt = "\n".join(parts)
    # Llama2 is sensitive to spaces; it is recommended to add a space after Answer:
    full_text = f"{prompt} {option_text}"
    
    # 2. Encoding
    prompt_enc = llama2_tokenizer(prompt, return_tensors="pt", add_special_tokens=False)
    full_enc = llama2_tokenizer(full_text, return_tensors="pt", truncation=True, max_length=2048)
    
    input_ids = full_enc.input_ids.to(DEVICE)
    attention_mask = full_enc.attention_mask.to(DEVICE)
    
    # 3. Masking (Mask the Prompt part, only calculate the score for the Option)
    labels = input_ids.clone()
    prompt_len = prompt_enc.input_ids.shape[1]
    
    if prompt_len < labels.shape[1]:
        labels[:, :prompt_len] = -100
    else:
        labels[:, :] = -100 # Exception safety
        
    # 4. Calculate Loss
    with torch.no_grad():
        outputs = llama2_model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        
        # HuggingFace returns Mean Loss by default (average loss per token)
        # This naturally has a length normalization effect (much better than Sum Loss)
        mean_loss = outputs.loss.item()
    
    if torch.isnan(outputs.loss):
        return -float('inf')
    # Return negative Loss (higher score is better)
    return -mean_loss

def solve_by_scoring(question, options_dict, context=""):
    """
    Iterate through all options and select the one with the highest score.
    """
    scores = {}
    for label in ["A", "B", "C", "D"]:
        if label not in options_dict:
            scores[label] = -float('inf')
            continue
            
        opt_text = options_dict[label]
        scores[label] = get_llama2_score(context, question, opt_text)
    # Select the maximum value
    best_label = max(scores, key=scores.get)
    return best_label, scores

# %%
# Cell 5: Run Evaluation
def evaluate_and_save(start_idx=0, end_idx=50):
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)
        
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    save_path = os.path.join(OUTPUT_DIR, f"llama2_scoring_{timestamp}.jsonl")
    print(f"Results will be saved to: {save_path}")
    print(f"Starting SCORING evaluation {start_idx} -> {end_idx}...\n")
    
    total = 0
    correct_base = 0
    correct_rag = 0
    
    # Answer formatting tool
    def format_gt(val):
        s = str(val).strip().upper()
        mapping = {'1':'A', '2':'B', '3':'C', '4':'D'}
        return mapping.get(s, s) if s in mapping else (s if s in ['A','B','C','D'] else None)

    with open(save_path, "w", encoding="utf-8") as f:
        for i in range(start_idx, end_idx):
            try:
                # Load
                ex = load_medmcqa_example(i)
                gt = format_gt(ex['answer'])
                if not gt: continue
                
                q_text = ex['question']
                opts = ex['options']
                
                # 1. Base Inference
                pred_base, scores_base = solve_by_scoring(q_text, opts, context="")
                
                # 2. RAG Inference
                ents, ctx = get_knowledge_context_multi(q_text)
                pred_rag, scores_rag = solve_by_scoring(q_text, opts, context=ctx)
                
                # 3. Statistics
                total += 1
                if pred_base == gt: correct_base += 1
                if pred_rag == gt: correct_rag += 1
                
                # 4. Write
                record = {
                    "id": i,
                    "question": q_text,
                    "ground_truth": gt,
                    "base_prediction": pred_base,
                    "rag_prediction": pred_rag,
                    "rag_context": ctx,
                    "is_base_correct": (pred_base == gt),
                    "is_rag_correct": (pred_rag == gt)
                }
                f.write(json.dumps(record, ensure_ascii=False) + "\n")
                
                # Print summary
                status = ""
                if pred_rag == gt and pred_base != gt: status = "O RAG FIX"
                elif pred_rag != gt and pred_base == gt: status = "X RAG HURT"
                print(f"[{i}] GT:{gt} | Base:{pred_base} | RAG:{pred_rag} | {status}")
                
            except Exception as e:
                print(f"Skipping {i}: {e}")
                continue
            
    if total > 0:
        print(f"Total: {total}")
        print(f"Base Acc: {correct_base/total:.2%}")
        print(f"RAG  Acc: {correct_rag/total:.2%}")

# Start execution
evaluate_and_save(0, 4183)
# Out:
# Results will be saved to: eval_results_llama2/llama2_scoring_20251222_233932.jsonl
# Starting SCORING evaluation 0 -> 4183...
#
# [0] GT:A | Base:A | RAG:A |
# [1] GT:A | Base:B | RAG:B |
# [2] GT:C | Base:B | RAG:B |
# [3] GT:C | Base:B | RAG:B |
# [4] GT:A | Base:C | RAG:C |
# [5] GT:A | Base:B | RAG:A | ✅ RAG FIX
# [6] GT:A | Base:A | RAG:A |
# [7] GT:B | Base:A | RAG:A |
# [8] GT:B | Base:C | RAG:C |
# [9] GT:B | Base:D | RAG:C |
# [10] GT:B | Base:B | RAG:B |
# [11] GT:A | Base:A | RAG:A |
# [12] GT:B | Base:A | RAG:A |
# [13] GT:A | Base:B | RAG:B |
# [14] GT:A | Base:D | RAG:D |
# [15] GT:B | Base:A | RAG:A |
# [16] GT:A | Base:C | RAG:C |
# [17] GT:D | Base:D | RAG:D |
# [18] GT:A | Base:A | RAG:A |
# [19] GT:A | Base:C | RAG:D |
# [20] GT:B | Base:A | RAG:A |
# [21] GT:C | Base:A | RAG:A |
# [22] GT:A | Base:D | RAG:D |
# [23] GT:A | Base:A | RAG:A |
# [24] GT:D | Base:C | RAG:C |
# [25] GT:B | Base:B | RAG:C | ❌ RAG HURT
# [26] GT:A | Base:C | RAG:C |
# [27] GT:D | Base:D | RAG:D |
# [28] GT:A | Base:D | RAG:B |
# [29] GT:C | Base:B | RAG:B |
# [30] GT:A | Base:C | RAG:C |
# [31] GT:B | Base:C | RAG:C |
# [32] GT:A | Base:D | RAG:D |
# [33] GT:A | Base:D | RAG:D |
# [34] GT:D | Base:B | RAG:B |
# [35] GT:C | Base:C | RAG:A | ❌ RAG HURT
# [36] GT:B | Base:B | RAG:B |
# [37] GT:D | Base:B | RAG:B |
# [38] GT:C | Base:A | RAG:A |
# [39] GT:C | Base:D | RAG:D |
# [40] GT:B | Base:D | RAG:D |
# [41] GT:A | Base:C | RAG:C |
# [42] GT:D | Base:A | RAG:A |
# [43] GT:D | Base:C | RAG:C |
# [44] GT:A | Base:B | RAG:B |
# [45] GT:B | Base:A | RAG:A |
# [46] GT:B | Base:D | RAG:D |
# [47] GT:A | Base:C | RAG:C |
# [48] GT:C | Base:D | RAG:D |
# [49] GT:C | Base:C | RAG:C |
# [50] GT:B | Base:A | RAG:A |
# [51] GT:C | Base:A | RAG:A |
# [52] GT:B | Base:C | RAG:C |
# [53] GT:A | Base:C | RAG:C |
# [54] GT:B | Base:D | RAG:D |
# [55] GT:C | Base:C | RAG:C |
# [56] GT:C | Base:A | RAG:A |
# [57] GT:A | Base:A | RAG:A |
# [58] GT:A | Base:C | RAG:C |
# [59] GT:D | Base:C | RAG:C |
# [60] GT:D | Base:A | RAG:A |
# [61] GT:C | Base:A | RAG:A |
# [62] GT:A | Base:C | RAG:C |
# [63] GT:D | Base:D | RAG:D |
# [64] GT:A | Base:A | RAG:A |
# [65] GT:D | Base:C | RAG:C |
# [66] GT:C | Base:D | RAG:D |
# [67] GT:D | Base:B | RAG:B |
# [68] GT:C | Base:C | RAG:C |
# [69] GT:B | Base:A | RAG:A |
# [70] GT:B | Base:B | RAG:B |
# [71] GT:C | Base:C | RAG:C |
# [72] GT:A | Base:C | RAG:D |
# [73] GT:B | Base:A | RAG:A |
# [74] GT:D | Base:D | RAG:D |
# [75] GT:A | Base:D | RAG:C |
# [76] GT:A | Base:C | RAG:C |
# [77] GT:B | Base:B | RAG:B |
# [78] GT:B | Base:A | RAG:D |
# [79] GT:B | Base:C | RAG:C |
# [80] GT:C | Base:B | RAG:B |
# [81] GT:A | Base:B | RAG:B |
# [82] GT:A | Base:B | RAG:B |
# [83] GT:A | Base:C | RAG:C |
# [84] GT:A | Base:D | RAG:D |
# [85] GT:C | Base:A | RAG:A |
# [86] GT:A | Base:C | RAG:C |
# [87] GT:D | Base:B | RAG:B |
# [88] GT:A | Base:A | RAG:A |
# [89] GT:D | Base:A | RAG:A |
# [90] GT:B | Base:D | RAG:C |
# [91] GT:B | Base:A | RAG:A |
# [92] GT:B | Base:D | RAG:D |
# [93] GT:A | Base:C | RAG:D |
# [94] GT:C | Base:C | RAG:C |
# [95] GT:A | Base:A | RAG:A |
# [96] GT:B | Base:B | RAG:B |
# [97] GT:D | Base:B | RAG:B |
# [98] GT:B | Base:C | RAG:C |
# [99] GT:D | Base:B | RAG:B |
# [100] GT:A | Base:C | RAG:C |
# [101] GT:B | Base:A | RAG:B | ✅ RAG FIX
# [102] GT:A | Base:B | RAG:B |
# [103] GT:D | Base:A | RAG:A |
# [104] GT:B | Base:D | RAG:D |
# [105] GT:A | Base:D | RAG:D |
# [106] GT:D | Base:B | RAG:B |
# [107] GT:B | Base:B | RAG:B |
# [108] GT:C | Base:C | RAG:C |
# [109] GT:A | Base:B | RAG:B |
# [110] GT:A | Base:D | RAG:D |
# [111] GT:D | Base:B | RAG:C |
# [112] GT:A | Base:C | RAG:C |
# [113] GT:C | Base:C | RAG:C |
# [114] GT:A | Base:B | RAG:B |
# [115] GT:B | Base:A | RAG:B | ✅ RAG FIX
# [116] GT:C | Base:B | RAG:B |
# [117] GT:B | Base:D | RAG:D |
# [118] GT:A | Base:D | RAG:D |
# [119] GT:A | Base:B | RAG:B |
# [120] GT:C | Base:B | RAG:B |
# [121] GT:A | Base:B | RAG:B |
# [122] GT:A | Base:D | RAG:D |
# [123] GT:D | Base:C | RAG:C |
# [124] GT:B | Base:D | RAG:D |
# [125] GT:A | Base:A | RAG:A |
# [126] GT:A | Base:B | RAG:B |
# [127] GT:B | Base:D | RAG:A |
# [128] GT:D | Base:B | RAG:A |
# [129] GT:B | Base:B | RAG:B |
# [130] GT:C | Base:A | RAG:C | ✅ RAG FIX
# [131] GT:D | Base:C | RAG:C |
# [132] GT:B | Base:C | RAG:C |
# [133] GT:B | Base:D | RAG:D |
# [134] GT:B | Base:B | RAG:B |
# [135] GT:A | Base:A | RAG:A |
# [136] GT:B | Base:D | RAG:D |
# [137] GT:A | Base:B | RAG:B |
# [138] GT:C | Base:B | RAG:B |
# [139] GT:A | Base:C | RAG:B |
# [140] GT:C | Base:B | RAG:B |
# [141] GT:A | Base:D | RAG:D |
# [142] GT:A | Base:A | RAG:A |
# [143] GT:C | Base:A | RAG:A |
# [144] GT:B | Base:A | RAG:A |
# [145] GT:A | Base:A | RAG:A |
# [146] GT:C | Base:D | RAG:D |
# [147] GT:A | Base:C | RAG:C |
# [148] GT:D | Base:C | RAG:C |
# [149] GT:B | Base:B | RAG:B |
# [150] GT:A | Base:C | RAG:C |
# [151] GT:B | Base:B | RAG:B |
# [152] GT:C | Base:D | RAG:D |
# [153] GT:A | Base:D | RAG:D |
# [154] GT:B | Base:B | RAG:B |
# [155] GT:B | Base:D | RAG:D |
# [156] GT:A | Base:A | RAG:A |
# [157] GT:D | Base:D | RAG:D |
# [158] GT:C | Base:D | RAG:D |
# [159] GT:D | Base:B | RAG:B |
# [160] GT:B | Base:B | RAG:B |
# [161] GT:B | Base:C | RAG:C |
# [162] GT:B | Base:C | RAG:C |
# [163] GT:D | Base:D | RAG:D |
# [164] GT:A | Base:C | RAG:A | ✅ RAG FIX
# [165] GT:C | Base:C | RAG:C |
# [166] GT:D | Base:C | RAG:C |
# [167] GT:B | Base:A | RAG:A |
# [168] GT:B | Base:A | RAG:A |
# [169] GT:C | Base:B | RAG:B |
# [170] GT:B | Base:B | RAG:B |
# [171] GT:A | Base:D | RAG:D |
# [172] GT:B | Base:C | RAG:D |
# [173] GT:A | Base:B | RAG:B |
# [174] GT:B | Base:D | RAG:D |
# [175] GT:C | Base:B | RAG:A |
# [176] GT:B | Base:B | RAG:C | ❌ RAG HURT
# [177] GT:C | Base:D | RAG:D |
# [178] GT:D | Base:D | RAG:D |
# [179] GT:D | Base:D | RAG:D |
# [180] GT:B | Base:B | RAG:B |
# [181] GT:A | Base:B | RAG:B |
# [182] GT:A | Base:C | RAG:C |
# [256] GT:D | Base:C | RAG:C |
# [257] GT:A | Base:C | RAG:C |
# [258] GT:A | Base:D | RAG:B |
# [259] GT:C | Base:D | RAG:D |
# [260] GT:C | Base:B | RAG:B |
# [261] GT:C | Base:C | RAG:C |
# [262] GT:D | Base:B | RAG:B |
# [263] GT:D | Base:B | RAG:B |
# [264] GT:B | Base:A | RAG:A |
# [265] GT:D | Base:B | RAG:B |
# [266] GT:A | Base:B | RAG:B |
# [267] GT:B | Base:B | RAG:B |
# [268] GT:B | Base:B | RAG:B |
# [269] GT:C | Base:D | RAG:D |
# [270] GT:C | Base:D | RAG:D |
# [271] GT:D | Base:B | RAG:B |
# [272] GT:A | Base:A | RAG:A |
# [273] GT:C | Base:C | RAG:C |
# [274] GT:C | Base:C | RAG:C |
# [275] GT:D | Base:D | RAG:D |
# [276] GT:D | Base:A | RAG:A |
# [277] GT:B | Base:A | RAG:A |
# [278] GT:B | Base:D | RAG:D |
# [279] GT:D | Base:B | RAG:B |
# [280] GT:A | Base:D | RAG:D |
# [281] GT:C | Base:B | RAG:D |
# [282] GT:C | Base:B | RAG:B |
# [283] GT:D | Base:C | RAG:C |
# [284] GT:C | Base:A | RAG:A |
# [285] GT:C | Base:A | RAG:A |
# [286] GT:C | Base:C | RAG:C |
# [287] GT:D | Base:B | RAG:B |
# [288] GT:B | Base:D | RAG:D |
# [289] GT:C | Base:B | RAG:B |
# [290] GT:D | Base:A | RAG:A |
# [291] GT:C | Base:C | RAG:C |
# [292] GT:A | Base:B | RAG:B |
# [293] GT:D | Base:A | RAG:A |
# [294] GT:D | Base:C | RAG:C |
# [295] GT:B | Base:B | RAG:B |
# [296] GT:A | Base:D | RAG:D |
# [297] GT:B | Base:B | RAG:B |
# [298] GT:B | Base:C | RAG:C |
# [299] GT:A | Base:B | RAG:B |
# [300] GT:A | Base:D | RAG:D |
# [301] GT:C | Base:D | RAG:C | ✅ RAG FIX
# [302] GT:B | Base:B | RAG:B |
# [303] GT:D | Base:A | RAG:A |
# [304] GT:A | Base:C | RAG:C |
# [305] GT:B | Base:A | RAG:A |
# [306] GT:B | Base:B | RAG:B |
# [307] GT:A | Base:C | RAG:C |
# [308] GT:A | Base:A | RAG:A |
# [309] GT:B | Base:D | RAG:D |
# [310] GT:B | Base:B | RAG:B |
# [311] GT:A | Base:A | RAG:A |
# [312] GT:D | Base:C | RAG:C |
# [313] GT:A | Base:C | RAG:C |
# [314] GT:A | Base:C | RAG:C |
# [315] GT:B | Base:C | RAG:C |
# [316] GT:A | Base:A | RAG:A |
# [317] GT:A | Base:C | RAG:C |
# [318] GT:A | Base:C | RAG:A | ✅ RAG FIX
# [319] GT:B | Base:A | RAG:A |
# [320] GT:A | Base:A | RAG:A |
# [321] GT:D | Base:C | RAG:C |
# [322] GT:D | Base:D | RAG:D |
# [323] GT:B | Base:C | RAG:C |
# [324] GT:D | Base:D | RAG:D |
# [325] GT:B | Base:B | RAG:B |
# [326] GT:B | Base:D | RAG:D |
# [327] GT:B | Base:C | RAG:C |
# [328] GT:B | Base:B | RAG:B |
# [329] GT:D | Base:B | RAG:B |
# [330] GT:C | Base:A | RAG:A |
# [331] GT:D | Base:C | RAG:C |
# [332] GT:D | Base:C | RAG:C |
# [333] GT:A | Base:D | RAG:D |
# [334] GT:B | Base:A | RAG:B | ✅ RAG FIX
#
# [401] GT:A | Base:D | RAG:D |
# [402] GT:A | Base:A | RAG:B | ❌ RAG HURT
# [403] GT:A | Base:D | RAG:D |
# [404] GT:C | Base:C | RAG:C |
# [405] GT:A | Base:B | RAG:B |
# [406] GT:B | Base:C | RAG:C |
# [407] GT:D | Base:A | RAG:D | ✅ RAG FIX
# [408] GT:B | Base:A | RAG:A |
# [409] GT:D | Base:D | RAG:D |
# [410] GT:B | Base:D | RAG:D |
# [411] GT:A | Base:B | RAG:B |
# [412] GT:B | Base:D | RAG:D |
# [413] GT:C | Base:C | RAG:D | ❌ RAG HURT
# [414] GT:C | Base:C | RAG:C |
# [415] GT:A | Base:C | RAG:C |
# [416] GT:A | Base:C | RAG:D |
# [417] GT:C | Base:B | RAG:B |
# [418] GT:C | Base:A | RAG:A |
# [419] GT:D | Base:C | RAG:C |
# [420] GT:D | Base:C | RAG:C |
# [421] GT:D | Base:C | RAG:C |
# [422] GT:B | Base:B | RAG:B |
# [423] GT:D | Base:D | RAG:D |
# [424] GT:C | Base:D | RAG:D |
# [425] GT:C | Base:B | RAG:B |
# [426] GT:A | Base:C | RAG:C |
# [427] GT:A | Base:B | RAG:A | ✅ RAG FIX
# [428] GT:A | Base:D | RAG:D |
# [429] GT:A | Base:B | RAG:B |
# [430] GT:C | Base:C | RAG:C |
# [431] GT:A | Base:B | RAG:B |
# [432] GT:D | Base:D | RAG:D |
# [433] GT:D | Base:D | RAG:D |
# [434] GT:C | Base:B | RAG:B |
# [435] GT:D | Base:D | RAG:C | ❌ RAG HURT
# [436] GT:A | Base:A | RAG:A |
# [437] GT:A | Base:A | RAG:A |
# [438] GT:C | Base:C | RAG:C |
# [439] GT:C | Base:A | RAG:A |
# [440] GT:B | Base:C | RAG:C |
# [441] GT:A | Base:B | RAG:B |
# [442] GT:A | Base:D | RAG:D |
# [443] GT:D | Base:D | RAG:D |
# [444] GT:A | Base:C | RAG:C |
# [445] GT:C | Base:C | RAG:D | ❌ RAG HURT
# [446] GT:C | Base:B | RAG:B |
# [447] GT:D | Base:B | RAG:B |
# [448] GT:D | Base:A | RAG:B |
# [449] GT:C | Base:B | RAG:B |
# [450] GT:A | Base:B | RAG:A | ✅ RAG FIX
# [451] GT:A | Base:B | RAG:B |
# [452] GT:B | Base:A | RAG:A |
# [453] GT:D | Base:D | RAG:D |
# [454] GT:B | Base:D | RAG:D |
# [455] GT:A | Base:A | RAG:A |
# [456] GT:D | Base:D | RAG:A | ❌ RAG HURT
# [457] GT:B | Base:D | RAG:D |
# [458] GT:B | Base:D | RAG:D |
# [459] GT:A | Base:A | RAG:A |
# [460] GT:A | Base:B | RAG:B |
# [461] GT:B | Base:D | RAG:D |
# [462] GT:A | Base:C | RAG:C |
# [463] GT:C | Base:C | RAG:C |
# [464] GT:D | Base:D | RAG:D |
# [465] GT:B | Base:B | RAG:B |
# [466] GT:A | Base:B | RAG:B |
# [467] GT:B | Base:C | RAG:C |
# [468] GT:C | Base:B | RAG:C | ✅ RAG FIX
# [469] GT:B | Base:D | RAG:D |
# [470] GT:C | Base:D | RAG:A |
# [471] GT:D | Base:A | RAG:A |
# [472] GT:A | Base:C | RAG:A | ✅ RAG FIX
# [473] GT:B | Base:B | RAG:B |
# [474] GT:A | Base:A | RAG:D | ❌ RAG HURT
#
# [616] GT:B | Base:B | RAG:B |
# [617] GT:C | Base:B | RAG:B |
# [618] GT:C | Base:C | RAG:C |
# [619] GT:A | Base:C | RAG:C |
# [620] GT:D | Base:B | RAG:B |
# [621] GT:B | Base:C | RAG:C |
# [622] GT:A | Base:D | RAG:D |
# [623] GT:A | Base:D | RAG:D |
# [624] GT:D | Base:B | RAG:B |
# [625] GT:C | Base:D | RAG:C | ✅ RAG FIX
# [626] GT:D | Base:C | RAG:C |
# [627] GT:B | Base:D | RAG:D |
# [628] GT:A | Base:A | RAG:A |
# [629] GT:C | Base:D | RAG:D |
# [630] GT:B | Base:B | RAG:B |
# [631] GT:C | Base:B | RAG:B |
# [632] GT:C | Base:A | RAG:A |
# [633] GT:A | Base:A | RAG:A |
# [634] GT:B | Base:C | RAG:C |
# [635] GT:A | Base:A | RAG:A |
# [636] GT:C | Base:D | RAG:D |
# [637] GT:A | Base:B | RAG:B |
# [638] GT:B | Base:B | RAG:B |
# [639] GT:B | Base:D | RAG:D |
# [640] GT:B | Base:C | RAG:C |
# [641] GT:C | Base:D | RAG:C | ✅ RAG FIX
# [642] GT:A | Base:A | RAG:A |
# [643] GT:B | Base:C | RAG:C |
# [644] GT:A | Base:C | RAG:C |
# [645] GT:A | Base:A | RAG:A |
# [646] GT:D | Base:B | RAG:B |
# [647] GT:A | Base:A | RAG:A |
# [648] GT:C | Base:C | RAG:C |
# [649] GT:B | Base:C | RAG:C |
# [650] GT:D | Base:B | RAG:B |
# [651] GT:B | Base:C | RAG:C |
# [652] GT:D | Base:C | RAG:C |
# [653] GT:B | Base:A | RAG:C |
# [654] GT:C | Base:C | RAG:C |
# [655] GT:C | Base:B | RAG:B |
# [656] GT:B | Base:C | RAG:C |
# [657] GT:A | Base:B | RAG:B |
# [658] GT:B | Base:C | RAG:C |
# [659] GT:A | Base:C | RAG:C |
# [660] GT:A | Base:B | RAG:B |
# [661] GT:B | Base:B | RAG:B |
# [662] GT:A | Base:B | RAG:C |
# [663] GT:A | Base:A | RAG:A |
# [664] GT:D | Base:D | RAG:C | ❌ RAG HURT
# [665] GT:D | Base:A | RAG:A |
# [666] GT:A | Base:C | RAG:C |
# [667] GT:D | Base:A | RAG:A |
# [668] GT:B | Base:D | RAG:D |
# [669] GT:C | Base:A | RAG:A |
# [670] GT:A | Base:D | RAG:D |
# [671] GT:A | Base:C | RAG:A | ✅ RAG FIX
# [672] GT:D | Base:B | RAG:B |
# [673] GT:D | Base:B | RAG:B |
# [674] GT:D | Base:B | RAG:B |
# [675] GT:B | Base:C | RAG:C |
# [676] GT:A | Base:C | RAG:C |
# [677] GT:B | Base:C | RAG:C |
# [678] GT:A | Base:B | RAG:B |
# [679] GT:B | Base:A | RAG:A |
# [680] GT:D | Base:A | RAG:A |
# [681] GT:C | Base:C | RAG:C |
# [682] GT:B | Base:B | RAG:B |
# [683] GT:B | Base:D | RAG:D |
# [684] GT:D | Base:B | RAG:B |
# [685] GT:B | Base:B | RAG:B |
# [686] GT:A | Base:A | RAG:C | ❌ RAG HURT
# [687] GT:D | Base:B | RAG:B |
# [688] GT:D | Base:B | RAG:B |
# [689] GT:D | Base:A | RAG:A |
# [690] GT:B | Base:D | RAG:D |
# [691] GT:C | Base:C | RAG:C |
# [692] GT:D | Base:D | RAG:D |
# [693] GT:B | Base:A | RAG:B | ✅ RAG FIX
#
# [759] GT:A | Base:D | RAG:D |
# [760] GT:A | Base:D | RAG:D |
# [761] GT:C | Base:A | RAG:A |
# [762] GT:B | Base:C | RAG:C |
# [763] GT:C | Base:D | RAG:D |
# [764] GT:A | Base:B | RAG:B |
# [765] GT:D | Base:B | RAG:B |
# [766] GT:C | Base:B | RAG:B |
# [767] GT:A | Base:C | RAG:C |
# [768] GT:B | Base:D | RAG:D |
# [769] GT:A | Base:A | RAG:D | ❌ RAG HURT
# [770] GT:A | Base:D | RAG:D |
# [771] GT:A | Base:B | RAG:A | ✅ RAG FIX
# [772] GT:A | Base:A | RAG:A |
# [773] GT:B | Base:A | RAG:A |
# [774] GT:C | Base:C | RAG:C |
# [775] GT:C | Base:C | RAG:C |
# [776] GT:C | Base:C | RAG:B | ❌ RAG HURT
# [777] GT:A | Base:D | RAG:D |
# [778] GT:D | Base:A | RAG:A |
# [779] GT:B | Base:B | RAG:B |
# [780] GT:A | Base:C | RAG:C |
# [781] GT:D | Base:B | RAG:B |
# [782] GT:A | Base:A | RAG:A |
# [783] GT:B | Base:C | RAG:C |
# [784] GT:A | Base:C | RAG:C |
# [785] GT:D | Base:B | RAG:D | ✅ RAG FIX
# [786] GT:C | Base:B | RAG:B |
# [787] GT:D | Base:B | RAG:B |
# [788] GT:A | Base:B | RAG:B |
# [789] GT:A | Base:B | RAG:B |
# [790] GT:B | Base:D | RAG:D |
# [791] GT:A | Base:C | RAG:C |
# [792] GT:A | Base:D | RAG:D |
# [793] GT:A | Base:D | RAG:D |
# [794] GT:C | Base:A | RAG:A |
# [795] GT:A | Base:A | RAG:A |
# [796] GT:A | Base:A | RAG:A |
# [797] GT:B | Base:C | RAG:A |
# [798] GT:C | Base:B | RAG:B |
# [799] GT:A | Base:A | RAG:A |
# [800] GT:C | Base:C | RAG:C |
# [801] GT:A | Base:A | RAG:A |
# [802] GT:D | Base:B | RAG:B |
# [803] GT:C | Base:C | RAG:C |
# [804] GT:A | Base:A | RAG:A |
# [805] GT:A | Base:D | RAG:D |
# [806] GT:C | Base:B | RAG:B |
# [807] GT:D | Base:B | RAG:B |
# [808] GT:A | Base:D | RAG:D |
# [809] GT:D | Base:B | RAG:B |
# [810] GT:C | Base:A | RAG:A |
# [811] GT:D | Base:B | RAG:B |
# [812] GT:A | Base:C | RAG:C |
# [813] GT:B | Base:A | RAG:A |
# [814] GT:B | Base:B | RAG:B |
# [815] GT:A | Base:C | RAG:C |
# [816] GT:B | Base:D | RAG:A |
# [817] GT:A | Base:B | RAG:B |
# [818] GT:A | Base:D | RAG:A | ✅ RAG FIX
# [819] GT:B | Base:B | RAG:D | ❌ RAG HURT
# [820] GT:A | Base:A | RAG:A |
# [821] GT:C | Base:C | RAG:B | ❌ RAG HURT
# [822] GT:C | Base:A | RAG:A |
# [823] GT:B | Base:B | RAG:B |
# [824] GT:B | Base:C | RAG:C |
# [825] GT:A | Base:B | RAG:B |
# [826] GT:D | Base:C | RAG:C |
# [827] GT:D | Base:D | RAG:D |
# [828] GT:C | Base:C | RAG:C |
# [829] GT:B | Base:A | RAG:A |
# [830] GT:D | Base:A | RAG:D | ✅ RAG FIX
# [1116] GT:D | Base:D | RAG:D |
# [1117] GT:C | Base:B | RAG:C | ✅ RAG FIX
# [1118] GT:A | Base:D | RAG:D |
# [1119] GT:C | Base:C | RAG:C |
# [1120] GT:A | Base:C | RAG:C |
# [1121] GT:D | Base:B | RAG:A |
# [1122] GT:D | Base:A | RAG:A |
# [1123] GT:A | Base:A | RAG:A |
# [1124] GT:C | Base:D | RAG:D |
# [1125] GT:C | Base:C | RAG:C |
# [1126] GT:B | Base:B | RAG:B |
# [1127] GT:A | Base:A | RAG:A |
# [1128] GT:C | Base:B | RAG:B |
# [1129] GT:B | Base:D | RAG:C |
# [1130] GT:B | Base:A | RAG:B | ✅ RAG FIX
# [1131] GT:B | Base:A | RAG:A |
# [1132] GT:B | Base:D | RAG:D |
# [1133] GT:C | Base:C | RAG:C |
# [1134] GT:B | Base:A | RAG:B | ✅ RAG FIX
# [1135] GT:B | Base:B | RAG:B |
# [1136] GT:B | Base:D | RAG:C |
# [1137] GT:D | Base:D | RAG:D |
# [1138] GT:B | Base:A | RAG:A |
# [1139] GT:A | Base:B | RAG:B |
# [1140] GT:D | Base:D | RAG:D |
# [1141] GT:B | Base:C | RAG:C |
# [1142] GT:A | Base:B | RAG:A | ✅ RAG FIX
# [1143] GT:C | Base:C | RAG:C |
# [1144] GT:C | Base:A | RAG:A |
# [1145] GT:A | Base:B | RAG:B |
# [1146] GT:C | Base:C | RAG:A | ❌ RAG HURT
# [1147] GT:B | Base:A | RAG:A |
# [1148] GT:C | Base:B | RAG:B |
# [1149] GT:A | Base:D | RAG:D |
# [1150] GT:C | Base:D | RAG:D |
# [1151] GT:B | Base:C | RAG:C |
# [1152] GT:B | Base:B | RAG:B |
# [1153] GT:B | Base:D | RAG:D |
# [1154] GT:A | Base:D | RAG:D |
# [1155] GT:A | Base:D | RAG:A | ✅ RAG FIX
# [1156] GT:D | Base:D | RAG:D |
# [1157] GT:A | Base:A | RAG:A |
# [1158] GT:B | Base:D | RAG:D |
# [1159] GT:A | Base:A | RAG:A |
# [1160] GT:D | Base:A | RAG:A |
# [1161] GT:C | Base:C | RAG:C |
# [1162] GT:C | Base:D | RAG:D |
# [1163] GT:B | Base:A | RAG:C |
# [1164] GT:A | Base:A | RAG:A |
# [1165] GT:B | Base:D | RAG:D |
# [1166] GT:C | Base:B | RAG:B |
# [1167] GT:A | Base:C | RAG:C |
# [1168] GT:B | Base:A | RAG:A |
# [1169] GT:A | Base:B | RAG:B |
# [1170] GT:D | Base:C | RAG:C |
# [1171] GT:B | Base:A | RAG:A |
# [1172] GT:A | Base:D | RAG:D |
# [1173] GT:D | Base:A | RAG:A |

# %%
import json

# Configuration Section
# Replace the path below with your actual generated jsonl file path
file_path = r"eval_results_llama2/llama2_scoring_20251212_130733.jsonl"

def analyze_negative_transfer(file_path):
    total_samples = 0
    negative_cases = [] # Base Correct, RAG Incorrect
    positive_cases = [] # Base Incorrect, RAG Correct
    neutral_cases = 0   # Results are the same
    
    print(f"Analyzing file: {file_path} ...\n")

    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            for line in f:
                try:
                    data = json.loads(line)
                    total_samples += 1
                    
                    # Assuming jsonl contains the following fields (based on typical eval output assumptions)
                    # You may need to fine-tune based on actual json keys, e.g., 'label' or 'answer_idx'
                    idx = data.get('id', total_samples)
                    question = data.get('question', '')
                    label = data.get('label', '') # Correct answer index (e.g., 0, 1, 2, 3 or A, B, C, D)
                    
                    # Get prediction results
                    base_pred = data.get('base_pred', '') 
                    rag_pred = data.get('rag_pred', '')
                    
                    # Get retrieved context (Key point)
                    context = data.get('context', 'No Context Content')
                    
                    # Simple standardized comparison (convert to string comparison)
                    is_base_correct = str(base_pred) == str(label)
                    is_rag_correct = str(rag_pred) == str(label)

                    if is_base_correct and not is_rag_correct:
                        # Record negative case: Base correct, RAG incorrect
                        negative_cases.append({
                            'id': idx,
                            'question': question,
                            'label': label,
                            'base_pred': base_pred,
                            'rag_pred': rag_pred,
                            'context': context
                        })
                    elif not is_base_correct and is_rag_correct:
                        positive_cases.append(idx)
                    else:
                        neutral_cases += 1
                        
                except json.JSONDecodeError:
                    continue

    except FileNotFoundError:
        print(f"Error: File not found {file_path}")
        return

    #Output Statistical Results
    print(f"=== Analysis Results (Total Samples: {total_samples}) ===")
    print(f"RAG Effective Fix (Base Wrong -> RAG Correct): {len(positive_cases)} cases")
    print(f"RAG Introduced Noise (Base Correct -> RAG Wrong): {len(negative_cases)} cases (Key Focus)")
    print(f"No Change or Both Wrong: {neutral_cases} cases")
    
    rag_drop_rate = (len(negative_cases) / total_samples) * 100 if total_samples > 0 else 0
    print(f"Negative Transfer Rate: {rag_drop_rate:.2f}%")
    
    print("\n" + "="*50)
    print("Detailed Check: Why did RAG cause errors? (Showing first 5 cases)")
    print("="*50)

    for i, case in enumerate(negative_cases[:5]): # Print only the first 5 bad cases
        print(f"\n[Case ID: {case['id']}]")
        print(f"Question: {case['question']}")
        print(f"Correct Answer: {case['label']}")
        print(f"Base Prediction: {case['base_pred']} (Correct)")
        print(f"RAG  Prediction: {case['rag_pred']} (Incorrect)")
        print(f"Retrieved Context (Possible Noise):")
        print(f"   > {case['context'][:300]}...") # Show only first 300 characters
        print("-" * 50)

if __name__ == "__main__":
    analyze_negative_transfer(file_path)

# %%
import os
import json
import re
import pickle
import numpy as np
import pandas as pd
from datetime import datetime
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

import faiss
import pyarrow.parquet as pq
from sentence_transformers import SentenceTransformer

# %%
LLAMA2_PATH = r"llama2"

# %%
# MedMCQA dev.json (Change this to your actual path)
MEDMCQA_FILE = r"medmcqa/dev.json"

# PubMedQA train.parquet (Used to build the paper knowledge base)
PARQUET_PATH = r"pubmedqa_hf/pqa_labeled_splits/train.parquet"

# Your specified new output path (Knowledge Base files)
OUT_INDEX = r"PrimeKG/pubmed_qa.index"
OUT_DOCS  = r"PrimeKG/pubmed_documents.pkl"

# Evaluation output directory (Saves llama2_scoring_xxx.jsonl)
OUTPUT_DIR = r"PrimeKG/eval_results_llama2_paperRAG"

# %%
# RAG Parameters (Paper Repository)
TOP_K_DOCS = 1          # Strongly recommended to start with 1
MAX_CTX_CHARS = 800     # Strongly recommended to start with 600~900; do not make it too long
# Embedding Model (Must match the one used during index construction)
# If the model isn't cached in your offline environment, the download will fail; 
# in that case, replace this with the local path to your existing SentenceTransformer model.
EMBED_MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("DEVICE:", DEVICE)
# Out:
# DEVICE: cuda

# %%
# Cell 2: load Llama-2 4bit
def load_llama2_4bit(model_path):
    print(f"Loading LLaMA2 4-bit from: {model_path}")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.float16,
    )

    tokenizer = AutoTokenizer.from_pretrained(model_path)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    model = AutoModelForCausalLM.from_pretrained(
        model_path,
        quantization_config=bnb_config,
        device_map="auto",
    )

    print("LLaMA2 4-bit loaded!")
    return tokenizer, model

llama2_tokenizer, llama2_model = load_llama2_4bit(LLAMA2_PATH)
# Out:
# Loading LLaMA2 4-bit from: /LLM/llama2
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# LLaMA2 4-bit loaded!

# %%
# Cell 3: load pubmed_qa.index + pubmed_documents.pkl
def build_paper_kb(parquet_path, out_index, out_docs, embed_model_name):
    print("[KB] Building paper KB from:", parquet_path)
    df = pq.read_table(parquet_path).to_pandas()

    documents = []
    for raw_ctx in df["context"]:
        try:
            if hasattr(raw_ctx, "get"):  # dict: {"contexts":[...]}
                text_list = raw_ctx.get("contexts", [])
            else:                        # list
                text_list = raw_ctx
            full_text = " ".join([str(x) for x in text_list if x])
            documents.append(full_text)
        except:
            documents.append("")

    print(f"[KB] Extracted docs: {len(documents)}")

    print("[KB] Embedding docs...")
    embed_model = SentenceTransformer(embed_model_name)
    emb = embed_model.encode(documents, convert_to_numpy=True, show_progress_bar=True)

    # cosine：normalize + IP
    faiss.normalize_L2(emb)
    index = faiss.IndexFlatIP(emb.shape[1])
    index.add(emb)

    os.makedirs(os.path.dirname(out_index), exist_ok=True)
    faiss.write_index(index, out_index)
    with open(out_docs, "wb") as f:
        pickle.dump(documents, f)

    print("[KB] Saved index:", out_index)
    print("[KB] Saved docs :", out_docs)
# Out:
# [KB] Loading index/docs...
# [KB] Loaded. docs: 800

# %%
def load_paper_kb(out_index, out_docs, embed_model_name):
    print("[KB] Loading index/docs...")
    if not os.path.exists(out_index) or not os.path.exists(out_docs):
        return None

    index = faiss.read_index(out_index)
    with open(out_docs, "rb") as f:
        documents = pickle.load(f)
    embed_model = SentenceTransformer(embed_model_name)

    print("[KB] Loaded. docs:", len(documents))
    return index, documents, embed_model

kb = load_paper_kb(OUT_INDEX, OUT_DOCS, EMBED_MODEL_NAME)
if kb is None:
    build_paper_kb(PARQUET_PATH, OUT_INDEX, OUT_DOCS, EMBED_MODEL_NAME)
    kb = load_paper_kb(OUT_INDEX, OUT_DOCS, EMBED_MODEL_NAME)

paper_index, paper_docs, paper_embed = kb
# Out:
# [KB] Loading index/docs...
# [KB] Loaded. docs: 800

# %%
# Cell 4: RAG Functions for Paper Retrieval

def retrieve_papers(query, top_k=TOP_K_DOCS):
    q_emb = paper_embed.encode([query], convert_to_numpy=True)
    faiss.normalize_L2(q_emb)
    scores, idxs = paper_index.search(q_emb, top_k)
    idxs = idxs[0].tolist()
    return [paper_docs[i] for i in idxs if 0 <= i < len(paper_docs)]

def get_paper_context(question, options_dict=None, top_k=TOP_K_DOCS, max_chars=MAX_CTX_CHARS):
    queries = [question]
    if options_dict:
        for lab, txt in options_dict.items():
            if txt:
                queries.append(f"{question} {txt}")

    seen = set()
    blocks = []
    cur = 0

    for q in queries:
        for d in retrieve_papers(q, top_k=top_k):
            d = (d or "").strip()
            if not d:
                continue
            key = d[:200]
            if key in seen:
                continue
            seen.add(key)

            block = f"Paper: {d}\n"
            if cur + len(block) > max_chars:
                return [], "".join(blocks)
            blocks.append(block)
            cur += len(block)

        if cur >= max_chars:
            break

    return [], "".join(blocks)

# %%
# Cell 5: load MedMCQA (return options dict)
def load_medmcqa_example(idx, file_path=MEDMCQA_FILE):
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"File not found: {file_path}")

    with open(file_path, "r", encoding="utf-8") as f:
        for line_id, line in enumerate(f):
            if line_id < idx:
                continue
            if line_id > idx:
                break

            line = line.strip()
            if not line:
                continue

            data = json.loads(line)
            q = data.get("question", "")

            options_dict = {}
            mapping = {"opa": "A", "opb": "B", "opc": "C", "opd": "D"}
            for key, lab in mapping.items():
                if key in data and data[key]:
                    options_dict[lab] = str(data[key]).strip()

            return {
                "id": idx,
                "question": q,
                "options": options_dict,
                "answer": data.get("cop")
            }

    raise IndexError("Index out of range")

# %%
# Cell 6:  Llama 2 PPL Scoring Function (with length normalization)
def get_llama2_score(context, question, option_text):
    sys_msg = "You are a medical expert. Choose the correct option."

    if context:
        user_content = f"Context: {context}\n\nQuestion: {question}"
    else:
        user_content = f"Question: {question}"

    prompt_prefix = (
        f"[INST] <<SYS>>\n{sys_msg}\n<</SYS>>\n\n{user_content} [/INST] "
        f"The correct answer is"
    )
    full_text = f"{prompt_prefix} {option_text}"

    full_enc = llama2_tokenizer(full_text, return_tensors="pt", truncation=True, max_length=2048)
    prompt_enc = llama2_tokenizer(prompt_prefix, return_tensors="pt", add_special_tokens=True)

    input_ids = full_enc.input_ids.to(DEVICE)
    attention_mask = full_enc.attention_mask.to(DEVICE)

    labels = input_ids.clone()
    prompt_len = prompt_enc.input_ids.shape[1]

    if prompt_len >= input_ids.shape[1]:
        return -float("inf")

    labels[:, :prompt_len] = -100

    with torch.no_grad():
        outputs = llama2_model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss

    if torch.isnan(loss):
        return -float("inf")

    return -loss.item()

def solve_by_scoring(question, options_dict, context=""):
    scores = {}
    for label in ["A", "B", "C", "D"]:
        if label not in options_dict:
            scores[label] = -float("inf")
            continue
        scores[label] = get_llama2_score(context, question, options_dict[label])

    best_label = max(scores, key=scores.get)
    return best_label, scores

# %%
# Cell 7: # Run Evaluation with Paper-RAG

def evaluate_and_save(start_idx=0, end_idx=50):
    os.makedirs(OUTPUT_DIR, exist_ok=True)

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    save_path = os.path.join(OUTPUT_DIR, f"llama2_scoring_{timestamp}.jsonl")
    print(f"Results will be saved to: {save_path}")
    print(f"Starting SCORING evaluation {start_idx} -> {end_idx}...\n")

    total = 0
    correct_base = 0
    correct_rag = 0

    def format_gt(val):
        s = str(val).strip().upper()
        mapping = {"1": "A", "2": "B", "3": "C", "4": "D"}
        if s in mapping:
            return mapping[s]
        if s in ["A", "B", "C", "D"]:
            return s
        return None

    with open(save_path, "w", encoding="utf-8") as f:
        for i in range(start_idx, end_idx):
            try:
                ex = load_medmcqa_example(i)
                gt = format_gt(ex["answer"])
                if not gt:
                    continue

                q_text = ex["question"]
                opts = ex["options"]

                # Base
                pred_base, scores_base = solve_by_scoring(q_text, opts, context="")

                # Paper-RAG
                ents, ctx = get_paper_context(q_text, opts, top_k=TOP_K_DOCS, max_chars=MAX_CTX_CHARS)
                pred_rag, scores_rag = solve_by_scoring(q_text, opts, context=ctx)

                total += 1
                if pred_base == gt:
                    correct_base += 1
                if pred_rag == gt:
                    correct_rag += 1

                status = ""
                if pred_rag == gt and pred_base != gt:
                    status = "O RAG FIX"
                elif pred_rag != gt and pred_base == gt:
                    status = "X RAG HURT"

                if i < start_idx + 3:
                    print(f"\n[DEBUG ID {i}]")
                    print("Q:", q_text[:120], "...")
                    print("GT:", gt, "| Base:", pred_base, "| RAG:", pred_rag, status)
                    print("Base scores:", {k: round(v, 4) for k, v in scores_base.items()})
                    print("RAG  scores:", {k: round(v, 4) for k, v in scores_rag.items()})
                    print("CTX(head):", (ctx[:300] + "...") if ctx else "<EMPTY>")

                record = {
                    "id": i,
                    "question": q_text,
                    "ground_truth": gt,
                    "base_prediction": pred_base,
                    "rag_prediction": pred_rag,
                    "rag_context": ctx,
                    "scores_base": scores_base,
                    "scores_rag": scores_rag,
                    "is_base_correct": (pred_base == gt),
                    "is_rag_correct": (pred_rag == gt),
                }
                f.write(json.dumps(record, ensure_ascii=False) + "\n")

                if i >= start_idx + 3:
                    print(f"[{i}] GT:{gt} | Base:{pred_base} | RAG:{pred_rag} | {status}")

            except Exception as e:
                print(f"Skipping {i}: {e}")
                continue

    if total > 0:
        print("\n" + "=" * 30)
        print(f"Total    : {total}")
        print(f"Base Acc : {correct_base/total:.2%}")
        print(f"RAG  Acc : {correct_rag/total:.2%}")
        print("=" * 30 + "\n")

    return save_path

# %%
# Cell 8: Start Execution
save_path = evaluate_and_save(0, 1500)
print("Saved:", save_path)
# Out:
# Results will be saved to: /LLM/PrimeKG/eval_results_llama2_paperRAG/llama2_scoring_20251222_172524.jsonl
# Starting SCORING evaluation 0 -> 1500...
#
#
# [DEBUG ID 0]
# Q: Which of the following is not true for myelinated nerve fibers: ...
# GT: A | Base: A | RAG: A
# Base scores: {'A': -2.7494, 'B': -4.2843, 'C': -3.8867, 'D': -3.4827}
# RAG  scores: {'A': -2.7494, 'B': -4.2843, 'C': -3.8867, 'D': -3.4827}
# CTX(head): <EMPTY>
#
# [DEBUG ID 1]
# Q: Which of the following is not true about glomerular capillaries') ...
# GT: A | Base: D | RAG: D
# Base scores: {'A': -3.988, 'B': -3.7157, 'C': -4.1374, 'D': -3.5972}
# RAG  scores: {'A': -3.988, 'B': -3.7157, 'C': -4.1374, 'D': -3.5972}
# CTX(head): <EMPTY>
#
# [DEBUG ID 2]
# Q: A 29 yrs old woman with a pregnancy of 17 week has a 10 years old boy with down syndrome. She does not want another down ...
# GT: C | Base: A | RAG: A
# Base scores: {'A': -4.3582, 'B': -4.4772, 'C': -5.0548, 'D': -6.5388}
# [146] GT:C | Base:D | RAG:D |
# [147] GT:A | Base:A | RAG:A |
# [148] GT:D | Base:C | RAG:C |
# [149] GT:B | Base:B | RAG:B |
# [150] GT:A | Base:C | RAG:C |
# [151] GT:B | Base:B | RAG:B |
# [152] GT:C | Base:D | RAG:D |
# [153] GT:A | Base:A | RAG:A |
# [154] GT:B | Base:C | RAG:C |
# [155] GT:B | Base:D | RAG:D |
# [156] GT:A | Base:A | RAG:A |
# [157] GT:D | Base:D | RAG:D |
# [158] GT:C | Base:C | RAG:C |
# [159] GT:D | Base:B | RAG:B |
# [160] GT:B | Base:A | RAG:A |
# [161] GT:B | Base:A | RAG:A |
# [162] GT:B | Base:C | RAG:C |
# [163] GT:D | Base:D | RAG:D |
# [164] GT:A | Base:C | RAG:C |
# [165] GT:C | Base:B | RAG:B |
# [166] GT:D | Base:C | RAG:C |
# [167] GT:B | Base:A | RAG:A |
# [168] GT:B | Base:A | RAG:A |
# [169] GT:C | Base:A | RAG:B |
# [170] GT:B | Base:D | RAG:D |
# [171] GT:A | Base:D | RAG:D |
# [172] GT:B | Base:D | RAG:D |
# [173] GT:A | Base:B | RAG:B |
# [174] GT:B | Base:A | RAG:A |
# [175] GT:C | Base:B | RAG:B |
# [176] GT:B | Base:C | RAG:C |
# [177] GT:C | Base:D | RAG:D |
# [178] GT:D | Base:D | RAG:D |
# [179] GT:D | Base:D | RAG:D |
# [180] GT:B | Base:C | RAG:C |
# [181] GT:A | Base:B | RAG:B |
# [182] GT:A | Base:C | RAG:C |
# [183] GT:A | Base:A | RAG:A |
# [184] GT:C | Base:C | RAG:C |
# [185] GT:C | Base:D | RAG:D |
# [186] GT:B | Base:D | RAG:D |
# [187] GT:A | Base:D | RAG:D |
# [188] GT:C | Base:B | RAG:B |
# [189] GT:A | Base:B | RAG:A | ✅ RAG FIX
# [190] GT:B | Base:A | RAG:A |
# [191] GT:A | Base:B | RAG:B |
# [192] GT:B | Base:B | RAG:B |
# [193] GT:B | Base:C | RAG:C |
# [194] GT:B | Base:D | RAG:D |
# [195] GT:B | Base:A | RAG:A |
# [196] GT:A | Base:A | RAG:A |
# [197] GT:B | Base:C | RAG:C |
# [198] GT:D | Base:D | RAG:D |
# [199] GT:A | Base:A | RAG:A |
# [200] GT:D | Base:B | RAG:B |
# [201] GT:C | Base:D | RAG:D |
# [202] GT:B | Base:C | RAG:C |
# [203] GT:C | Base:B | RAG:B |
# [204] GT:C | Base:C | RAG:C |
# [205] GT:D | Base:A | RAG:A |
# [206] GT:C | Base:B | RAG:B |
# [207] GT:C | Base:A | RAG:A |
# [208] GT:D | Base:B | RAG:B |
# [209] GT:B | Base:A | RAG:A |
# [210] GT:B | Base:B | RAG:B |
# [211] GT:A | Base:D | RAG:D |
# [212] GT:D | Base:D | RAG:D |
# [213] GT:C | Base:B | RAG:B |
# [214] GT:C | Base:B | RAG:B |
# [215] GT:C | Base:D | RAG:D |
# [216] GT:A | Base:D | RAG:D |
# [217] GT:A | Base:C | RAG:C |
# [218] GT:D | Base:D | RAG:D |
# [655] GT:C | Base:B | RAG:B |
# [656] GT:B | Base:C | RAG:C |
# [657] GT:A | Base:A | RAG:A |
# [658] GT:B | Base:C | RAG:C |
# [659] GT:A | Base:C | RAG:C |
# [660] GT:A | Base:C | RAG:C |
# [661] GT:B | Base:B | RAG:B |
# [662] GT:A | Base:B | RAG:B |
# [663] GT:A | Base:A | RAG:A |
# [664] GT:D | Base:C | RAG:C |
# [665] GT:D | Base:C | RAG:C |
# [666] GT:A | Base:C | RAG:C |
# [667] GT:D | Base:A | RAG:A |
# [668] GT:B | Base:D | RAG:D |
# [669] GT:C | Base:A | RAG:A |
# [670] GT:A | Base:D | RAG:D |
# [671] GT:A | Base:B | RAG:B |
# [672] GT:D | Base:B | RAG:B |
# [673] GT:D | Base:B | RAG:B |
# [674] GT:D | Base:D | RAG:D |
# [675] GT:B | Base:C | RAG:C |
# [676] GT:A | Base:D | RAG:D |
# [677] GT:B | Base:C | RAG:C |
# [678] GT:A | Base:B | RAG:B |
# [679] GT:B | Base:A | RAG:A |
# [680] GT:D | Base:C | RAG:C |
# [681] GT:C | Base:D | RAG:D |
# [682] GT:B | Base:B | RAG:B |
# [683] GT:B | Base:D | RAG:D |
# [684] GT:D | Base:C | RAG:C |
# [685] GT:B | Base:B | RAG:B |
# [686] GT:A | Base:D | RAG:D |
# [687] GT:D | Base:B | RAG:B |
# [688] GT:D | Base:C | RAG:C |
# [689] GT:D | Base:A | RAG:A |
# [690] GT:B | Base:D | RAG:D |
# [691] GT:C | Base:C | RAG:C |
# [692] GT:D | Base:D | RAG:D |
# [693] GT:B | Base:A | RAG:A |
# [694] GT:D | Base:D | RAG:D |
# [695] GT:A | Base:A | RAG:A |
# [696] GT:A | Base:D | RAG:D |
# [697] GT:C | Base:A | RAG:A |
# [698] GT:A | Base:C | RAG:C |
# [699] GT:C | Base:C | RAG:C |
# [700] GT:B | Base:A | RAG:A |
# [701] GT:A | Base:C | RAG:C |
# [702] GT:D | Base:A | RAG:A |
# [703] GT:C | Base:D | RAG:D |
# [704] GT:A | Base:A | RAG:A |
# [705] GT:B | Base:B | RAG:B |
# [706] GT:D | Base:D | RAG:D |
# [707] GT:B | Base:B | RAG:B |
# [708] GT:B | Base:D | RAG:D |
# [709] GT:D | Base:B | RAG:B |
# [710] GT:A | Base:A | RAG:A |
# [711] GT:D | Base:A | RAG:A |
# [712] GT:B | Base:C | RAG:C |
# [713] GT:B | Base:C | RAG:C |
# [714] GT:B | Base:C | RAG:C |
# [715] GT:A | Base:D | RAG:D |
# [716] GT:B | Base:B | RAG:B |
# [717] GT:D | Base:B | RAG:B |
# [718] GT:A | Base:A | RAG:A |
# [719] GT:A | Base:C | RAG:C |
# [720] GT:C | Base:A | RAG:A |
# [721] GT:D | Base:D | RAG:D |
# [722] GT:C | Base:D | RAG:D |
# [723] GT:B | Base:B | RAG:B |
# [724] GT:B | Base:D | RAG:D |
# [725] GT:C | Base:B | RAG:B |
# [726] GT:B | Base:A | RAG:C |
# [727] GT:C | Base:D | RAG:D |
# [728] GT:A | Base:C | RAG:C |
# [729] GT:B | Base:A | RAG:A |
# [730] GT:D | Base:D | RAG:D |
# [731] GT:C | Base:A | RAG:A |
# [732] GT:B | Base:B | RAG:B |
# [733] GT:B | Base:B | RAG:B |
# [734] GT:A | Base:A | RAG:A |
# [735] GT:D | Base:B | RAG:B |
# [736] GT:C | Base:B | RAG:B |
# [737] GT:A | Base:B | RAG:B |
# [738] GT:B | Base:C | RAG:C |
# [739] GT:C | Base:C | RAG:C |
# [740] GT:C | Base:A | RAG:A |
# [741] GT:A | Base:B | RAG:B |
# [742] GT:A | Base:B | RAG:B |
# [743] GT:B | Base:D | RAG:D |
# [744] GT:A | Base:C | RAG:C |
# [745] GT:C | Base:D | RAG:D |
# [746] GT:D | Base:C | RAG:C |
# [747] GT:C | Base:C | RAG:C |
# [748] GT:A | Base:A | RAG:D | ❌ RAG HURT
# [749] GT:D | Base:C | RAG:C |
# [750] GT:B | Base:B | RAG:B |
# [751] GT:B | Base:B | RAG:B |
# [752] GT:A | Base:A | RAG:A |
# [753] GT:D | Base:D | RAG:D |
# [754] GT:C | Base:C | RAG:C |
# [755] GT:A | Base:C | RAG:C |
# [756] GT:C | Base:C | RAG:C |
# [757] GT:B | Base:D | RAG:D |
# [758] GT:C | Base:D | RAG:D |
# [759] GT:A | Base:D | RAG:D |
# [760] GT:A | Base:D | RAG:D |
# [761] GT:C | Base:A | RAG:A |
# [762] GT:B | Base:C | RAG:C |
# [763] GT:C | Base:D | RAG:D |
# [764] GT:A | Base:B | RAG:B |
# [765] GT:D | Base:C | RAG:C |
# [766] GT:C | Base:B | RAG:B |
# [767] GT:A | Base:C | RAG:C |
# [768] GT:B | Base:D | RAG:D |
# [769] GT:A | Base:A | RAG:A |
# [770] GT:A | Base:A | RAG:A |
# [771] GT:A | Base:A | RAG:A |
# [772] GT:A | Base:A | RAG:C | ❌ RAG HURT
# [773] GT:B | Base:A | RAG:A |
# [774] GT:C | Base:C | RAG:C |
# [775] GT:C | Base:C | RAG:C |
# [776] GT:C | Base:A | RAG:A |
# [777] GT:A | Base:D | RAG:D |
# [778] GT:D | Base:A | RAG:A |
# [779] GT:B | Base:B | RAG:B |
# [780] GT:A | Base:C | RAG:C |
# [781] GT:D | Base:B | RAG:B |
# [782] GT:A | Base:A | RAG:A |
# [783] GT:B | Base:A | RAG:A |
# [784] GT:A | Base:C | RAG:C |
# [785] GT:D | Base:B | RAG:B |
# [786] GT:C | Base:B | RAG:B |
# [787] GT:D | Base:B | RAG:B |
# [788] GT:A | Base:B | RAG:B |
# [789] GT:A | Base:B | RAG:B |
# [790] GT:B | Base:D | RAG:D |
# [791] GT:A | Base:B | RAG:D |
# [792] GT:A | Base:D | RAG:D |
# [793] GT:A | Base:A | RAG:A |
# [794] GT:C | Base:A | RAG:D |
# [795] GT:A | Base:B | RAG:B |
# [796] GT:A | Base:A | RAG:A |
# [797] GT:B | Base:C | RAG:C |
# [798] GT:C | Base:B | RAG:B |
# [799] GT:A | Base:B | RAG:B |
# [800] GT:C | Base:C | RAG:C |
# [801] GT:A | Base:A | RAG:A |
# [802] GT:D | Base:A | RAG:A |
# [803] GT:C | Base:C | RAG:C |
# [804] GT:A | Base:A | RAG:A |
# [805] GT:A | Base:D | RAG:D |
# [806] GT:C | Base:B | RAG:B |
# [807] GT:D | Base:D | RAG:D |
# [808] GT:A | Base:A | RAG:A |
# [809] GT:D | Base:B | RAG:B |
# [810] GT:C | Base:A | RAG:A |
# [811] GT:D | Base:B | RAG:B |
# [812] GT:A | Base:C | RAG:C |
# [813] GT:B | Base:A | RAG:A |
# [814] GT:B | Base:B | RAG:B |
# [815] GT:A | Base:C | RAG:C |
# [816] GT:B | Base:B | RAG:B |
# [817] GT:A | Base:B | RAG:B |
# [818] GT:A | Base:A | RAG:A |
# [819] GT:B | Base:C | RAG:C |
# [820] GT:A | Base:A | RAG:A |
# [821] GT:C | Base:C | RAG:C |
# [822] GT:C | Base:A | RAG:A |
# [823] GT:B | Base:A | RAG:A |
# [824] GT:B | Base:C | RAG:C |
# [825] GT:A | Base:C | RAG:C |
# [826] GT:D | Base:C | RAG:C |
# [827] GT:D | Base:C | RAG:C |
# [828] GT:C | Base:D | RAG:D |
# [829] GT:B | Base:A | RAG:A |
# [830] GT:D | Base:A | RAG:A |
# [831] GT:B | Base:D | RAG:D |
# [832] GT:C | Base:B | RAG:B |
# [833] GT:D | Base:B | RAG:B |
# [834] GT:B | Base:C | RAG:C |
# [835] GT:A | Base:A | RAG:A |
# [836] GT:A | Base:D | RAG:D |
# [837] GT:D | Base:A | RAG:A |
# [838] GT:C | Base:B | RAG:B |
# [839] GT:B | Base:D | RAG:D |
# [840] GT:A | Base:C | RAG:C |
# [841] GT:B | Base:D | RAG:D |
# [842] GT:C | Base:D | RAG:D |
# [843] GT:D | Base:D | RAG:D |
# [844] GT:B | Base:D | RAG:D |
# [845] GT:B | Base:C | RAG:C |
# [846] GT:C | Base:C | RAG:C |
# [847] GT:A | Base:C | RAG:C |
# [848] GT:A | Base:B | RAG:B |
# [849] GT:B | Base:B | RAG:B |
# [850] GT:C | Base:A | RAG:A |
# [851] GT:A | Base:A | RAG:A |
# [852] GT:C | Base:A | RAG:A |
# [853] GT:B | Base:B | RAG:B |
# [854] GT:D | Base:C | RAG:C |
# [855] GT:C | Base:B | RAG:B |
# [856] GT:C | Base:C | RAG:C |
# [857] GT:A | Base:D | RAG:D |
# [858] GT:A | Base:A | RAG:A |
# [859] GT:A | Base:C | RAG:C |
# [860] GT:D | Base:D | RAG:D |
# [861] GT:A | Base:A | RAG:A |
# [862] GT:C | Base:A | RAG:A |
# [863] GT:A | Base:A | RAG:B | ❌ RAG HURT
# [864] GT:B | Base:C | RAG:C |
# [865] GT:A | Base:D | RAG:D |
# [866] GT:D | Base:D | RAG:D |
# [867] GT:C | Base:C | RAG:C |
# [868] GT:C | Base:A | RAG:A |
# [869] GT:C | Base:C | RAG:C |
# [870] GT:B | Base:C | RAG:C |
# [871] GT:B | Base:D | RAG:D |
# [872] GT:A | Base:A | RAG:A |
# [873] GT:A | Base:B | RAG:B |
# [874] GT:D | Base:D | RAG:D |
# [875] GT:A | Base:A | RAG:A |
# [876] GT:D | Base:D | RAG:D |
# [877] GT:A | Base:C | RAG:C |
# [878] GT:C | Base:D | RAG:D |
# [879] GT:A | Base:C | RAG:C |
# [880] GT:D | Base:B | RAG:B |
# [881] GT:C | Base:A | RAG:A |
# [882] GT:C | Base:A | RAG:A |
# [883] GT:D | Base:C | RAG:C |
# [884] GT:D | Base:D | RAG:D |
# [885] GT:A | Base:B | RAG:B |
# [886] GT:C | Base:B | RAG:B |
# [887] GT:A | Base:D | RAG:D |
# [888] GT:A | Base:A | RAG:A |
# [889] GT:B | Base:D | RAG:D |
# [890] GT:C | Base:D | RAG:D |
# [891] GT:A | Base:D | RAG:D |
# [892] GT:A | Base:A | RAG:A |
# [893] GT:D | Base:D | RAG:D |
# [894] GT:C | Base:B | RAG:B |
# [895] GT:A | Base:A | RAG:A |
# [896] GT:B | Base:D | RAG:D |
# [897] GT:A | Base:C | RAG:C |
# [898] GT:A | Base:D | RAG:D |
# [899] GT:D | Base:C | RAG:C |
# [900] GT:A | Base:B | RAG:B |
# [901] GT:A | Base:B | RAG:B |
# [902] GT:C | Base:D | RAG:D |
# [903] GT:B | Base:B | RAG:B |
# [904] GT:A | Base:A | RAG:A |
# [905] GT:D | Base:C | RAG:C |
# [906] GT:B | Base:C | RAG:C |
# [907] GT:B | Base:B | RAG:B |
# [908] GT:D | Base:D | RAG:D |
# [909] GT:A | Base:B | RAG:B |
# [910] GT:C | Base:B | RAG:B |
# [911] GT:B | Base:B | RAG:B |
# [912] GT:A | Base:B | RAG:B |
# [913] GT:B | Base:D | RAG:D |
# [914] GT:D | Base:D | RAG:D |
# [915] GT:B | Base:B | RAG:B |
# [916] GT:C | Base:C | RAG:C |
# [917] GT:C | Base:C | RAG:C |
# [918] GT:B | Base:C | RAG:C |
# [919] GT:A | Base:D | RAG:D |
# [920] GT:A | Base:D | RAG:D |
# [921] GT:C | Base:B | RAG:B |
# [922] GT:A | Base:A | RAG:A |
# [923] GT:C | Base:C | RAG:C |
# [924] GT:D | Base:C | RAG:C |
# [925] GT:B | Base:C | RAG:B | ✅ RAG FIX
# [926] GT:B | Base:D | RAG:D |
# [927] GT:B | Base:A | RAG:A |
# [928] GT:C | Base:D | RAG:D |
# [929] GT:A | Base:A | RAG:A |
# [930] GT:A | Base:D | RAG:D |
# [931] GT:A | Base:B | RAG:B |
# [932] GT:B | Base:D | RAG:D |
# [933] GT:A | Base:B | RAG:B |
# [934] GT:C | Base:D | RAG:D |
# [935] GT:C | Base:C | RAG:C |
# [936] GT:A | Base:A | RAG:A |
# [937] GT:B | Base:A | RAG:A |
# [938] GT:A | Base:D | RAG:D |
# [939] GT:A | Base:B | RAG:B |
# [940] GT:A | Base:A | RAG:A |
# [941] GT:B | Base:A | RAG:A |
# [942] GT:B | Base:C | RAG:C |
# [943] GT:C | Base:A | RAG:A |
# [944] GT:A | Base:C | RAG:C |
# [945] GT:B | Base:D | RAG:D |
# [946] GT:B | Base:B | RAG:B |
# [1435] GT:A | Base:A | RAG:A |
# [1436] GT:A | Base:A | RAG:A |
# [1437] GT:D | Base:B | RAG:B |
# [1438] GT:A | Base:A | RAG:A |
# [1439] GT:B | Base:A | RAG:A |
# [1440] GT:A | Base:D | RAG:D |
# [1441] GT:D | Base:B | RAG:B |
# [1442] GT:C | Base:A | RAG:A |
# [1443] GT:B | Base:A | RAG:A |
# [1444] GT:A | Base:B | RAG:B |
# [1445] GT:B | Base:D | RAG:D |
# [1446] GT:B | Base:A | RAG:A |
# [1447] GT:D | Base:D | RAG:D |
# [1448] GT:A | Base:D | RAG:D |
# [1449] GT:B | Base:A | RAG:A |
# [1450] GT:A | Base:D | RAG:D |
# [1451] GT:A | Base:C | RAG:C |
# [1452] GT:A | Base:C | RAG:C |
# [1453] GT:A | Base:B | RAG:B |
# [1454] GT:C | Base:D | RAG:D |
# [1455] GT:A | Base:A | RAG:A |
# [1456] GT:B | Base:B | RAG:B |
# [1457] GT:B | Base:B | RAG:B |
# [1458] GT:C | Base:C | RAG:C |
# [1459] GT:A | Base:D | RAG:D |
# [1460] GT:C | Base:B | RAG:B |
# [1461] GT:C | Base:C | RAG:C |
# [1462] GT:A | Base:C | RAG:C |
# [1463] GT:D | Base:D | RAG:D |
# [1464] GT:C | Base:C | RAG:C |
# [1465] GT:A | Base:B | RAG:B |
# [1466] GT:B | Base:C | RAG:C |
# [1467] GT:B | Base:D | RAG:D |
# [1468] GT:D | Base:C | RAG:C |
# [1469] GT:B | Base:B | RAG:B |
# [1470] GT:B | Base:C | RAG:C |
# [1471] GT:C | Base:D | RAG:D |
# [1472] GT:D | Base:C | RAG:C |
# [1473] GT:C | Base:D | RAG:D |
# [1474] GT:D | Base:C | RAG:C |
# [1475] GT:A | Base:C | RAG:C |
# [1476] GT:A | Base:C | RAG:C |
# [1477] GT:C | Base:A | RAG:A |
# [1478] GT:B | Base:B | RAG:B |
# [1479] GT:A | Base:D | RAG:D |
# [1480] GT:B | Base:B | RAG:B |
# [1481] GT:C | Base:B | RAG:B |
# [1482] GT:D | Base:D | RAG:D |
# [1483] GT:D | Base:C | RAG:C |
# [1484] GT:D | Base:A | RAG:D | ✅ RAG FIX
# [1485] GT:C | Base:B | RAG:B |
# [1486] GT:C | Base:D | RAG:D |
# [1487] GT:C | Base:D | RAG:D |
# [1488] GT:A | Base:D | RAG:D |
# [1489] GT:B | Base:D | RAG:D |
# [1490] GT:B | Base:B | RAG:B |
# [1491] GT:A | Base:D | RAG:D |
# [1492] GT:D | Base:D | RAG:D |
# [1493] GT:A | Base:A | RAG:A |
# [1494] GT:C | Base:C | RAG:C |
# [1495] GT:C | Base:A | RAG:A |
# [1496] GT:A | Base:D | RAG:D |
# [1497] GT:A | Base:A | RAG:A |
# [1498] GT:B | Base:D | RAG:D |
# [1499] GT:A | Base:D | RAG:D |
#
# ==============================
# Total    : 1500
# Base Acc : 31.87%
# RAG  Acc : 31.53%
# ==============================
#
# Saved: /LLM/PrimeKG/eval_results_llama2_paperRAG/llama2_scoring_20251222_172524.jsonl
